# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 4
sample_id = 3
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 4:
# Samples: 10000
# Label Counts: {0: 1003, 1: 963, 2: 1041, 3: 976, 4: 1004, 5: 1021, 6: 1004, 7: 981, 8: 1024, 9: 983}
# First 20 Labels: [0, 6, 0, 2, 7, 2, 1, 2, 4, 1, 5, 6, 6, 3, 1, 3, 5, 5, 8, 1]
#
# Example of Image 3:
# Image - Min Value: 0 Max Value: 248
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
from sklearn import preprocessing

def normalize(images):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : images: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return images / 255.0

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing

range_of_labels = range(0, 10)
one_hot_encoder = preprocessing.LabelBinarizer()
one_hot_encoder.fit(range_of_labels)

def one_hot_encode(labels):
    """
    One-hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : labels: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    return one_hot_encoder.transform(labels)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, (None,) + image_shape, name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.float32, (None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
# A helper method to initialize weights to sensible values
def weights_stddev(shape):
    # the last element is the number of outputs
    num_inputs = sum(shape[:-1])
    return 1.0 / np.sqrt(num_inputs)

import unittest
test = unittest.TestCase('__init__')
test.assertEqual(weights_stddev([8, 4, 4, 9]), 0.25)
test.assertEqual(weights_stddev([4, 10000]), 0.5)
print("Tests passed")
# Out:
# Tests passed

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    weights_shape = (conv_ksize[0], conv_ksize[1], x_tensor.shape[3].value, conv_num_outputs)
    weights = tf.Variable(tf.truncated_normal(weights_shape, mean=0.0, stddev=weights_stddev(weights_shape)))

    biases = tf.Variable(tf.zeros(conv_num_outputs))

    # Convolution
    conv_layer = tf.nn.conv2d(
        x_tensor,
        weights,
        strides=[1, conv_strides[0], conv_strides[1], 1],
        padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, biases)
    
    # Nonlinearity
    conv_layer = tf.nn.relu(conv_layer)
    
    # Max Pooling
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=[1, pool_ksize[0], pool_ksize[1], 1],
        strides=[1, pool_strides[0], pool_strides[1], 1],
        padding='SAME')
    
    return conv_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    flattened_image_length = (x_tensor.shape[1] * x_tensor.shape[2] * x_tensor.shape[3]).value
    return tf.reshape(x_tensor, shape=(-1, flattened_image_length))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights_shape = [x_tensor.shape[1].value, num_outputs]
    weights = tf.Variable(tf.truncated_normal(weights_shape, mean=0.0, stddev=weights_stddev(weights_shape)))
    
    biases = tf.Variable(tf.zeros(num_outputs))

    fully_connected_layer = tf.add(tf.matmul(x_tensor, weights), biases)
    fully_connected_layer = tf.nn.relu(fully_connected_layer)
    
    return fully_connected_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    weights_shape = [x_tensor.shape[1].value, num_outputs]
    weights = tf.Variable(tf.truncated_normal(weights_shape, mean=0.0, stddev=weights_stddev(weights_shape)))
    biases = tf.Variable(tf.zeros(num_outputs))
    
    output = tf.add(tf.matmul(x_tensor, weights), biases)
                          
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """

    # Convolutional Layer 1
    # ---------------------
    #
    #  input: 32x32x3
    #  20 8x8x3 filters
    #  stride: 1 in both directions
    #   => convolution output:  32x32x20
    #  pool shape: 2x2
    #  pool stride: 2 in both directions
    #   => pooling output:  16x16x20
    #
    # Reminder: conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv_net = conv2d_maxpool(x, 20, (8, 8, 3), (1, 1), (2, 2), (2, 2))

    # Convolutional Layer 2
    # ---------------------
    #
    #  input: 16x16x20
    #  30 4x4x20 filters
    #  stride: 1 in both directions
    #   => convolution output:  16x16x30
    #  pool shape: 2x2
    #  pool stride: 2 in both directions
    #   => pooling output:  8x8x30
    conv_net = conv2d_maxpool(conv_net, 40, (4, 4, 20), (1, 1), (2, 2), (2, 2))
    
    # Convolutional Layer 3
    # ---------------------
    #
    #  input: 8x8x30
    #  40 3x3x30 filters
    #  stride: 1 in both directions
    #   => convolution output:  8x8x40
    #  pool shape: 2x2
    #  pool stride: 2 in both directions
    #   => pooling output:  4x4x40
    conv_net = conv2d_maxpool(conv_net, 40, (3, 3, 30), (1, 1), (2, 2), (2, 2))

    # Flattening
    # ----------
    #
    #  4x4x40 => 640
    conv_net = flatten(conv_net)

    # Fully Connected Layer
    # ---------------------
    #
    #  640 -> 100
    conv_net = fully_conn(conv_net, 100)
    
    # Dropout
    # -------
    #
    conv_net = tf.nn.dropout(conv_net, keep_prob)

    # Output Layer
    # ------------
    #
    #  100 -> 10
    return output(conv_net, 10)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability
    })


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
        
    cost = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0})
    
    accuracy = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0})

    print("Cost: {:.2f}, Accuracy: {:.3f}".format(cost, accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# Tune Parameters
epochs = 200
batch_size = 4096
keep_probability = 0.6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.80, Accuracy: 0.113
# Epoch  2, CIFAR-10 Batch 1:  Cost: 2.31, Accuracy: 0.140
# Epoch  3, CIFAR-10 Batch 1:  Cost: 2.24, Accuracy: 0.165
# Epoch  4, CIFAR-10 Batch 1:  Cost: 2.24, Accuracy: 0.177
# Epoch  5, CIFAR-10 Batch 1:  Cost: 2.21, Accuracy: 0.183
# Epoch  6, CIFAR-10 Batch 1:  Cost: 2.16, Accuracy: 0.196
# Epoch  7, CIFAR-10 Batch 1:  Cost: 2.11, Accuracy: 0.206
# Epoch  8, CIFAR-10 Batch 1:  Cost: 2.08, Accuracy: 0.226
# Epoch  9, CIFAR-10 Batch 1:  Cost: 2.05, Accuracy: 0.252
# Epoch 10, CIFAR-10 Batch 1:  Cost: 2.01, Accuracy: 0.259
# Epoch 11, CIFAR-10 Batch 1:  Cost: 1.96, Accuracy: 0.263
# Epoch 12, CIFAR-10 Batch 1:  Cost: 1.92, Accuracy: 0.294
# Epoch 13, CIFAR-10 Batch 1:  Cost: 1.88, Accuracy: 0.303
# Epoch 14, CIFAR-10 Batch 1:  Cost: 1.84, Accuracy: 0.314
# Epoch 15, CIFAR-10 Batch 1:  Cost: 1.82, Accuracy: 0.333
# Epoch 16, CIFAR-10 Batch 1:  Cost: 1.78, Accuracy: 0.339
# Epoch 17, CIFAR-10 Batch 1:  Cost: 1.74, Accuracy: 0.350
# Epoch 18, CIFAR-10 Batch 1:  Cost: 1.70, Accuracy: 0.364
# Epoch 19, CIFAR-10 Batch 1:  Cost: 1.67, Accuracy: 0.380
# Epoch 20, CIFAR-10 Batch 1:  Cost: 1.65, Accuracy: 0.386
# Epoch 21, CIFAR-10 Batch 1:  Cost: 1.61, Accuracy: 0.396
# Epoch 22, CIFAR-10 Batch 1:  Cost: 1.58, Accuracy: 0.397
# Epoch 23, CIFAR-10 Batch 1:  Cost: 1.55, Accuracy: 0.412
# Epoch 24, CIFAR-10 Batch 1:  Cost: 1.54, Accuracy: 0.414
# Epoch 25, CIFAR-10 Batch 1:  Cost: 1.50, Accuracy: 0.414
# Epoch 26, CIFAR-10 Batch 1:  Cost: 1.46, Accuracy: 0.421
# Epoch 27, CIFAR-10 Batch 1:  Cost: 1.43, Accuracy: 0.425
# Epoch 28, CIFAR-10 Batch 1:  Cost: 1.42, Accuracy: 0.429
# Epoch 29, CIFAR-10 Batch 1:  Cost: 1.39, Accuracy: 0.429
# Epoch 30, CIFAR-10 Batch 1:  Cost: 1.36, Accuracy: 0.432
# Epoch 31, CIFAR-10 Batch 1:  Cost: 1.34, Accuracy: 0.437
# Epoch 32, CIFAR-10 Batch 1:  Cost: 1.33, Accuracy: 0.436
# Epoch 33, CIFAR-10 Batch 1:  Cost: 1.30, Accuracy: 0.453
# Epoch 34, CIFAR-10 Batch 1:  Cost: 1.29, Accuracy: 0.453
# Epoch 35, CIFAR-10 Batch 1:  Cost: 1.27, Accuracy: 0.456
# Epoch 36, CIFAR-10 Batch 1:  Cost: 1.25, Accuracy: 0.454
# Epoch 37, CIFAR-10 Batch 1:  Cost: 1.23, Accuracy: 0.451
# Epoch 38, CIFAR-10 Batch 1:  Cost: 1.21, Accuracy: 0.456
# Epoch 39, CIFAR-10 Batch 1:  Cost: 1.20, Accuracy: 0.450
# Epoch 40, CIFAR-10 Batch 1:  Cost: 1.19, Accuracy: 0.458
# Epoch 41, CIFAR-10 Batch 1:  Cost: 1.17, Accuracy: 0.464
# Epoch 42, CIFAR-10 Batch 1:  Cost: 1.17, Accuracy: 0.463
# Epoch 43, CIFAR-10 Batch 1:  Cost: 1.15, Accuracy: 0.467
# Epoch 44, CIFAR-10 Batch 1:  Cost: 1.14, Accuracy: 0.459
# Epoch 45, CIFAR-10 Batch 1:  Cost: 1.11, Accuracy: 0.462
# Epoch 46, CIFAR-10 Batch 1:  Cost: 1.13, Accuracy: 0.469
# Epoch 47, CIFAR-10 Batch 1:  Cost: 1.09, Accuracy: 0.474
# Epoch 48, CIFAR-10 Batch 1:  Cost: 1.07, Accuracy: 0.468
# Epoch 49, CIFAR-10 Batch 1:  Cost: 1.06, Accuracy: 0.473
# Epoch 50, CIFAR-10 Batch 1:  Cost: 1.06, Accuracy: 0.476
# Epoch 51, CIFAR-10 Batch 1:  Cost: 1.03, Accuracy: 0.480
# Epoch 52, CIFAR-10 Batch 1:  Cost: 1.02, Accuracy: 0.473
# Epoch 53, CIFAR-10 Batch 1:  Cost: 1.01, Accuracy: 0.481
# Epoch 54, CIFAR-10 Batch 1:  Cost: 1.01, Accuracy: 0.478
# Epoch 55, CIFAR-10 Batch 1:  Cost: 0.99, Accuracy: 0.485
# Epoch 56, CIFAR-10 Batch 1:  Cost: 0.97, Accuracy: 0.482
# Epoch 57, CIFAR-10 Batch 1:  Cost: 0.96, Accuracy: 0.483
# Epoch 58, CIFAR-10 Batch 1:  Cost: 0.96, Accuracy: 0.481
# Epoch 59, CIFAR-10 Batch 1:  Cost: 0.93, Accuracy: 0.483
# Epoch 60, CIFAR-10 Batch 1:  Cost: 0.93, Accuracy: 0.485
# Epoch 61, CIFAR-10 Batch 1:  Cost: 0.91, Accuracy: 0.492
# Epoch 62, CIFAR-10 Batch 1:  Cost: 0.91, Accuracy: 0.490
# Epoch 63, CIFAR-10 Batch 1:  Cost: 0.93, Accuracy: 0.487
# Epoch 64, CIFAR-10 Batch 1:  Cost: 0.91, Accuracy: 0.498
# Epoch 65, CIFAR-10 Batch 1:  Cost: 0.87, Accuracy: 0.490
# Epoch 66, CIFAR-10 Batch 1:  Cost: 0.87, Accuracy: 0.489
# Epoch 67, CIFAR-10 Batch 1:  Cost: 0.86, Accuracy: 0.487
# Epoch 68, CIFAR-10 Batch 1:  Cost: 0.85, Accuracy: 0.498
# Epoch 69, CIFAR-10 Batch 1:  Cost: 0.83, Accuracy: 0.501
# Epoch 70, CIFAR-10 Batch 1:  Cost: 0.83, Accuracy: 0.494
# Epoch 71, CIFAR-10 Batch 1:  Cost: 0.82, Accuracy: 0.496
# Epoch 72, CIFAR-10 Batch 1:  Cost: 0.80, Accuracy: 0.500
# Epoch 73, CIFAR-10 Batch 1:  Cost: 0.79, Accuracy: 0.502
# Epoch 74, CIFAR-10 Batch 1:  Cost: 0.79, Accuracy: 0.501
# Epoch 75, CIFAR-10 Batch 1:  Cost: 0.77, Accuracy: 0.499
# Epoch 76, CIFAR-10 Batch 1:  Cost: 0.77, Accuracy: 0.500
# Epoch 77, CIFAR-10 Batch 1:  Cost: 0.76, Accuracy: 0.504
# Epoch 78, CIFAR-10 Batch 1:  Cost: 0.75, Accuracy: 0.505
# Epoch 79, CIFAR-10 Batch 1:  Cost: 0.75, Accuracy: 0.506
# Epoch 80, CIFAR-10 Batch 1:  Cost: 0.74, Accuracy: 0.502
# Epoch 81, CIFAR-10 Batch 1:  Cost: 0.72, Accuracy: 0.503
# Epoch 82, CIFAR-10 Batch 1:  Cost: 0.76, Accuracy: 0.499
# Epoch 83, CIFAR-10 Batch 1:  Cost: 0.72, Accuracy: 0.501
# Epoch 84, CIFAR-10 Batch 1:  Cost: 0.70, Accuracy: 0.507
# Epoch 85, CIFAR-10 Batch 1:  Cost: 0.70, Accuracy: 0.507
# Epoch 86, CIFAR-10 Batch 1:  Cost: 0.68, Accuracy: 0.509
# Epoch 87, CIFAR-10 Batch 1:  Cost: 0.69, Accuracy: 0.499
# Epoch 88, CIFAR-10 Batch 1:  Cost: 0.67, Accuracy: 0.507
# Epoch 89, CIFAR-10 Batch 1:  Cost: 0.66, Accuracy: 0.512
# Epoch 90, CIFAR-10 Batch 1:  Cost: 0.65, Accuracy: 0.513
# Epoch 91, CIFAR-10 Batch 1:  Cost: 0.64, Accuracy: 0.512
# Epoch 92, CIFAR-10 Batch 1:  Cost: 0.64, Accuracy: 0.515
# Epoch 93, CIFAR-10 Batch 1:  Cost: 0.64, Accuracy: 0.513
# Epoch 94, CIFAR-10 Batch 1:  Cost: 0.63, Accuracy: 0.509
# Epoch 95, CIFAR-10 Batch 1:  Cost: 0.63, Accuracy: 0.503
# Epoch 96, CIFAR-10 Batch 1:  Cost: 0.61, Accuracy: 0.510
# Epoch 97, CIFAR-10 Batch 1:  Cost: 0.60, Accuracy: 0.513
# Epoch 98, CIFAR-10 Batch 1:  Cost: 0.60, Accuracy: 0.507
# Epoch 99, CIFAR-10 Batch 1:  Cost: 0.59, Accuracy: 0.514
# Epoch 100, CIFAR-10 Batch 1:  Cost: 0.57, Accuracy: 0.516
# Epoch 101, CIFAR-10 Batch 1:  Cost: 0.58, Accuracy: 0.509
# Epoch 102, CIFAR-10 Batch 1:  Cost: 0.56, Accuracy: 0.518
# Epoch 103, CIFAR-10 Batch 1:  Cost: 0.56, Accuracy: 0.513
# Epoch 104, CIFAR-10 Batch 1:  Cost: 0.56, Accuracy: 0.514
# Epoch 105, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.516
# Epoch 106, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.512
# Epoch 107, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.515
# Epoch 108, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.512
# Epoch 109, CIFAR-10 Batch 1:  Cost: 0.53, Accuracy: 0.516
# Epoch 110, CIFAR-10 Batch 1:  Cost: 0.52, Accuracy: 0.513
# Epoch 111, CIFAR-10 Batch 1:  Cost: 0.52, Accuracy: 0.517
# Epoch 112, CIFAR-10 Batch 1:  Cost: 0.52, Accuracy: 0.515
# Epoch 113, CIFAR-10 Batch 1:  Cost: 0.52, Accuracy: 0.511
# Epoch 114, CIFAR-10 Batch 1:  Cost: 0.51, Accuracy: 0.518
# Epoch 115, CIFAR-10 Batch 1:  Cost: 0.50, Accuracy: 0.521
# Epoch 116, CIFAR-10 Batch 1:  Cost: 0.49, Accuracy: 0.513
# Epoch 117, CIFAR-10 Batch 1:  Cost: 0.48, Accuracy: 0.522
# Epoch 118, CIFAR-10 Batch 1:  Cost: 0.48, Accuracy: 0.524
# Epoch 119, CIFAR-10 Batch 1:  Cost: 0.48, Accuracy: 0.517
# Epoch 120, CIFAR-10 Batch 1:  Cost: 0.49, Accuracy: 0.515
# Epoch 121, CIFAR-10 Batch 1:  Cost: 0.50, Accuracy: 0.517
# Epoch 122, CIFAR-10 Batch 1:  Cost: 0.47, Accuracy: 0.515
# Epoch 123, CIFAR-10 Batch 1:  Cost: 0.47, Accuracy: 0.522
# Epoch 124, CIFAR-10 Batch 1:  Cost: 0.47, Accuracy: 0.518
# Epoch 125, CIFAR-10 Batch 1:  Cost: 0.44, Accuracy: 0.517
# Epoch 126, CIFAR-10 Batch 1:  Cost: 0.44, Accuracy: 0.520
# Epoch 127, CIFAR-10 Batch 1:  Cost: 0.46, Accuracy: 0.523
# Epoch 128, CIFAR-10 Batch 1:  Cost: 0.44, Accuracy: 0.517
# Epoch 129, CIFAR-10 Batch 1:  Cost: 0.42, Accuracy: 0.520
# Epoch 130, CIFAR-10 Batch 1:  Cost: 0.43, Accuracy: 0.517
# Epoch 131, CIFAR-10 Batch 1:  Cost: 0.42, Accuracy: 0.523
# Epoch 132, CIFAR-10 Batch 1:  Cost: 0.41, Accuracy: 0.525
# Epoch 133, CIFAR-10 Batch 1:  Cost: 0.41, Accuracy: 0.523
# Epoch 134, CIFAR-10 Batch 1:  Cost: 0.40, Accuracy: 0.522
# Epoch 135, CIFAR-10 Batch 1:  Cost: 0.40, Accuracy: 0.529
# Epoch 136, CIFAR-10 Batch 1:  Cost: 0.40, Accuracy: 0.527
# Epoch 137, CIFAR-10 Batch 1:  Cost: 0.39, Accuracy: 0.521
# Epoch 138, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.527
# Epoch 139, CIFAR-10 Batch 1:  Cost: 0.39, Accuracy: 0.528
# Epoch 140, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.526
# Epoch 141, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.524
# Epoch 142, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.528
# Epoch 143, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.528
# Epoch 144, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.523
# Epoch 145, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.516
# Epoch 146, CIFAR-10 Batch 1:  Cost: 0.39, Accuracy: 0.517
# Epoch 147, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.521
# Epoch 148, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.515
# Epoch 149, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.525
# Epoch 150, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.524
# Epoch 151, CIFAR-10 Batch 1:  Cost: 0.35, Accuracy: 0.529
# Epoch 152, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.517
# Epoch 153, CIFAR-10 Batch 1:  Cost: 0.35, Accuracy: 0.518
# Epoch 154, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.519
# Epoch 155, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.523
# Epoch 156, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.527
# Epoch 157, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.528
# Epoch 158, CIFAR-10 Batch 1:  Cost: 0.33, Accuracy: 0.531
# Epoch 159, CIFAR-10 Batch 1:  Cost: 0.31, Accuracy: 0.531
# Epoch 160, CIFAR-10 Batch 1:  Cost: 0.31, Accuracy: 0.525
# Epoch 161, CIFAR-10 Batch 1:  Cost: 0.32, Accuracy: 0.522
# Epoch 162, CIFAR-10 Batch 1:  Cost: 0.31, Accuracy: 0.525
# Epoch 163, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.529
# Epoch 164, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.531
# Epoch 165, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.531
# Epoch 166, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.532
# Epoch 167, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.530
# Epoch 168, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.528
# Epoch 169, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.529
# Epoch 170, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.526
# Epoch 171, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.523
# Epoch 172, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.525
# Epoch 173, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.530
# Epoch 174, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.529
# Epoch 175, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.532
# Epoch 176, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.524
# Epoch 177, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.523
# Epoch 178, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.528
# Epoch 179, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.527
# Epoch 180, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.532
# Epoch 181, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.530
# Epoch 182, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.527
# Epoch 183, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.533
# Epoch 184, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.536
# Epoch 185, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.529
# Epoch 186, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.533
# Epoch 187, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.530
# Epoch 188, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.534
# Epoch 189, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.533
# Epoch 190, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.532
# Epoch 191, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.531
# Epoch 192, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.533
# Epoch 193, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.529
# Epoch 194, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.521
# Epoch 195, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.526
# Epoch 196, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.524
# Epoch 197, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.523
# Epoch 198, CIFAR-10 Batch 1:  Cost: 0.24, Accuracy: 0.532
# Epoch 199, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.529
# Epoch 200, CIFAR-10 Batch 1:  Cost: 0.24, Accuracy: 0.529

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.58, Accuracy: 0.121
# Epoch  1, CIFAR-10 Batch 2:  Cost: 2.29, Accuracy: 0.152
# Epoch  1, CIFAR-10 Batch 3:  Cost: 2.26, Accuracy: 0.178
# Epoch  1, CIFAR-10 Batch 4:  Cost: 2.22, Accuracy: 0.177
# Epoch  1, CIFAR-10 Batch 5:  Cost: 2.22, Accuracy: 0.207
# Epoch  2, CIFAR-10 Batch 1:  Cost: 2.20, Accuracy: 0.213
# Epoch  2, CIFAR-10 Batch 2:  Cost: 2.17, Accuracy: 0.219
# Epoch  2, CIFAR-10 Batch 3:  Cost: 2.16, Accuracy: 0.238
# Epoch  2, CIFAR-10 Batch 4:  Cost: 2.09, Accuracy: 0.242
# Epoch  2, CIFAR-10 Batch 5:  Cost: 2.05, Accuracy: 0.259
# Epoch  3, CIFAR-10 Batch 1:  Cost: 2.01, Accuracy: 0.279
# Epoch  3, CIFAR-10 Batch 2:  Cost: 1.95, Accuracy: 0.307
# Epoch  3, CIFAR-10 Batch 3:  Cost: 1.92, Accuracy: 0.317
# Epoch  3, CIFAR-10 Batch 4:  Cost: 1.87, Accuracy: 0.329
# Epoch  3, CIFAR-10 Batch 5:  Cost: 1.87, Accuracy: 0.337
# Epoch  4, CIFAR-10 Batch 1:  Cost: 1.82, Accuracy: 0.351
# Epoch  4, CIFAR-10 Batch 2:  Cost: 1.79, Accuracy: 0.359
# Epoch  4, CIFAR-10 Batch 3:  Cost: 1.75, Accuracy: 0.366
# Epoch  4, CIFAR-10 Batch 4:  Cost: 1.72, Accuracy: 0.379
# Epoch  4, CIFAR-10 Batch 5:  Cost: 1.76, Accuracy: 0.385
# Epoch  5, CIFAR-10 Batch 1:  Cost: 1.73, Accuracy: 0.384
# Epoch  5, CIFAR-10 Batch 2:  Cost: 1.70, Accuracy: 0.395
# Epoch  5, CIFAR-10 Batch 3:  Cost: 1.66, Accuracy: 0.401
# Epoch  5, CIFAR-10 Batch 4:  Cost: 1.64, Accuracy: 0.397
# Epoch  5, CIFAR-10 Batch 5:  Cost: 1.68, Accuracy: 0.409
# Epoch  6, CIFAR-10 Batch 1:  Cost: 1.63, Accuracy: 0.412
# Epoch  6, CIFAR-10 Batch 2:  Cost: 1.61, Accuracy: 0.427
# Epoch  6, CIFAR-10 Batch 3:  Cost: 1.57, Accuracy: 0.423
# Epoch  6, CIFAR-10 Batch 4:  Cost: 1.56, Accuracy: 0.422
# Epoch  6, CIFAR-10 Batch 5:  Cost: 1.59, Accuracy: 0.425
# Epoch  7, CIFAR-10 Batch 1:  Cost: 1.57, Accuracy: 0.436
# Epoch  7, CIFAR-10 Batch 2:  Cost: 1.55, Accuracy: 0.433
# Epoch  7, CIFAR-10 Batch 3:  Cost: 1.52, Accuracy: 0.439
# Epoch  7, CIFAR-10 Batch 4:  Cost: 1.50, Accuracy: 0.442
# Epoch  7, CIFAR-10 Batch 5:  Cost: 1.54, Accuracy: 0.434
# Epoch  8, CIFAR-10 Batch 1:  Cost: 1.51, Accuracy: 0.443
# Epoch  8, CIFAR-10 Batch 2:  Cost: 1.50, Accuracy: 0.441
# Epoch  8, CIFAR-10 Batch 3:  Cost: 1.47, Accuracy: 0.454
# Epoch  8, CIFAR-10 Batch 4:  Cost: 1.45, Accuracy: 0.449
# Epoch  8, CIFAR-10 Batch 5:  Cost: 1.49, Accuracy: 0.453
# Epoch  9, CIFAR-10 Batch 1:  Cost: 1.47, Accuracy: 0.451
# Epoch  9, CIFAR-10 Batch 2:  Cost: 1.46, Accuracy: 0.453
# Epoch  9, CIFAR-10 Batch 3:  Cost: 1.43, Accuracy: 0.460
# Epoch  9, CIFAR-10 Batch 4:  Cost: 1.41, Accuracy: 0.461
# Epoch  9, CIFAR-10 Batch 5:  Cost: 1.46, Accuracy: 0.464
# Epoch 10, CIFAR-10 Batch 1:  Cost: 1.44, Accuracy: 0.469
# Epoch 10, CIFAR-10 Batch 2:  Cost: 1.43, Accuracy: 0.455
# Epoch 10, CIFAR-10 Batch 3:  Cost: 1.41, Accuracy: 0.461
# Epoch 10, CIFAR-10 Batch 4:  Cost: 1.39, Accuracy: 0.467
# Epoch 10, CIFAR-10 Batch 5:  Cost: 1.42, Accuracy: 0.479
# Epoch 11, CIFAR-10 Batch 1:  Cost: 1.37, Accuracy: 0.477
# Epoch 11, CIFAR-10 Batch 2:  Cost: 1.37, Accuracy: 0.477
# Epoch 11, CIFAR-10 Batch 3:  Cost: 1.35, Accuracy: 0.476
# Epoch 11, CIFAR-10 Batch 4:  Cost: 1.36, Accuracy: 0.475
# Epoch 11, CIFAR-10 Batch 5:  Cost: 1.40, Accuracy: 0.487
# Epoch 12, CIFAR-10 Batch 1:  Cost: 1.35, Accuracy: 0.485
# Epoch 12, CIFAR-10 Batch 2:  Cost: 1.33, Accuracy: 0.488
# Epoch 12, CIFAR-10 Batch 3:  Cost: 1.29, Accuracy: 0.494
# Epoch 12, CIFAR-10 Batch 4:  Cost: 1.29, Accuracy: 0.493
# Epoch 12, CIFAR-10 Batch 5:  Cost: 1.34, Accuracy: 0.495
# Epoch 13, CIFAR-10 Batch 1:  Cost: 1.32, Accuracy: 0.500
# Epoch 13, CIFAR-10 Batch 2:  Cost: 1.29, Accuracy: 0.497
# Epoch 13, CIFAR-10 Batch 3:  Cost: 1.26, Accuracy: 0.499
# Epoch 13, CIFAR-10 Batch 4:  Cost: 1.27, Accuracy: 0.497
# Epoch 13, CIFAR-10 Batch 5:  Cost: 1.30, Accuracy: 0.501
# Epoch 14, CIFAR-10 Batch 1:  Cost: 1.29, Accuracy: 0.501
# Epoch 14, CIFAR-10 Batch 2:  Cost: 1.26, Accuracy: 0.503
# Epoch 14, CIFAR-10 Batch 3:  Cost: 1.23, Accuracy: 0.507
# Epoch 14, CIFAR-10 Batch 4:  Cost: 1.24, Accuracy: 0.507
# Epoch 14, CIFAR-10 Batch 5:  Cost: 1.26, Accuracy: 0.511
# Epoch 15, CIFAR-10 Batch 1:  Cost: 1.26, Accuracy: 0.506
# Epoch 15, CIFAR-10 Batch 2:  Cost: 1.25, Accuracy: 0.504
# Epoch 15, CIFAR-10 Batch 3:  Cost: 1.22, Accuracy: 0.507
# Epoch 15, CIFAR-10 Batch 4:  Cost: 1.20, Accuracy: 0.511
# Epoch 15, CIFAR-10 Batch 5:  Cost: 1.24, Accuracy: 0.504
# Epoch 16, CIFAR-10 Batch 1:  Cost: 1.23, Accuracy: 0.518
# Epoch 16, CIFAR-10 Batch 2:  Cost: 1.23, Accuracy: 0.512
# Epoch 16, CIFAR-10 Batch 3:  Cost: 1.20, Accuracy: 0.513
# Epoch 16, CIFAR-10 Batch 4:  Cost: 1.18, Accuracy: 0.515
# Epoch 16, CIFAR-10 Batch 5:  Cost: 1.21, Accuracy: 0.517
# Epoch 17, CIFAR-10 Batch 1:  Cost: 1.21, Accuracy: 0.520
# Epoch 17, CIFAR-10 Batch 2:  Cost: 1.21, Accuracy: 0.516
# Epoch 17, CIFAR-10 Batch 3:  Cost: 1.16, Accuracy: 0.518
# Epoch 17, CIFAR-10 Batch 4:  Cost: 1.17, Accuracy: 0.515
# Epoch 17, CIFAR-10 Batch 5:  Cost: 1.18, Accuracy: 0.524
# Epoch 18, CIFAR-10 Batch 1:  Cost: 1.18, Accuracy: 0.524
# Epoch 18, CIFAR-10 Batch 2:  Cost: 1.17, Accuracy: 0.523
# Epoch 18, CIFAR-10 Batch 3:  Cost: 1.14, Accuracy: 0.519
# Epoch 18, CIFAR-10 Batch 4:  Cost: 1.15, Accuracy: 0.521
# Epoch 18, CIFAR-10 Batch 5:  Cost: 1.16, Accuracy: 0.528
# Epoch 19, CIFAR-10 Batch 1:  Cost: 1.16, Accuracy: 0.530
# Epoch 19, CIFAR-10 Batch 2:  Cost: 1.14, Accuracy: 0.528
# Epoch 19, CIFAR-10 Batch 3:  Cost: 1.12, Accuracy: 0.529
# Epoch 19, CIFAR-10 Batch 4:  Cost: 1.13, Accuracy: 0.524
# Epoch 19, CIFAR-10 Batch 5:  Cost: 1.13, Accuracy: 0.536
# Epoch 20, CIFAR-10 Batch 1:  Cost: 1.12, Accuracy: 0.534
# Epoch 20, CIFAR-10 Batch 2:  Cost: 1.13, Accuracy: 0.530
# Epoch 20, CIFAR-10 Batch 3:  Cost: 1.10, Accuracy: 0.532
# Epoch 20, CIFAR-10 Batch 4:  Cost: 1.10, Accuracy: 0.519
# Epoch 20, CIFAR-10 Batch 5:  Cost: 1.13, Accuracy: 0.529
# Epoch 21, CIFAR-10 Batch 1:  Cost: 1.14, Accuracy: 0.530
# Epoch 21, CIFAR-10 Batch 2:  Cost: 1.11, Accuracy: 0.534
# Epoch 21, CIFAR-10 Batch 3:  Cost: 1.07, Accuracy: 0.536
# Epoch 21, CIFAR-10 Batch 4:  Cost: 1.07, Accuracy: 0.536
# Epoch 21, CIFAR-10 Batch 5:  Cost: 1.08, Accuracy: 0.543
# Epoch 22, CIFAR-10 Batch 1:  Cost: 1.09, Accuracy: 0.533
# Epoch 22, CIFAR-10 Batch 2:  Cost: 1.09, Accuracy: 0.542
# Epoch 22, CIFAR-10 Batch 3:  Cost: 1.05, Accuracy: 0.544
# Epoch 22, CIFAR-10 Batch 4:  Cost: 1.05, Accuracy: 0.535
# Epoch 22, CIFAR-10 Batch 5:  Cost: 1.06, Accuracy: 0.539
# Epoch 23, CIFAR-10 Batch 1:  Cost: 1.07, Accuracy: 0.536
# Epoch 23, CIFAR-10 Batch 2:  Cost: 1.08, Accuracy: 0.541
# Epoch 23, CIFAR-10 Batch 3:  Cost: 1.02, Accuracy: 0.541
# Epoch 23, CIFAR-10 Batch 4:  Cost: 1.03, Accuracy: 0.542
# Epoch 23, CIFAR-10 Batch 5:  Cost: 1.06, Accuracy: 0.539
# Epoch 24, CIFAR-10 Batch 1:  Cost: 1.05, Accuracy: 0.543
# Epoch 24, CIFAR-10 Batch 2:  Cost: 1.05, Accuracy: 0.545
# Epoch 24, CIFAR-10 Batch 3:  Cost: 1.00, Accuracy: 0.547
# Epoch 24, CIFAR-10 Batch 4:  Cost: 1.02, Accuracy: 0.540
# Epoch 24, CIFAR-10 Batch 5:  Cost: 1.03, Accuracy: 0.548
# Epoch 25, CIFAR-10 Batch 1:  Cost: 1.03, Accuracy: 0.548
# Epoch 25, CIFAR-10 Batch 2:  Cost: 1.02, Accuracy: 0.548
# Epoch 25, CIFAR-10 Batch 3:  Cost: 0.99, Accuracy: 0.551
# Epoch 25, CIFAR-10 Batch 4:  Cost: 1.00, Accuracy: 0.547
# Epoch 25, CIFAR-10 Batch 5:  Cost: 1.00, Accuracy: 0.547
# Epoch 26, CIFAR-10 Batch 1:  Cost: 1.01, Accuracy: 0.546
# Epoch 26, CIFAR-10 Batch 2:  Cost: 1.03, Accuracy: 0.555
# Epoch 26, CIFAR-10 Batch 3:  Cost: 0.97, Accuracy: 0.554
# Epoch 26, CIFAR-10 Batch 4:  Cost: 0.99, Accuracy: 0.539
# Epoch 26, CIFAR-10 Batch 5:  Cost: 1.00, Accuracy: 0.546
# Epoch 27, CIFAR-10 Batch 1:  Cost: 1.02, Accuracy: 0.549
# Epoch 27, CIFAR-10 Batch 2:  Cost: 1.00, Accuracy: 0.550
# Epoch 27, CIFAR-10 Batch 3:  Cost: 0.97, Accuracy: 0.552
# Epoch 27, CIFAR-10 Batch 4:  Cost: 0.96, Accuracy: 0.556
# Epoch 27, CIFAR-10 Batch 5:  Cost: 0.97, Accuracy: 0.557
# Epoch 28, CIFAR-10 Batch 1:  Cost: 1.00, Accuracy: 0.545
# Epoch 28, CIFAR-10 Batch 2:  Cost: 1.00, Accuracy: 0.555
# Epoch 28, CIFAR-10 Batch 3:  Cost: 0.96, Accuracy: 0.552
# Epoch 28, CIFAR-10 Batch 4:  Cost: 0.94, Accuracy: 0.559
# Epoch 28, CIFAR-10 Batch 5:  Cost: 0.96, Accuracy: 0.556
# Epoch 29, CIFAR-10 Batch 1:  Cost: 0.96, Accuracy: 0.556
# Epoch 29, CIFAR-10 Batch 2:  Cost: 0.97, Accuracy: 0.559
# Epoch 29, CIFAR-10 Batch 3:  Cost: 0.92, Accuracy: 0.564
# Epoch 29, CIFAR-10 Batch 4:  Cost: 0.92, Accuracy: 0.556
# Epoch 29, CIFAR-10 Batch 5:  Cost: 0.93, Accuracy: 0.561
# Epoch 30, CIFAR-10 Batch 1:  Cost: 0.94, Accuracy: 0.562
# Epoch 30, CIFAR-10 Batch 2:  Cost: 0.95, Accuracy: 0.557
# Epoch 30, CIFAR-10 Batch 3:  Cost: 0.91, Accuracy: 0.565
# Epoch 30, CIFAR-10 Batch 4:  Cost: 0.90, Accuracy: 0.561
# Epoch 30, CIFAR-10 Batch 5:  Cost: 0.92, Accuracy: 0.561
# Epoch 31, CIFAR-10 Batch 1:  Cost: 0.92, Accuracy: 0.565
# Epoch 31, CIFAR-10 Batch 2:  Cost: 0.94, Accuracy: 0.565
# Epoch 31, CIFAR-10 Batch 3:  Cost: 0.90, Accuracy: 0.567
# Epoch 31, CIFAR-10 Batch 4:  Cost: 0.89, Accuracy: 0.563
# Epoch 31, CIFAR-10 Batch 5:  Cost: 0.88, Accuracy: 0.565
# Epoch 32, CIFAR-10 Batch 1:  Cost: 0.91, Accuracy: 0.562
# Epoch 32, CIFAR-10 Batch 2:  Cost: 0.93, Accuracy: 0.567
# Epoch 32, CIFAR-10 Batch 3:  Cost: 0.88, Accuracy: 0.564
# Epoch 32, CIFAR-10 Batch 4:  Cost: 0.87, Accuracy: 0.566
# Epoch 32, CIFAR-10 Batch 5:  Cost: 0.88, Accuracy: 0.566
# Epoch 33, CIFAR-10 Batch 1:  Cost: 0.90, Accuracy: 0.567
# Epoch 33, CIFAR-10 Batch 2:  Cost: 0.92, Accuracy: 0.561
# Epoch 33, CIFAR-10 Batch 3:  Cost: 0.87, Accuracy: 0.563
# Epoch 33, CIFAR-10 Batch 4:  Cost: 0.87, Accuracy: 0.568
# Epoch 33, CIFAR-10 Batch 5:  Cost: 0.87, Accuracy: 0.563
# Epoch 34, CIFAR-10 Batch 1:  Cost: 0.87, Accuracy: 0.569
# Epoch 34, CIFAR-10 Batch 2:  Cost: 0.89, Accuracy: 0.566
# Epoch 34, CIFAR-10 Batch 3:  Cost: 0.86, Accuracy: 0.566
# Epoch 34, CIFAR-10 Batch 4:  Cost: 0.85, Accuracy: 0.565
# Epoch 34, CIFAR-10 Batch 5:  Cost: 0.86, Accuracy: 0.560
# Epoch 35, CIFAR-10 Batch 1:  Cost: 0.88, Accuracy: 0.565
# Epoch 35, CIFAR-10 Batch 2:  Cost: 0.89, Accuracy: 0.564
# Epoch 35, CIFAR-10 Batch 3:  Cost: 0.83, Accuracy: 0.571
# Epoch 35, CIFAR-10 Batch 4:  Cost: 0.85, Accuracy: 0.567
# Epoch 35, CIFAR-10 Batch 5:  Cost: 0.83, Accuracy: 0.574
# Epoch 36, CIFAR-10 Batch 1:  Cost: 0.85, Accuracy: 0.569
# Epoch 36, CIFAR-10 Batch 2:  Cost: 0.87, Accuracy: 0.568
# Epoch 36, CIFAR-10 Batch 3:  Cost: 0.83, Accuracy: 0.570
# Epoch 36, CIFAR-10 Batch 4:  Cost: 0.82, Accuracy: 0.572
# Epoch 36, CIFAR-10 Batch 5:  Cost: 0.82, Accuracy: 0.573
# Epoch 37, CIFAR-10 Batch 1:  Cost: 0.85, Accuracy: 0.570
# Epoch 37, CIFAR-10 Batch 2:  Cost: 0.87, Accuracy: 0.565
# Epoch 37, CIFAR-10 Batch 3:  Cost: 0.81, Accuracy: 0.576
# Epoch 37, CIFAR-10 Batch 4:  Cost: 0.81, Accuracy: 0.570
# Epoch 37, CIFAR-10 Batch 5:  Cost: 0.81, Accuracy: 0.571
# Epoch 38, CIFAR-10 Batch 1:  Cost: 0.84, Accuracy: 0.574
# Epoch 38, CIFAR-10 Batch 2:  Cost: 0.85, Accuracy: 0.574
# Epoch 38, CIFAR-10 Batch 3:  Cost: 0.80, Accuracy: 0.577
# Epoch 38, CIFAR-10 Batch 4:  Cost: 0.80, Accuracy: 0.576
# Epoch 38, CIFAR-10 Batch 5:  Cost: 0.79, Accuracy: 0.579
# Epoch 39, CIFAR-10 Batch 1:  Cost: 0.81, Accuracy: 0.580
# Epoch 39, CIFAR-10 Batch 2:  Cost: 0.82, Accuracy: 0.575
# Epoch 39, CIFAR-10 Batch 3:  Cost: 0.79, Accuracy: 0.576
# Epoch 39, CIFAR-10 Batch 4:  Cost: 0.79, Accuracy: 0.573
# Epoch 39, CIFAR-10 Batch 5:  Cost: 0.78, Accuracy: 0.580
# Epoch 40, CIFAR-10 Batch 1:  Cost: 0.80, Accuracy: 0.577
# Epoch 40, CIFAR-10 Batch 2:  Cost: 0.81, Accuracy: 0.579
# Epoch 40, CIFAR-10 Batch 3:  Cost: 0.78, Accuracy: 0.582
# Epoch 40, CIFAR-10 Batch 4:  Cost: 0.77, Accuracy: 0.580
# Epoch 40, CIFAR-10 Batch 5:  Cost: 0.77, Accuracy: 0.577
# Epoch 41, CIFAR-10 Batch 1:  Cost: 0.78, Accuracy: 0.585
# Epoch 41, CIFAR-10 Batch 2:  Cost: 0.80, Accuracy: 0.581
# Epoch 41, CIFAR-10 Batch 3:  Cost: 0.77, Accuracy: 0.583
# Epoch 41, CIFAR-10 Batch 4:  Cost: 0.75, Accuracy: 0.578
# Epoch 41, CIFAR-10 Batch 5:  Cost: 0.76, Accuracy: 0.578
# Epoch 42, CIFAR-10 Batch 1:  Cost: 0.77, Accuracy: 0.583
# Epoch 42, CIFAR-10 Batch 2:  Cost: 0.79, Accuracy: 0.584
# Epoch 42, CIFAR-10 Batch 3:  Cost: 0.76, Accuracy: 0.588
# Epoch 42, CIFAR-10 Batch 4:  Cost: 0.75, Accuracy: 0.584
# Epoch 42, CIFAR-10 Batch 5:  Cost: 0.74, Accuracy: 0.585
# Epoch 43, CIFAR-10 Batch 1:  Cost: 0.76, Accuracy: 0.588
# Epoch 43, CIFAR-10 Batch 2:  Cost: 0.77, Accuracy: 0.584
# Epoch 43, CIFAR-10 Batch 3:  Cost: 0.74, Accuracy: 0.589
# Epoch 43, CIFAR-10 Batch 4:  Cost: 0.74, Accuracy: 0.584
# Epoch 43, CIFAR-10 Batch 5:  Cost: 0.74, Accuracy: 0.583
# Epoch 44, CIFAR-10 Batch 1:  Cost: 0.75, Accuracy: 0.588
# Epoch 44, CIFAR-10 Batch 2:  Cost: 0.75, Accuracy: 0.584
# Epoch 44, CIFAR-10 Batch 3:  Cost: 0.73, Accuracy: 0.590
# Epoch 44, CIFAR-10 Batch 4:  Cost: 0.72, Accuracy: 0.588
# Epoch 44, CIFAR-10 Batch 5:  Cost: 0.73, Accuracy: 0.588
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.74, Accuracy: 0.589
# Epoch 45, CIFAR-10 Batch 2:  Cost: 0.75, Accuracy: 0.587
# Epoch 45, CIFAR-10 Batch 3:  Cost: 0.72, Accuracy: 0.586
# Epoch 45, CIFAR-10 Batch 4:  Cost: 0.71, Accuracy: 0.582
# Epoch 45, CIFAR-10 Batch 5:  Cost: 0.72, Accuracy: 0.584
# Epoch 46, CIFAR-10 Batch 1:  Cost: 0.73, Accuracy: 0.588
# Epoch 46, CIFAR-10 Batch 2:  Cost: 0.74, Accuracy: 0.585
# Epoch 46, CIFAR-10 Batch 3:  Cost: 0.72, Accuracy: 0.585
# Epoch 46, CIFAR-10 Batch 4:  Cost: 0.70, Accuracy: 0.586
# Epoch 46, CIFAR-10 Batch 5:  Cost: 0.70, Accuracy: 0.587
# Epoch 47, CIFAR-10 Batch 1:  Cost: 0.72, Accuracy: 0.589
# Epoch 47, CIFAR-10 Batch 2:  Cost: 0.73, Accuracy: 0.587
# Epoch 47, CIFAR-10 Batch 3:  Cost: 0.69, Accuracy: 0.591
# Epoch 47, CIFAR-10 Batch 4:  Cost: 0.68, Accuracy: 0.592
# Epoch 47, CIFAR-10 Batch 5:  Cost: 0.69, Accuracy: 0.584
# Epoch 48, CIFAR-10 Batch 1:  Cost: 0.71, Accuracy: 0.592
# Epoch 48, CIFAR-10 Batch 2:  Cost: 0.73, Accuracy: 0.583
# Epoch 48, CIFAR-10 Batch 3:  Cost: 0.69, Accuracy: 0.589
# Epoch 48, CIFAR-10 Batch 4:  Cost: 0.68, Accuracy: 0.591
# Epoch 48, CIFAR-10 Batch 5:  Cost: 0.68, Accuracy: 0.591
# Epoch 49, CIFAR-10 Batch 1:  Cost: 0.69, Accuracy: 0.594
# Epoch 49, CIFAR-10 Batch 2:  Cost: 0.71, Accuracy: 0.589
# Epoch 49, CIFAR-10 Batch 3:  Cost: 0.68, Accuracy: 0.591
# Epoch 49, CIFAR-10 Batch 4:  Cost: 0.67, Accuracy: 0.593
# Epoch 49, CIFAR-10 Batch 5:  Cost: 0.65, Accuracy: 0.594
# Epoch 50, CIFAR-10 Batch 1:  Cost: 0.68, Accuracy: 0.591
# Epoch 50, CIFAR-10 Batch 2:  Cost: 0.69, Accuracy: 0.594
# Epoch 50, CIFAR-10 Batch 3:  Cost: 0.67, Accuracy: 0.592
# Epoch 50, CIFAR-10 Batch 4:  Cost: 0.66, Accuracy: 0.590
# Epoch 50, CIFAR-10 Batch 5:  Cost: 0.65, Accuracy: 0.593
# Epoch 51, CIFAR-10 Batch 1:  Cost: 0.67, Accuracy: 0.595
# Epoch 51, CIFAR-10 Batch 2:  Cost: 0.70, Accuracy: 0.589
# Epoch 51, CIFAR-10 Batch 3:  Cost: 0.66, Accuracy: 0.594
# Epoch 51, CIFAR-10 Batch 4:  Cost: 0.64, Accuracy: 0.592
# Epoch 51, CIFAR-10 Batch 5:  Cost: 0.65, Accuracy: 0.592
# Epoch 52, CIFAR-10 Batch 1:  Cost: 0.66, Accuracy: 0.593
# Epoch 52, CIFAR-10 Batch 2:  Cost: 0.69, Accuracy: 0.590
# Epoch 52, CIFAR-10 Batch 3:  Cost: 0.66, Accuracy: 0.594
# Epoch 52, CIFAR-10 Batch 4:  Cost: 0.64, Accuracy: 0.593
# Epoch 52, CIFAR-10 Batch 5:  Cost: 0.65, Accuracy: 0.585
# Epoch 53, CIFAR-10 Batch 1:  Cost: 0.67, Accuracy: 0.595
# Epoch 53, CIFAR-10 Batch 2:  Cost: 0.67, Accuracy: 0.595
# Epoch 53, CIFAR-10 Batch 3:  Cost: 0.65, Accuracy: 0.593
# Epoch 53, CIFAR-10 Batch 4:  Cost: 0.63, Accuracy: 0.593
# Epoch 53, CIFAR-10 Batch 5:  Cost: 0.65, Accuracy: 0.582
# Epoch 54, CIFAR-10 Batch 1:  Cost: 0.66, Accuracy: 0.596
# Epoch 54, CIFAR-10 Batch 2:  Cost: 0.67, Accuracy: 0.594
# Epoch 54, CIFAR-10 Batch 3:  Cost: 0.68, Accuracy: 0.586
# Epoch 54, CIFAR-10 Batch 4:  Cost: 0.65, Accuracy: 0.588
# Epoch 54, CIFAR-10 Batch 5:  Cost: 0.63, Accuracy: 0.594
# Epoch 55, CIFAR-10 Batch 1:  Cost: 0.66, Accuracy: 0.588
# Epoch 55, CIFAR-10 Batch 2:  Cost: 0.67, Accuracy: 0.596
# Epoch 55, CIFAR-10 Batch 3:  Cost: 0.63, Accuracy: 0.596
# Epoch 55, CIFAR-10 Batch 4:  Cost: 0.63, Accuracy: 0.595
# Epoch 55, CIFAR-10 Batch 5:  Cost: 0.61, Accuracy: 0.599
# Epoch 56, CIFAR-10 Batch 1:  Cost: 0.62, Accuracy: 0.603
# Epoch 56, CIFAR-10 Batch 2:  Cost: 0.65, Accuracy: 0.608
# Epoch 56, CIFAR-10 Batch 3:  Cost: 0.61, Accuracy: 0.597
# Epoch 56, CIFAR-10 Batch 4:  Cost: 0.61, Accuracy: 0.594
# Epoch 56, CIFAR-10 Batch 5:  Cost: 0.60, Accuracy: 0.599
# Epoch 57, CIFAR-10 Batch 1:  Cost: 0.61, Accuracy: 0.601
# Epoch 57, CIFAR-10 Batch 2:  Cost: 0.64, Accuracy: 0.602
# Epoch 57, CIFAR-10 Batch 3:  Cost: 0.60, Accuracy: 0.600
# Epoch 57, CIFAR-10 Batch 4:  Cost: 0.62, Accuracy: 0.596
# Epoch 57, CIFAR-10 Batch 5:  Cost: 0.60, Accuracy: 0.598
# Epoch 58, CIFAR-10 Batch 1:  Cost: 0.63, Accuracy: 0.597
# Epoch 58, CIFAR-10 Batch 2:  Cost: 0.62, Accuracy: 0.599
# Epoch 58, CIFAR-10 Batch 3:  Cost: 0.60, Accuracy: 0.597
# Epoch 58, CIFAR-10 Batch 4:  Cost: 0.60, Accuracy: 0.598
# Epoch 58, CIFAR-10 Batch 5:  Cost: 0.59, Accuracy: 0.595
# Epoch 59, CIFAR-10 Batch 1:  Cost: 0.60, Accuracy: 0.598
# Epoch 59, CIFAR-10 Batch 2:  Cost: 0.62, Accuracy: 0.596
# Epoch 59, CIFAR-10 Batch 3:  Cost: 0.59, Accuracy: 0.599
# Epoch 59, CIFAR-10 Batch 4:  Cost: 0.58, Accuracy: 0.602
# Epoch 59, CIFAR-10 Batch 5:  Cost: 0.57, Accuracy: 0.596
# Epoch 60, CIFAR-10 Batch 1:  Cost: 0.60, Accuracy: 0.603
# Epoch 60, CIFAR-10 Batch 2:  Cost: 0.61, Accuracy: 0.601
# Epoch 60, CIFAR-10 Batch 3:  Cost: 0.58, Accuracy: 0.597
# Epoch 60, CIFAR-10 Batch 4:  Cost: 0.56, Accuracy: 0.597
# Epoch 60, CIFAR-10 Batch 5:  Cost: 0.56, Accuracy: 0.596
# Epoch 61, CIFAR-10 Batch 1:  Cost: 0.57, Accuracy: 0.599
# Epoch 61, CIFAR-10 Batch 2:  Cost: 0.59, Accuracy: 0.603
# Epoch 61, CIFAR-10 Batch 3:  Cost: 0.57, Accuracy: 0.599
# Epoch 61, CIFAR-10 Batch 4:  Cost: 0.56, Accuracy: 0.608
# Epoch 61, CIFAR-10 Batch 5:  Cost: 0.56, Accuracy: 0.598
# Epoch 62, CIFAR-10 Batch 1:  Cost: 0.59, Accuracy: 0.601
# Epoch 62, CIFAR-10 Batch 2:  Cost: 0.60, Accuracy: 0.602
# Epoch 62, CIFAR-10 Batch 3:  Cost: 0.57, Accuracy: 0.602
# Epoch 62, CIFAR-10 Batch 4:  Cost: 0.57, Accuracy: 0.603
# Epoch 62, CIFAR-10 Batch 5:  Cost: 0.56, Accuracy: 0.598
# Epoch 63, CIFAR-10 Batch 1:  Cost: 0.58, Accuracy: 0.606
# Epoch 63, CIFAR-10 Batch 2:  Cost: 0.59, Accuracy: 0.603
# Epoch 63, CIFAR-10 Batch 3:  Cost: 0.57, Accuracy: 0.608
# Epoch 63, CIFAR-10 Batch 4:  Cost: 0.55, Accuracy: 0.605
# Epoch 63, CIFAR-10 Batch 5:  Cost: 0.56, Accuracy: 0.598
# Epoch 64, CIFAR-10 Batch 1:  Cost: 0.57, Accuracy: 0.604
# Epoch 64, CIFAR-10 Batch 2:  Cost: 0.59, Accuracy: 0.601
# Epoch 64, CIFAR-10 Batch 3:  Cost: 0.55, Accuracy: 0.603
# Epoch 64, CIFAR-10 Batch 4:  Cost: 0.56, Accuracy: 0.605
# Epoch 64, CIFAR-10 Batch 5:  Cost: 0.54, Accuracy: 0.600
# Epoch 65, CIFAR-10 Batch 1:  Cost: 0.57, Accuracy: 0.606
# Epoch 65, CIFAR-10 Batch 2:  Cost: 0.56, Accuracy: 0.600
# Epoch 65, CIFAR-10 Batch 3:  Cost: 0.55, Accuracy: 0.600
# Epoch 65, CIFAR-10 Batch 4:  Cost: 0.54, Accuracy: 0.609
# Epoch 65, CIFAR-10 Batch 5:  Cost: 0.54, Accuracy: 0.600
# Epoch 66, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.611
# Epoch 66, CIFAR-10 Batch 2:  Cost: 0.56, Accuracy: 0.601
# Epoch 66, CIFAR-10 Batch 3:  Cost: 0.54, Accuracy: 0.603
# Epoch 66, CIFAR-10 Batch 4:  Cost: 0.54, Accuracy: 0.610
# Epoch 66, CIFAR-10 Batch 5:  Cost: 0.52, Accuracy: 0.603
# Epoch 67, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.611
# Epoch 67, CIFAR-10 Batch 2:  Cost: 0.56, Accuracy: 0.607
# Epoch 67, CIFAR-10 Batch 3:  Cost: 0.53, Accuracy: 0.605
# Epoch 67, CIFAR-10 Batch 4:  Cost: 0.53, Accuracy: 0.608
# Epoch 67, CIFAR-10 Batch 5:  Cost: 0.52, Accuracy: 0.605
# Epoch 68, CIFAR-10 Batch 1:  Cost: 0.54, Accuracy: 0.606
# Epoch 68, CIFAR-10 Batch 2:  Cost: 0.54, Accuracy: 0.609
# Epoch 68, CIFAR-10 Batch 3:  Cost: 0.53, Accuracy: 0.604
# Epoch 68, CIFAR-10 Batch 4:  Cost: 0.53, Accuracy: 0.613
# Epoch 68, CIFAR-10 Batch 5:  Cost: 0.51, Accuracy: 0.609
# Epoch 69, CIFAR-10 Batch 1:  Cost: 0.55, Accuracy: 0.607
# Epoch 69, CIFAR-10 Batch 2:  Cost: 0.54, Accuracy: 0.604
# Epoch 69, CIFAR-10 Batch 3:  Cost: 0.51, Accuracy: 0.609
# Epoch 69, CIFAR-10 Batch 4:  Cost: 0.51, Accuracy: 0.613
# Epoch 69, CIFAR-10 Batch 5:  Cost: 0.52, Accuracy: 0.596
# Epoch 70, CIFAR-10 Batch 1:  Cost: 0.52, Accuracy: 0.608
# Epoch 70, CIFAR-10 Batch 2:  Cost: 0.54, Accuracy: 0.608
# Epoch 70, CIFAR-10 Batch 3:  Cost: 0.51, Accuracy: 0.606
# Epoch 70, CIFAR-10 Batch 4:  Cost: 0.50, Accuracy: 0.611
# Epoch 70, CIFAR-10 Batch 5:  Cost: 0.49, Accuracy: 0.604
# Epoch 71, CIFAR-10 Batch 1:  Cost: 0.51, Accuracy: 0.604
# Epoch 71, CIFAR-10 Batch 2:  Cost: 0.53, Accuracy: 0.609
# Epoch 71, CIFAR-10 Batch 3:  Cost: 0.52, Accuracy: 0.607
# Epoch 71, CIFAR-10 Batch 4:  Cost: 0.50, Accuracy: 0.611
# Epoch 71, CIFAR-10 Batch 5:  Cost: 0.48, Accuracy: 0.606
# Epoch 72, CIFAR-10 Batch 1:  Cost: 0.50, Accuracy: 0.609
# Epoch 72, CIFAR-10 Batch 2:  Cost: 0.51, Accuracy: 0.610
# Epoch 72, CIFAR-10 Batch 3:  Cost: 0.50, Accuracy: 0.613
# Epoch 72, CIFAR-10 Batch 4:  Cost: 0.49, Accuracy: 0.612
# Epoch 72, CIFAR-10 Batch 5:  Cost: 0.49, Accuracy: 0.603
# Epoch 73, CIFAR-10 Batch 1:  Cost: 0.50, Accuracy: 0.610
# Epoch 73, CIFAR-10 Batch 2:  Cost: 0.52, Accuracy: 0.606
# Epoch 73, CIFAR-10 Batch 3:  Cost: 0.49, Accuracy: 0.612
# Epoch 73, CIFAR-10 Batch 4:  Cost: 0.48, Accuracy: 0.610
# Epoch 73, CIFAR-10 Batch 5:  Cost: 0.49, Accuracy: 0.598
# Epoch 74, CIFAR-10 Batch 1:  Cost: 0.50, Accuracy: 0.612
# Epoch 74, CIFAR-10 Batch 2:  Cost: 0.51, Accuracy: 0.612
# Epoch 74, CIFAR-10 Batch 3:  Cost: 0.49, Accuracy: 0.611
# Epoch 74, CIFAR-10 Batch 4:  Cost: 0.48, Accuracy: 0.612
# Epoch 74, CIFAR-10 Batch 5:  Cost: 0.49, Accuracy: 0.599
# Epoch 75, CIFAR-10 Batch 1:  Cost: 0.49, Accuracy: 0.611
# Epoch 75, CIFAR-10 Batch 2:  Cost: 0.49, Accuracy: 0.610
# Epoch 75, CIFAR-10 Batch 3:  Cost: 0.48, Accuracy: 0.610
# Epoch 75, CIFAR-10 Batch 4:  Cost: 0.48, Accuracy: 0.608
# Epoch 75, CIFAR-10 Batch 5:  Cost: 0.47, Accuracy: 0.604
# Epoch 76, CIFAR-10 Batch 1:  Cost: 0.48, Accuracy: 0.613
# Epoch 76, CIFAR-10 Batch 2:  Cost: 0.50, Accuracy: 0.612
# Epoch 76, CIFAR-10 Batch 3:  Cost: 0.47, Accuracy: 0.610
# Epoch 76, CIFAR-10 Batch 4:  Cost: 0.46, Accuracy: 0.608
# Epoch 76, CIFAR-10 Batch 5:  Cost: 0.46, Accuracy: 0.598
# Epoch 77, CIFAR-10 Batch 1:  Cost: 0.48, Accuracy: 0.613
# Epoch 77, CIFAR-10 Batch 2:  Cost: 0.49, Accuracy: 0.608
# Epoch 77, CIFAR-10 Batch 3:  Cost: 0.47, Accuracy: 0.611
# Epoch 77, CIFAR-10 Batch 4:  Cost: 0.46, Accuracy: 0.614
# Epoch 77, CIFAR-10 Batch 5:  Cost: 0.47, Accuracy: 0.596
# Epoch 78, CIFAR-10 Batch 1:  Cost: 0.51, Accuracy: 0.608
# Epoch 78, CIFAR-10 Batch 2:  Cost: 0.50, Accuracy: 0.601
# Epoch 78, CIFAR-10 Batch 3:  Cost: 0.49, Accuracy: 0.608
# Epoch 78, CIFAR-10 Batch 4:  Cost: 0.48, Accuracy: 0.603
# Epoch 78, CIFAR-10 Batch 5:  Cost: 0.46, Accuracy: 0.610
# Epoch 79, CIFAR-10 Batch 1:  Cost: 0.52, Accuracy: 0.599
# Epoch 79, CIFAR-10 Batch 2:  Cost: 0.53, Accuracy: 0.592
# Epoch 79, CIFAR-10 Batch 3:  Cost: 0.53, Accuracy: 0.600
# Epoch 79, CIFAR-10 Batch 4:  Cost: 0.51, Accuracy: 0.600
# Epoch 79, CIFAR-10 Batch 5:  Cost: 0.48, Accuracy: 0.603
# Epoch 80, CIFAR-10 Batch 1:  Cost: 0.50, Accuracy: 0.612
# Epoch 80, CIFAR-10 Batch 2:  Cost: 0.49, Accuracy: 0.614
# Epoch 80, CIFAR-10 Batch 3:  Cost: 0.47, Accuracy: 0.611
# Epoch 80, CIFAR-10 Batch 4:  Cost: 0.47, Accuracy: 0.609
# Epoch 80, CIFAR-10 Batch 5:  Cost: 0.45, Accuracy: 0.608
# Epoch 81, CIFAR-10 Batch 1:  Cost: 0.45, Accuracy: 0.610
# Epoch 81, CIFAR-10 Batch 2:  Cost: 0.48, Accuracy: 0.608
# Epoch 81, CIFAR-10 Batch 3:  Cost: 0.46, Accuracy: 0.614
# Epoch 81, CIFAR-10 Batch 4:  Cost: 0.45, Accuracy: 0.608
# Epoch 81, CIFAR-10 Batch 5:  Cost: 0.45, Accuracy: 0.607
# Epoch 82, CIFAR-10 Batch 1:  Cost: 0.45, Accuracy: 0.618
# Epoch 82, CIFAR-10 Batch 2:  Cost: 0.47, Accuracy: 0.615
# Epoch 82, CIFAR-10 Batch 3:  Cost: 0.46, Accuracy: 0.613
# Epoch 82, CIFAR-10 Batch 4:  Cost: 0.46, Accuracy: 0.603
# Epoch 82, CIFAR-10 Batch 5:  Cost: 0.44, Accuracy: 0.610
# Epoch 83, CIFAR-10 Batch 1:  Cost: 0.44, Accuracy: 0.611
# Epoch 83, CIFAR-10 Batch 2:  Cost: 0.48, Accuracy: 0.611
# Epoch 83, CIFAR-10 Batch 3:  Cost: 0.47, Accuracy: 0.607
# Epoch 83, CIFAR-10 Batch 4:  Cost: 0.46, Accuracy: 0.600
# Epoch 83, CIFAR-10 Batch 5:  Cost: 0.43, Accuracy: 0.612
# Epoch 84, CIFAR-10 Batch 1:  Cost: 0.45, Accuracy: 0.610
# Epoch 84, CIFAR-10 Batch 2:  Cost: 0.49, Accuracy: 0.614
# Epoch 84, CIFAR-10 Batch 3:  Cost: 0.45, Accuracy: 0.612
# Epoch 84, CIFAR-10 Batch 4:  Cost: 0.44, Accuracy: 0.603
# Epoch 84, CIFAR-10 Batch 5:  Cost: 0.42, Accuracy: 0.611
# Epoch 85, CIFAR-10 Batch 1:  Cost: 0.43, Accuracy: 0.615
# Epoch 85, CIFAR-10 Batch 2:  Cost: 0.46, Accuracy: 0.613
# Epoch 85, CIFAR-10 Batch 3:  Cost: 0.45, Accuracy: 0.610
# Epoch 85, CIFAR-10 Batch 4:  Cost: 0.45, Accuracy: 0.602
# Epoch 85, CIFAR-10 Batch 5:  Cost: 0.43, Accuracy: 0.617
# Epoch 86, CIFAR-10 Batch 1:  Cost: 0.43, Accuracy: 0.612
# Epoch 86, CIFAR-10 Batch 2:  Cost: 0.43, Accuracy: 0.614
# Epoch 86, CIFAR-10 Batch 3:  Cost: 0.43, Accuracy: 0.616
# Epoch 86, CIFAR-10 Batch 4:  Cost: 0.43, Accuracy: 0.606
# Epoch 86, CIFAR-10 Batch 5:  Cost: 0.40, Accuracy: 0.613
# Epoch 87, CIFAR-10 Batch 1:  Cost: 0.41, Accuracy: 0.613
# Epoch 87, CIFAR-10 Batch 2:  Cost: 0.45, Accuracy: 0.614
# Epoch 87, CIFAR-10 Batch 3:  Cost: 0.44, Accuracy: 0.609
# Epoch 87, CIFAR-10 Batch 4:  Cost: 0.42, Accuracy: 0.605
# Epoch 87, CIFAR-10 Batch 5:  Cost: 0.41, Accuracy: 0.615
# Epoch 88, CIFAR-10 Batch 1:  Cost: 0.43, Accuracy: 0.610
# Epoch 88, CIFAR-10 Batch 2:  Cost: 0.43, Accuracy: 0.613
# Epoch 88, CIFAR-10 Batch 3:  Cost: 0.44, Accuracy: 0.605
# Epoch 88, CIFAR-10 Batch 4:  Cost: 0.45, Accuracy: 0.604
# Epoch 88, CIFAR-10 Batch 5:  Cost: 0.41, Accuracy: 0.609
# Epoch 89, CIFAR-10 Batch 1:  Cost: 0.42, Accuracy: 0.614
# Epoch 89, CIFAR-10 Batch 2:  Cost: 0.43, Accuracy: 0.617
# Epoch 89, CIFAR-10 Batch 3:  Cost: 0.42, Accuracy: 0.613
# Epoch 89, CIFAR-10 Batch 4:  Cost: 0.41, Accuracy: 0.611
# Epoch 89, CIFAR-10 Batch 5:  Cost: 0.39, Accuracy: 0.609
# Epoch 90, CIFAR-10 Batch 1:  Cost: 0.40, Accuracy: 0.615
# Epoch 90, CIFAR-10 Batch 2:  Cost: 0.42, Accuracy: 0.617
# Epoch 90, CIFAR-10 Batch 3:  Cost: 0.40, Accuracy: 0.619
# Epoch 90, CIFAR-10 Batch 4:  Cost: 0.42, Accuracy: 0.608
# Epoch 90, CIFAR-10 Batch 5:  Cost: 0.39, Accuracy: 0.608
# Epoch 91, CIFAR-10 Batch 1:  Cost: 0.40, Accuracy: 0.612
# Epoch 91, CIFAR-10 Batch 2:  Cost: 0.42, Accuracy: 0.612
# Epoch 91, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.619
# Epoch 91, CIFAR-10 Batch 4:  Cost: 0.40, Accuracy: 0.608
# Epoch 91, CIFAR-10 Batch 5:  Cost: 0.40, Accuracy: 0.609
# Epoch 92, CIFAR-10 Batch 1:  Cost: 0.40, Accuracy: 0.615
# Epoch 92, CIFAR-10 Batch 2:  Cost: 0.41, Accuracy: 0.613
# Epoch 92, CIFAR-10 Batch 3:  Cost: 0.42, Accuracy: 0.613
# Epoch 92, CIFAR-10 Batch 4:  Cost: 0.40, Accuracy: 0.612
# Epoch 92, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.609
# Epoch 93, CIFAR-10 Batch 1:  Cost: 0.39, Accuracy: 0.616
# Epoch 93, CIFAR-10 Batch 2:  Cost: 0.41, Accuracy: 0.613
# Epoch 93, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.614
# Epoch 93, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.616
# Epoch 93, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.609
# Epoch 94, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.611
# Epoch 94, CIFAR-10 Batch 2:  Cost: 0.40, Accuracy: 0.617
# Epoch 94, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.617
# Epoch 94, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.614
# Epoch 94, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.608
# Epoch 95, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.614
# Epoch 95, CIFAR-10 Batch 2:  Cost: 0.40, Accuracy: 0.618
# Epoch 95, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.615
# Epoch 95, CIFAR-10 Batch 4:  Cost: 0.40, Accuracy: 0.610
# Epoch 95, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.607
# Epoch 96, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.615
# Epoch 96, CIFAR-10 Batch 2:  Cost: 0.41, Accuracy: 0.613
# Epoch 96, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.617
# Epoch 96, CIFAR-10 Batch 4:  Cost: 0.38, Accuracy: 0.611
# Epoch 96, CIFAR-10 Batch 5:  Cost: 0.36, Accuracy: 0.612
# Epoch 97, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.612
# Epoch 97, CIFAR-10 Batch 2:  Cost: 0.39, Accuracy: 0.616
# Epoch 97, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.608
# Epoch 97, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.618
# Epoch 97, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.605
# Epoch 98, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.617
# Epoch 98, CIFAR-10 Batch 2:  Cost: 0.40, Accuracy: 0.614
# Epoch 98, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.613
# Epoch 98, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.607
# Epoch 98, CIFAR-10 Batch 5:  Cost: 0.38, Accuracy: 0.616
# Epoch 99, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.613
# Epoch 99, CIFAR-10 Batch 2:  Cost: 0.38, Accuracy: 0.615
# Epoch 99, CIFAR-10 Batch 3:  Cost: 0.39, Accuracy: 0.610
# Epoch 99, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.614
# Epoch 99, CIFAR-10 Batch 5:  Cost: 0.36, Accuracy: 0.611
# Epoch 100, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.619
# Epoch 100, CIFAR-10 Batch 2:  Cost: 0.37, Accuracy: 0.613
# Epoch 100, CIFAR-10 Batch 3:  Cost: 0.37, Accuracy: 0.618
# Epoch 100, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.609
# Epoch 100, CIFAR-10 Batch 5:  Cost: 0.35, Accuracy: 0.615
# Epoch 101, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.619
# Epoch 101, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.615
# Epoch 101, CIFAR-10 Batch 3:  Cost: 0.37, Accuracy: 0.617
# Epoch 101, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.608
# Epoch 101, CIFAR-10 Batch 5:  Cost: 0.36, Accuracy: 0.613
# Epoch 102, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.615
# Epoch 102, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.620
# Epoch 102, CIFAR-10 Batch 3:  Cost: 0.36, Accuracy: 0.620
# Epoch 102, CIFAR-10 Batch 4:  Cost: 0.37, Accuracy: 0.616
# Epoch 102, CIFAR-10 Batch 5:  Cost: 0.35, Accuracy: 0.612
# Epoch 103, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.617
# Epoch 103, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.615
# Epoch 103, CIFAR-10 Batch 3:  Cost: 0.36, Accuracy: 0.610
# Epoch 103, CIFAR-10 Batch 4:  Cost: 0.38, Accuracy: 0.611
# Epoch 103, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.606
# Epoch 104, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.619
# Epoch 104, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.619
# Epoch 104, CIFAR-10 Batch 3:  Cost: 0.36, Accuracy: 0.615
# Epoch 104, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.601
# Epoch 104, CIFAR-10 Batch 5:  Cost: 0.39, Accuracy: 0.595
# Epoch 105, CIFAR-10 Batch 1:  Cost: 0.44, Accuracy: 0.590
# Epoch 105, CIFAR-10 Batch 2:  Cost: 0.41, Accuracy: 0.607
# Epoch 105, CIFAR-10 Batch 3:  Cost: 0.42, Accuracy: 0.597
# Epoch 105, CIFAR-10 Batch 4:  Cost: 0.40, Accuracy: 0.610
# Epoch 105, CIFAR-10 Batch 5:  Cost: 0.39, Accuracy: 0.602
# Epoch 106, CIFAR-10 Batch 1:  Cost: 0.39, Accuracy: 0.615
# Epoch 106, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.612
# Epoch 106, CIFAR-10 Batch 3:  Cost: 0.36, Accuracy: 0.616
# Epoch 106, CIFAR-10 Batch 4:  Cost: 0.36, Accuracy: 0.615
# Epoch 106, CIFAR-10 Batch 5:  Cost: 0.37, Accuracy: 0.599
# Epoch 107, CIFAR-10 Batch 1:  Cost: 0.38, Accuracy: 0.610
# Epoch 107, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.615
# Epoch 107, CIFAR-10 Batch 3:  Cost: 0.35, Accuracy: 0.618
# Epoch 107, CIFAR-10 Batch 4:  Cost: 0.35, Accuracy: 0.618
# Epoch 107, CIFAR-10 Batch 5:  Cost: 0.34, Accuracy: 0.609
# Epoch 108, CIFAR-10 Batch 1:  Cost: 0.37, Accuracy: 0.605
# Epoch 108, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.609
# Epoch 108, CIFAR-10 Batch 3:  Cost: 0.37, Accuracy: 0.612
# Epoch 108, CIFAR-10 Batch 4:  Cost: 0.35, Accuracy: 0.619
# Epoch 108, CIFAR-10 Batch 5:  Cost: 0.35, Accuracy: 0.606
# Epoch 109, CIFAR-10 Batch 1:  Cost: 0.36, Accuracy: 0.617
# Epoch 109, CIFAR-10 Batch 2:  Cost: 0.37, Accuracy: 0.599
# Epoch 109, CIFAR-10 Batch 3:  Cost: 0.41, Accuracy: 0.602
# Epoch 109, CIFAR-10 Batch 4:  Cost: 0.39, Accuracy: 0.595
# Epoch 109, CIFAR-10 Batch 5:  Cost: 0.41, Accuracy: 0.607
# Epoch 110, CIFAR-10 Batch 1:  Cost: 0.39, Accuracy: 0.608
# Epoch 110, CIFAR-10 Batch 2:  Cost: 0.36, Accuracy: 0.620
# Epoch 110, CIFAR-10 Batch 3:  Cost: 0.35, Accuracy: 0.611
# Epoch 110, CIFAR-10 Batch 4:  Cost: 0.36, Accuracy: 0.618
# Epoch 110, CIFAR-10 Batch 5:  Cost: 0.34, Accuracy: 0.613
# Epoch 111, CIFAR-10 Batch 1:  Cost: 0.33, Accuracy: 0.615
# Epoch 111, CIFAR-10 Batch 2:  Cost: 0.34, Accuracy: 0.613
# Epoch 111, CIFAR-10 Batch 3:  Cost: 0.36, Accuracy: 0.614
# Epoch 111, CIFAR-10 Batch 4:  Cost: 0.35, Accuracy: 0.606
# Epoch 111, CIFAR-10 Batch 5:  Cost: 0.34, Accuracy: 0.613
# Epoch 112, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.619
# Epoch 112, CIFAR-10 Batch 2:  Cost: 0.33, Accuracy: 0.621
# Epoch 112, CIFAR-10 Batch 3:  Cost: 0.33, Accuracy: 0.615
# Epoch 112, CIFAR-10 Batch 4:  Cost: 0.33, Accuracy: 0.616
# Epoch 112, CIFAR-10 Batch 5:  Cost: 0.33, Accuracy: 0.621
# Epoch 113, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.613
# Epoch 113, CIFAR-10 Batch 2:  Cost: 0.32, Accuracy: 0.620
# Epoch 113, CIFAR-10 Batch 3:  Cost: 0.32, Accuracy: 0.612
# Epoch 113, CIFAR-10 Batch 4:  Cost: 0.33, Accuracy: 0.618
# Epoch 113, CIFAR-10 Batch 5:  Cost: 0.33, Accuracy: 0.616
# Epoch 114, CIFAR-10 Batch 1:  Cost: 0.32, Accuracy: 0.616
# Epoch 114, CIFAR-10 Batch 2:  Cost: 0.32, Accuracy: 0.618
# Epoch 114, CIFAR-10 Batch 3:  Cost: 0.33, Accuracy: 0.617
# Epoch 114, CIFAR-10 Batch 4:  Cost: 0.33, Accuracy: 0.616
# Epoch 114, CIFAR-10 Batch 5:  Cost: 0.33, Accuracy: 0.621
# Epoch 115, CIFAR-10 Batch 1:  Cost: 0.32, Accuracy: 0.616
# Epoch 115, CIFAR-10 Batch 2:  Cost: 0.32, Accuracy: 0.621
# Epoch 115, CIFAR-10 Batch 3:  Cost: 0.34, Accuracy: 0.610
# Epoch 115, CIFAR-10 Batch 4:  Cost: 0.35, Accuracy: 0.612
# Epoch 115, CIFAR-10 Batch 5:  Cost: 0.34, Accuracy: 0.611
# Epoch 116, CIFAR-10 Batch 1:  Cost: 0.34, Accuracy: 0.612
# Epoch 116, CIFAR-10 Batch 2:  Cost: 0.32, Accuracy: 0.617
# Epoch 116, CIFAR-10 Batch 3:  Cost: 0.33, Accuracy: 0.616
# Epoch 116, CIFAR-10 Batch 4:  Cost: 0.32, Accuracy: 0.623
# Epoch 116, CIFAR-10 Batch 5:  Cost: 0.32, Accuracy: 0.620
# Epoch 117, CIFAR-10 Batch 1:  Cost: 0.31, Accuracy: 0.618
# Epoch 117, CIFAR-10 Batch 2:  Cost: 0.31, Accuracy: 0.622
# Epoch 117, CIFAR-10 Batch 3:  Cost: 0.31, Accuracy: 0.616
# Epoch 117, CIFAR-10 Batch 4:  Cost: 0.31, Accuracy: 0.620
# Epoch 117, CIFAR-10 Batch 5:  Cost: 0.33, Accuracy: 0.612
# Epoch 118, CIFAR-10 Batch 1:  Cost: 0.31, Accuracy: 0.623
# Epoch 118, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.622
# Epoch 118, CIFAR-10 Batch 3:  Cost: 0.33, Accuracy: 0.614
# Epoch 118, CIFAR-10 Batch 4:  Cost: 0.32, Accuracy: 0.618
# Epoch 118, CIFAR-10 Batch 5:  Cost: 0.31, Accuracy: 0.616
# Epoch 119, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.621
# Epoch 119, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.618
# Epoch 119, CIFAR-10 Batch 3:  Cost: 0.31, Accuracy: 0.617
# Epoch 119, CIFAR-10 Batch 4:  Cost: 0.31, Accuracy: 0.619
# Epoch 119, CIFAR-10 Batch 5:  Cost: 0.33, Accuracy: 0.609
# Epoch 120, CIFAR-10 Batch 1:  Cost: 0.33, Accuracy: 0.616
# Epoch 120, CIFAR-10 Batch 2:  Cost: 0.31, Accuracy: 0.610
# Epoch 120, CIFAR-10 Batch 3:  Cost: 0.30, Accuracy: 0.618
# Epoch 120, CIFAR-10 Batch 4:  Cost: 0.30, Accuracy: 0.623
# Epoch 120, CIFAR-10 Batch 5:  Cost: 0.32, Accuracy: 0.622
# Epoch 121, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.621
# Epoch 121, CIFAR-10 Batch 2:  Cost: 0.29, Accuracy: 0.616
# Epoch 121, CIFAR-10 Batch 3:  Cost: 0.30, Accuracy: 0.619
# Epoch 121, CIFAR-10 Batch 4:  Cost: 0.31, Accuracy: 0.618
# Epoch 121, CIFAR-10 Batch 5:  Cost: 0.31, Accuracy: 0.622
# Epoch 122, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.620
# Epoch 122, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.621
# Epoch 122, CIFAR-10 Batch 3:  Cost: 0.29, Accuracy: 0.616
# Epoch 122, CIFAR-10 Batch 4:  Cost: 0.29, Accuracy: 0.624
# Epoch 122, CIFAR-10 Batch 5:  Cost: 0.30, Accuracy: 0.622
# Epoch 123, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.616
# Epoch 123, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.619
# Epoch 123, CIFAR-10 Batch 3:  Cost: 0.30, Accuracy: 0.620
# Epoch 123, CIFAR-10 Batch 4:  Cost: 0.30, Accuracy: 0.617
# Epoch 123, CIFAR-10 Batch 5:  Cost: 0.30, Accuracy: 0.620
# Epoch 124, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.619
# Epoch 124, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.622
# Epoch 124, CIFAR-10 Batch 3:  Cost: 0.30, Accuracy: 0.614
# Epoch 124, CIFAR-10 Batch 4:  Cost: 0.30, Accuracy: 0.613
# Epoch 124, CIFAR-10 Batch 5:  Cost: 0.30, Accuracy: 0.620
# Epoch 125, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.623
# Epoch 125, CIFAR-10 Batch 2:  Cost: 0.29, Accuracy: 0.623
# Epoch 125, CIFAR-10 Batch 3:  Cost: 0.29, Accuracy: 0.615
# Epoch 125, CIFAR-10 Batch 4:  Cost: 0.29, Accuracy: 0.616
# Epoch 125, CIFAR-10 Batch 5:  Cost: 0.30, Accuracy: 0.619
# Epoch 126, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.625
# Epoch 126, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.621
# Epoch 126, CIFAR-10 Batch 3:  Cost: 0.29, Accuracy: 0.618
# Epoch 126, CIFAR-10 Batch 4:  Cost: 0.30, Accuracy: 0.615
# Epoch 126, CIFAR-10 Batch 5:  Cost: 0.30, Accuracy: 0.615
# Epoch 127, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.621
# Epoch 127, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.616
# Epoch 127, CIFAR-10 Batch 3:  Cost: 0.29, Accuracy: 0.617
# Epoch 127, CIFAR-10 Batch 4:  Cost: 0.30, Accuracy: 0.613
# Epoch 127, CIFAR-10 Batch 5:  Cost: 0.31, Accuracy: 0.616
# Epoch 128, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.624
# Epoch 128, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.618
# Epoch 128, CIFAR-10 Batch 3:  Cost: 0.29, Accuracy: 0.622
# Epoch 128, CIFAR-10 Batch 4:  Cost: 0.32, Accuracy: 0.611
# Epoch 128, CIFAR-10 Batch 5:  Cost: 0.29, Accuracy: 0.618
# Epoch 129, CIFAR-10 Batch 1:  Cost: 0.30, Accuracy: 0.622
# Epoch 129, CIFAR-10 Batch 2:  Cost: 0.30, Accuracy: 0.619
# Epoch 129, CIFAR-10 Batch 3:  Cost: 0.31, Accuracy: 0.617
# Epoch 129, CIFAR-10 Batch 4:  Cost: 0.31, Accuracy: 0.618
# Epoch 129, CIFAR-10 Batch 5:  Cost: 0.31, Accuracy: 0.607
# Epoch 130, CIFAR-10 Batch 1:  Cost: 0.29, Accuracy: 0.625
# Epoch 130, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.619
# Epoch 130, CIFAR-10 Batch 3:  Cost: 0.28, Accuracy: 0.618
# Epoch 130, CIFAR-10 Batch 4:  Cost: 0.27, Accuracy: 0.622
# Epoch 130, CIFAR-10 Batch 5:  Cost: 0.28, Accuracy: 0.619
# Epoch 131, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.622
# Epoch 131, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.624
# Epoch 131, CIFAR-10 Batch 3:  Cost: 0.28, Accuracy: 0.624
# Epoch 131, CIFAR-10 Batch 4:  Cost: 0.28, Accuracy: 0.625
# Epoch 131, CIFAR-10 Batch 5:  Cost: 0.27, Accuracy: 0.621
# Epoch 132, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.623
# Epoch 132, CIFAR-10 Batch 2:  Cost: 0.27, Accuracy: 0.626
# Epoch 132, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.623
# Epoch 132, CIFAR-10 Batch 4:  Cost: 0.27, Accuracy: 0.620
# Epoch 132, CIFAR-10 Batch 5:  Cost: 0.29, Accuracy: 0.615
# Epoch 133, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.620
# Epoch 133, CIFAR-10 Batch 2:  Cost: 0.32, Accuracy: 0.606
# Epoch 133, CIFAR-10 Batch 3:  Cost: 0.28, Accuracy: 0.619
# Epoch 133, CIFAR-10 Batch 4:  Cost: 0.27, Accuracy: 0.626
# Epoch 133, CIFAR-10 Batch 5:  Cost: 0.28, Accuracy: 0.623
# Epoch 134, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.627
# Epoch 134, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.617
# Epoch 134, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.619
# Epoch 134, CIFAR-10 Batch 4:  Cost: 0.28, Accuracy: 0.624
# Epoch 134, CIFAR-10 Batch 5:  Cost: 0.28, Accuracy: 0.617
# Epoch 135, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.620
# Epoch 135, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.614
# Epoch 135, CIFAR-10 Batch 3:  Cost: 0.28, Accuracy: 0.619
# Epoch 135, CIFAR-10 Batch 4:  Cost: 0.27, Accuracy: 0.622
# Epoch 135, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.621
# Epoch 136, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.626
# Epoch 136, CIFAR-10 Batch 2:  Cost: 0.27, Accuracy: 0.621
# Epoch 136, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.623
# Epoch 136, CIFAR-10 Batch 4:  Cost: 0.28, Accuracy: 0.617
# Epoch 136, CIFAR-10 Batch 5:  Cost: 0.28, Accuracy: 0.617
# Epoch 137, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.618
# Epoch 137, CIFAR-10 Batch 2:  Cost: 0.27, Accuracy: 0.626
# Epoch 137, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.619
# Epoch 137, CIFAR-10 Batch 4:  Cost: 0.27, Accuracy: 0.617
# Epoch 137, CIFAR-10 Batch 5:  Cost: 0.27, Accuracy: 0.625
# Epoch 138, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.618
# Epoch 138, CIFAR-10 Batch 2:  Cost: 0.26, Accuracy: 0.620
# Epoch 138, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.620
# Epoch 138, CIFAR-10 Batch 4:  Cost: 0.28, Accuracy: 0.618
# Epoch 138, CIFAR-10 Batch 5:  Cost: 0.27, Accuracy: 0.614
# Epoch 139, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.618
# Epoch 139, CIFAR-10 Batch 2:  Cost: 0.26, Accuracy: 0.626
# Epoch 139, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.616
# Epoch 139, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.620
# Epoch 139, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.619
# Epoch 140, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.629
# Epoch 140, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.629
# Epoch 140, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.617
# Epoch 140, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.625
# Epoch 140, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.621
# Epoch 141, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.629
# Epoch 141, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.626
# Epoch 141, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.620
# Epoch 141, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.625
# Epoch 141, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.623
# Epoch 142, CIFAR-10 Batch 1:  Cost: 0.24, Accuracy: 0.629
# Epoch 142, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.624
# Epoch 142, CIFAR-10 Batch 3:  Cost: 0.25, Accuracy: 0.620
# Epoch 142, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.622
# Epoch 142, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.613
# Epoch 143, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.624
# Epoch 143, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.630
# Epoch 143, CIFAR-10 Batch 3:  Cost: 0.25, Accuracy: 0.617
# Epoch 143, CIFAR-10 Batch 4:  Cost: 0.26, Accuracy: 0.619
# Epoch 143, CIFAR-10 Batch 5:  Cost: 0.27, Accuracy: 0.613
# Epoch 144, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.622
# Epoch 144, CIFAR-10 Batch 2:  Cost: 0.26, Accuracy: 0.620
# Epoch 144, CIFAR-10 Batch 3:  Cost: 0.24, Accuracy: 0.623
# Epoch 144, CIFAR-10 Batch 4:  Cost: 0.26, Accuracy: 0.622
# Epoch 144, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.623
# Epoch 145, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.622
# Epoch 145, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.630
# Epoch 145, CIFAR-10 Batch 3:  Cost: 0.25, Accuracy: 0.622
# Epoch 145, CIFAR-10 Batch 4:  Cost: 0.26, Accuracy: 0.625
# Epoch 145, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.621
# Epoch 146, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.622
# Epoch 146, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.625
# Epoch 146, CIFAR-10 Batch 3:  Cost: 0.25, Accuracy: 0.621
# Epoch 146, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.624
# Epoch 146, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.614
# Epoch 147, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.623
# Epoch 147, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.622
# Epoch 147, CIFAR-10 Batch 3:  Cost: 0.25, Accuracy: 0.613
# Epoch 147, CIFAR-10 Batch 4:  Cost: 0.26, Accuracy: 0.624
# Epoch 147, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.618
# Epoch 148, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.624
# Epoch 148, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.627
# Epoch 148, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.613
# Epoch 148, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.627
# Epoch 148, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.611
# Epoch 149, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.627
# Epoch 149, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.622
# Epoch 149, CIFAR-10 Batch 3:  Cost: 0.24, Accuracy: 0.616
# Epoch 149, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.626
# Epoch 149, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.616
# Epoch 150, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.625
# Epoch 150, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.628
# Epoch 150, CIFAR-10 Batch 3:  Cost: 0.23, Accuracy: 0.623
# Epoch 150, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.628
# Epoch 150, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.613
# Epoch 151, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.627
# Epoch 151, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.624
# Epoch 151, CIFAR-10 Batch 3:  Cost: 0.23, Accuracy: 0.625
# Epoch 151, CIFAR-10 Batch 4:  Cost: 0.23, Accuracy: 0.626
# Epoch 151, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.614
# Epoch 152, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.619
# Epoch 152, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.623
# Epoch 152, CIFAR-10 Batch 3:  Cost: 0.24, Accuracy: 0.619
# Epoch 152, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.625
# Epoch 152, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.607
# Epoch 153, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.616
# Epoch 153, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.618
# Epoch 153, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.625
# Epoch 153, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.625
# Epoch 153, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.618
# Epoch 154, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.623
# Epoch 154, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.613
# Epoch 154, CIFAR-10 Batch 3:  Cost: 0.23, Accuracy: 0.622
# Epoch 154, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.619
# Epoch 154, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.620
# Epoch 155, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.614
# Epoch 155, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.617
# Epoch 155, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.615
# Epoch 155, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.614
# Epoch 155, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.619
# Epoch 156, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.618
# Epoch 156, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.620
# Epoch 156, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.606
# Epoch 156, CIFAR-10 Batch 4:  Cost: 0.26, Accuracy: 0.608
# Epoch 156, CIFAR-10 Batch 5:  Cost: 0.27, Accuracy: 0.609
# Epoch 157, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.618
# Epoch 157, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.625
# Epoch 157, CIFAR-10 Batch 3:  Cost: 0.24, Accuracy: 0.619
# Epoch 157, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.619
# Epoch 157, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.614
# Epoch 158, CIFAR-10 Batch 1:  Cost: 0.27, Accuracy: 0.615
# Epoch 158, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.622
# Epoch 158, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.619
# Epoch 158, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.624
# Epoch 158, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.620
# Epoch 159, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.624
# Epoch 159, CIFAR-10 Batch 2:  Cost: 0.22, Accuracy: 0.627
# Epoch 159, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.623
# Epoch 159, CIFAR-10 Batch 4:  Cost: 0.22, Accuracy: 0.624
# Epoch 159, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.615
# Epoch 160, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.619
# Epoch 160, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.622
# Epoch 160, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.625
# Epoch 160, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.621
# Epoch 160, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.619
# Epoch 161, CIFAR-10 Batch 1:  Cost: 0.24, Accuracy: 0.618
# Epoch 161, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.626
# Epoch 161, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.624
# Epoch 161, CIFAR-10 Batch 4:  Cost: 0.23, Accuracy: 0.624
# Epoch 161, CIFAR-10 Batch 5:  Cost: 0.21, Accuracy: 0.626
# Epoch 162, CIFAR-10 Batch 1:  Cost: 0.24, Accuracy: 0.625
# Epoch 162, CIFAR-10 Batch 2:  Cost: 0.22, Accuracy: 0.624
# Epoch 162, CIFAR-10 Batch 3:  Cost: 0.21, Accuracy: 0.623
# Epoch 162, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.619
# Epoch 162, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.621
# Epoch 163, CIFAR-10 Batch 1:  Cost: 0.24, Accuracy: 0.613
# Epoch 163, CIFAR-10 Batch 2:  Cost: 0.23, Accuracy: 0.620
# Epoch 163, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.618
# Epoch 163, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.622
# Epoch 163, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.614
# Epoch 164, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.607
# Epoch 164, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.618
# Epoch 164, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.595
# Epoch 164, CIFAR-10 Batch 4:  Cost: 0.26, Accuracy: 0.622
# Epoch 164, CIFAR-10 Batch 5:  Cost: 0.26, Accuracy: 0.609
# Epoch 165, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.611
# Epoch 165, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.610
# Epoch 165, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.611
# Epoch 165, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.619
# Epoch 165, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.619
# Epoch 166, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.608
# Epoch 166, CIFAR-10 Batch 2:  Cost: 0.27, Accuracy: 0.605
# Epoch 166, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.616
# Epoch 166, CIFAR-10 Batch 4:  Cost: 0.25, Accuracy: 0.628
# Epoch 166, CIFAR-10 Batch 5:  Cost: 0.27, Accuracy: 0.620
# Epoch 167, CIFAR-10 Batch 1:  Cost: 0.28, Accuracy: 0.603
# Epoch 167, CIFAR-10 Batch 2:  Cost: 0.28, Accuracy: 0.606
# Epoch 167, CIFAR-10 Batch 3:  Cost: 0.27, Accuracy: 0.610
# Epoch 167, CIFAR-10 Batch 4:  Cost: 0.28, Accuracy: 0.604
# Epoch 167, CIFAR-10 Batch 5:  Cost: 0.29, Accuracy: 0.612
# Epoch 168, CIFAR-10 Batch 1:  Cost: 0.26, Accuracy: 0.611
# Epoch 168, CIFAR-10 Batch 2:  Cost: 0.25, Accuracy: 0.614
# Epoch 168, CIFAR-10 Batch 3:  Cost: 0.26, Accuracy: 0.606
# Epoch 168, CIFAR-10 Batch 4:  Cost: 0.27, Accuracy: 0.603
# Epoch 168, CIFAR-10 Batch 5:  Cost: 0.28, Accuracy: 0.612
# Epoch 169, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.623
# Epoch 169, CIFAR-10 Batch 2:  Cost: 0.24, Accuracy: 0.614
# Epoch 169, CIFAR-10 Batch 3:  Cost: 0.25, Accuracy: 0.617
# Epoch 169, CIFAR-10 Batch 4:  Cost: 0.24, Accuracy: 0.613
# Epoch 169, CIFAR-10 Batch 5:  Cost: 0.25, Accuracy: 0.620
# Epoch 170, CIFAR-10 Batch 1:  Cost: 0.25, Accuracy: 0.621
# Epoch 170, CIFAR-10 Batch 2:  Cost: 0.22, Accuracy: 0.622
# Epoch 170, CIFAR-10 Batch 3:  Cost: 0.21, Accuracy: 0.625
# Epoch 170, CIFAR-10 Batch 4:  Cost: 0.21, Accuracy: 0.621
# Epoch 170, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.625
# Epoch 171, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.617
# Epoch 171, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.627
# Epoch 171, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.623
# Epoch 171, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.623
# Epoch 171, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.625
# Epoch 172, CIFAR-10 Batch 1:  Cost: 0.22, Accuracy: 0.620
# Epoch 172, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.628
# Epoch 172, CIFAR-10 Batch 3:  Cost: 0.22, Accuracy: 0.616
# Epoch 172, CIFAR-10 Batch 4:  Cost: 0.22, Accuracy: 0.621
# Epoch 172, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.627
# Epoch 173, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.625
# Epoch 173, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.623
# Epoch 173, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.623
# Epoch 173, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.619
# Epoch 173, CIFAR-10 Batch 5:  Cost: 0.23, Accuracy: 0.626
# Epoch 174, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.627
# Epoch 174, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.623
# Epoch 174, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.621
# Epoch 174, CIFAR-10 Batch 4:  Cost: 0.21, Accuracy: 0.617
# Epoch 174, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.624
# Epoch 175, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.623
# Epoch 175, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.621
# Epoch 175, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.625
# Epoch 175, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.615
# Epoch 175, CIFAR-10 Batch 5:  Cost: 0.22, Accuracy: 0.626
# Epoch 176, CIFAR-10 Batch 1:  Cost: 0.22, Accuracy: 0.623
# Epoch 176, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.623
# Epoch 176, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.622
# Epoch 176, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.616
# Epoch 176, CIFAR-10 Batch 5:  Cost: 0.22, Accuracy: 0.615
# Epoch 177, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.618
# Epoch 177, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.624
# Epoch 177, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.624
# Epoch 177, CIFAR-10 Batch 4:  Cost: 0.19, Accuracy: 0.626
# Epoch 177, CIFAR-10 Batch 5:  Cost: 0.20, Accuracy: 0.629
# Epoch 178, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.622
# Epoch 178, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.630
# Epoch 178, CIFAR-10 Batch 3:  Cost: 0.21, Accuracy: 0.615
# Epoch 178, CIFAR-10 Batch 4:  Cost: 0.21, Accuracy: 0.617
# Epoch 178, CIFAR-10 Batch 5:  Cost: 0.22, Accuracy: 0.616
# Epoch 179, CIFAR-10 Batch 1:  Cost: 0.22, Accuracy: 0.623
# Epoch 179, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.620
# Epoch 179, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.623
# Epoch 179, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.617
# Epoch 179, CIFAR-10 Batch 5:  Cost: 0.20, Accuracy: 0.622
# Epoch 180, CIFAR-10 Batch 1:  Cost: 0.22, Accuracy: 0.620
# Epoch 180, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.618
# Epoch 180, CIFAR-10 Batch 3:  Cost: 0.20, Accuracy: 0.620
# Epoch 180, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.618
# Epoch 180, CIFAR-10 Batch 5:  Cost: 0.22, Accuracy: 0.614
# Epoch 181, CIFAR-10 Batch 1:  Cost: 0.22, Accuracy: 0.621
# Epoch 181, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.619
# Epoch 181, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.623
# Epoch 181, CIFAR-10 Batch 4:  Cost: 0.19, Accuracy: 0.624
# Epoch 181, CIFAR-10 Batch 5:  Cost: 0.20, Accuracy: 0.627
# Epoch 182, CIFAR-10 Batch 1:  Cost: 0.22, Accuracy: 0.619
# Epoch 182, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.625
# Epoch 182, CIFAR-10 Batch 3:  Cost: 0.21, Accuracy: 0.614
# Epoch 182, CIFAR-10 Batch 4:  Cost: 0.20, Accuracy: 0.611
# Epoch 182, CIFAR-10 Batch 5:  Cost: 0.24, Accuracy: 0.613
# Epoch 183, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.615
# Epoch 183, CIFAR-10 Batch 2:  Cost: 0.21, Accuracy: 0.619
# Epoch 183, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.623
# Epoch 183, CIFAR-10 Batch 4:  Cost: 0.18, Accuracy: 0.628
# Epoch 183, CIFAR-10 Batch 5:  Cost: 0.19, Accuracy: 0.630
# Epoch 184, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.626
# Epoch 184, CIFAR-10 Batch 2:  Cost: 0.19, Accuracy: 0.624
# Epoch 184, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.617
# Epoch 184, CIFAR-10 Batch 4:  Cost: 0.18, Accuracy: 0.621
# Epoch 184, CIFAR-10 Batch 5:  Cost: 0.21, Accuracy: 0.618
# Epoch 185, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.626
# Epoch 185, CIFAR-10 Batch 2:  Cost: 0.19, Accuracy: 0.623
# Epoch 185, CIFAR-10 Batch 3:  Cost: 0.18, Accuracy: 0.626
# Epoch 185, CIFAR-10 Batch 4:  Cost: 0.18, Accuracy: 0.622
# Epoch 185, CIFAR-10 Batch 5:  Cost: 0.20, Accuracy: 0.625
# Epoch 186, CIFAR-10 Batch 1:  Cost: 0.20, Accuracy: 0.623
# Epoch 186, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.621
# Epoch 186, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.621
# Epoch 186, CIFAR-10 Batch 4:  Cost: 0.19, Accuracy: 0.617
# Epoch 186, CIFAR-10 Batch 5:  Cost: 0.20, Accuracy: 0.623
# Epoch 187, CIFAR-10 Batch 1:  Cost: 0.20, Accuracy: 0.625
# Epoch 187, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.623
# Epoch 187, CIFAR-10 Batch 3:  Cost: 0.18, Accuracy: 0.624
# Epoch 187, CIFAR-10 Batch 4:  Cost: 0.19, Accuracy: 0.616
# Epoch 187, CIFAR-10 Batch 5:  Cost: 0.21, Accuracy: 0.619
# Epoch 188, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.619
# Epoch 188, CIFAR-10 Batch 2:  Cost: 0.19, Accuracy: 0.625
# Epoch 188, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.624
# Epoch 188, CIFAR-10 Batch 4:  Cost: 0.18, Accuracy: 0.622
# Epoch 188, CIFAR-10 Batch 5:  Cost: 0.19, Accuracy: 0.620
# Epoch 189, CIFAR-10 Batch 1:  Cost: 0.21, Accuracy: 0.619
# Epoch 189, CIFAR-10 Batch 2:  Cost: 0.20, Accuracy: 0.624
# Epoch 189, CIFAR-10 Batch 3:  Cost: 0.21, Accuracy: 0.617
# Epoch 189, CIFAR-10 Batch 4:  Cost: 0.19, Accuracy: 0.619
# Epoch 189, CIFAR-10 Batch 5:  Cost: 0.21, Accuracy: 0.607
# Epoch 190, CIFAR-10 Batch 1:  Cost: 0.23, Accuracy: 0.618
# Epoch 190, CIFAR-10 Batch 2:  Cost: 0.22, Accuracy: 0.622
# Epoch 190, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.620
# Epoch 190, CIFAR-10 Batch 4:  Cost: 0.18, Accuracy: 0.628
# Epoch 190, CIFAR-10 Batch 5:  Cost: 0.19, Accuracy: 0.625
# Epoch 191, CIFAR-10 Batch 1:  Cost: 0.20, Accuracy: 0.628
# Epoch 191, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.628
# Epoch 191, CIFAR-10 Batch 3:  Cost: 0.19, Accuracy: 0.616
# Epoch 191, CIFAR-10 Batch 4:  Cost: 0.18, Accuracy: 0.619
# Epoch 191, CIFAR-10 Batch 5:  Cost: 0.20, Accuracy: 0.617
# Epoch 192, CIFAR-10 Batch 1:  Cost: 0.20, Accuracy: 0.625
# Epoch 192, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.622
# Epoch 192, CIFAR-10 Batch 3:  Cost: 0.17, Accuracy: 0.621
# Epoch 192, CIFAR-10 Batch 4:  Cost: 0.17, Accuracy: 0.625
# Epoch 192, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.628
# Epoch 193, CIFAR-10 Batch 1:  Cost: 0.18, Accuracy: 0.632
# Epoch 193, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.623
# Epoch 193, CIFAR-10 Batch 3:  Cost: 0.18, Accuracy: 0.615
# Epoch 193, CIFAR-10 Batch 4:  Cost: 0.17, Accuracy: 0.622
# Epoch 193, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.625
# Epoch 194, CIFAR-10 Batch 1:  Cost: 0.19, Accuracy: 0.628
# Epoch 194, CIFAR-10 Batch 2:  Cost: 0.17, Accuracy: 0.629
# Epoch 194, CIFAR-10 Batch 3:  Cost: 0.17, Accuracy: 0.621
# Epoch 194, CIFAR-10 Batch 4:  Cost: 0.17, Accuracy: 0.621
# Epoch 194, CIFAR-10 Batch 5:  Cost: 0.19, Accuracy: 0.623
# Epoch 195, CIFAR-10 Batch 1:  Cost: 0.19, Accuracy: 0.625
# Epoch 195, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.626
# Epoch 195, CIFAR-10 Batch 3:  Cost: 0.17, Accuracy: 0.617
# Epoch 195, CIFAR-10 Batch 4:  Cost: 0.17, Accuracy: 0.622
# Epoch 195, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.624
# Epoch 196, CIFAR-10 Batch 1:  Cost: 0.19, Accuracy: 0.626
# Epoch 196, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.625
# Epoch 196, CIFAR-10 Batch 3:  Cost: 0.17, Accuracy: 0.620
# Epoch 196, CIFAR-10 Batch 4:  Cost: 0.16, Accuracy: 0.625
# Epoch 196, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.620
# Epoch 197, CIFAR-10 Batch 1:  Cost: 0.18, Accuracy: 0.628
# Epoch 197, CIFAR-10 Batch 2:  Cost: 0.18, Accuracy: 0.626
# Epoch 197, CIFAR-10 Batch 3:  Cost: 0.18, Accuracy: 0.616
# Epoch 197, CIFAR-10 Batch 4:  Cost: 0.16, Accuracy: 0.625
# Epoch 197, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.623
# Epoch 198, CIFAR-10 Batch 1:  Cost: 0.18, Accuracy: 0.626
# Epoch 198, CIFAR-10 Batch 2:  Cost: 0.17, Accuracy: 0.628
# Epoch 198, CIFAR-10 Batch 3:  Cost: 0.18, Accuracy: 0.616
# Epoch 198, CIFAR-10 Batch 4:  Cost: 0.17, Accuracy: 0.625
# Epoch 198, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.622
# Epoch 199, CIFAR-10 Batch 1:  Cost: 0.18, Accuracy: 0.625
# Epoch 199, CIFAR-10 Batch 2:  Cost: 0.17, Accuracy: 0.624
# Epoch 199, CIFAR-10 Batch 3:  Cost: 0.17, Accuracy: 0.622
# Epoch 199, CIFAR-10 Batch 4:  Cost: 0.16, Accuracy: 0.623
# Epoch 199, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.624
# Epoch 200, CIFAR-10 Batch 1:  Cost: 0.17, Accuracy: 0.629
# Epoch 200, CIFAR-10 Batch 2:  Cost: 0.16, Accuracy: 0.624
# Epoch 200, CIFAR-10 Batch 3:  Cost: 0.17, Accuracy: 0.618
# Epoch 200, CIFAR-10 Batch 4:  Cost: 0.16, Accuracy: 0.621
# Epoch 200, CIFAR-10 Batch 5:  Cost: 0.18, Accuracy: 0.619

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6160395344098409

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
