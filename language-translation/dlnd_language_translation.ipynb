# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (10, 20)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 10 to 20:
# the lime is her least liked fruit , but the banana is my least liked .
# he saw a old yellow truck .
# india is rainy during june , and it is sometimes warm in november .
# that cat was my most loved animal .
# he dislikes grapefruit , limes , and lemons .
# her least liked fruit is the lemon , but his least liked is the grapefruit .
# california is never cold during february , but it is sometimes freezing in june .
# china is usually pleasant during autumn , and it is usually quiet in october .
# paris is never freezing during november , but it is wonderful in october .
# the united states is never rainy during january , but it is sometimes mild in october .
#
# French sentences 10 to 20:
# la chaux est son moins aimé des fruits , mais la banane est mon moins aimé.
# il a vu un vieux camion jaune .
# inde est pluvieux en juin , et il est parfois chaud en novembre .
# ce chat était mon animal le plus aimé .
# il n'aime pamplemousse , citrons verts et les citrons .
# son fruit est moins aimé le citron , mais son moins aimé est le pamplemousse .
# californie ne fait jamais froid en février , mais il est parfois le gel en juin .
# chine est généralement agréable en automne , et il est généralement calme en octobre .
# paris est jamais le gel en novembre , mais il est merveilleux en octobre .
# les états-unis est jamais pluvieux en janvier , mais il est parfois doux en octobre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    def words_to_ids(words, vocab_to_int):
        return [vocab_to_int[word] for word in words]
    
    source_split_sentences = [sentence.split() for sentence in source_text.split('\n')]
    source_id_text = tuple((words_to_ids(words, source_vocab_to_int) for words in source_split_sentences))
    
    target_split_sentences = [sentence.split() + ['<EOS>'] for sentence in target_text.split('\n')]
    target_id_text = tuple((words_to_ids(words, target_vocab_to_int) for words in target_split_sentences))
    
    return source_id_text, target_id_text


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    input_ = tf.placeholder(tf.int32, shape=[None, None], name="input")
    targets = tf.placeholder(tf.int32, shape=[None, None], name="targets")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    target_sequence_length = tf.placeholder(tf.int32, shape=(None,), name="target_sequence_length")
    max_target_sequence_length = tf.reduce_max(target_sequence_length, name='max_target_sequence_length')
    source_sequence_length = tf.placeholder(tf.int32, shape=(None,), name="source_sequence_length")
    
    return input_, targets, learning_rate, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    return tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # Embed the encoder input
    embedded_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)

    # Build the RNN
    initializer = tf.random_uniform_initializer(-0.1, 0.1, seed=99)
    lstm_cells = [tf.contrib.rnn.LSTMCell(rnn_size, initializer=initializer) for _ in range(num_layers)]
    multi_rnn_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)
    
    # Add dropout
    dropout = tf.contrib.rnn.DropoutWrapper(multi_rnn_cell, input_keep_prob=keep_prob, dtype=tf.float32)
    
    return tf.nn.dynamic_rnn(dropout, embedded_input, sequence_length=source_sequence_length, dtype=tf.float32)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=target_sequence_length,
                                                        time_major=False)

    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       encoder_state,
                                                       output_layer) 
    
    training_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                   impute_finished=True,
                                                                   maximum_iterations=max_summary_length)
    
    return training_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)
    
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
    
    inference_decoder_outputs = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                  impute_finished=True,
                                                                  maximum_iterations=max_target_sequence_length)
    
    return inference_decoder_outputs[0]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # Embed the target sequences
    embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    embedded_input = tf.nn.embedding_lookup(embeddings, dec_input)
    
    # Construct the decoder LSTM cell
    initializer = tf.random_uniform_initializer(-0.1, 0.1, seed=99)
    lstm_cells = [tf.contrib.rnn.LSTMCell(rnn_size, initializer=initializer) for _ in range(num_layers)]
    multi_rnn_cell = tf.contrib.rnn.MultiRNNCell(lstm_cells)

    # Create an output layer to map the outputs of the decoder to the elements of our vocabulary
    output_layer = Dense(target_vocab_size, kernel_initializer = tf.truncated_normal_initializer(mean=0.0, stddev=0.1))

    # Get the training logits
    with tf.variable_scope("decode"):
        training_decoder_output = decoding_layer_train(encoder_state,
                                                       multi_rnn_cell,
                                                       embedded_input,
                                                       target_sequence_length,
                                                       max_target_sequence_length,
                                                       output_layer,
                                                       keep_prob)
    
    # Get the inference logits
    with tf.variable_scope("decode", reuse=True):
        inference_decoder_output = decoding_layer_infer(encoder_state,
                                                        multi_rnn_cell,
                                                        embeddings,
                                                        target_vocab_to_int['<GO>'],
                                                        target_vocab_to_int['<EOS>'],
                                                        max_target_sequence_length,
                                                        target_vocab_size,
                                                        output_layer,
                                                        batch_size,
                                                        keep_prob)

    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    
    # Encode the input
    _, encoder_state = encoding_layer(input_data,
                                      rnn_size,
                                      num_layers,
                                      keep_prob,
                                      source_sequence_length,
                                      source_vocab_size,
                                      enc_embedding_size)

    # Process target data
    decoder_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)

    # Decode the encoded input
    training_decoder_output, inference_decoder_output = decoding_layer(decoder_input,
                                                                       encoder_state,
                                                                       target_sequence_length,
                                                                       max_target_sentence_length,
                                                                       rnn_size,
                                                                       num_layers,
                                                                       target_vocab_to_int,
                                                                       target_vocab_size,
                                                                       batch_size,
                                                                       keep_prob,
                                                                       dec_embedding_size) 
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 150
# Batch Size
batch_size = 1024
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 50
decoding_embedding_size = 50
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/134 - Train Accuracy: 0.2778, Validation Accuracy: 0.3100, Loss: 5.3129
# Epoch   0 Batch   20/134 - Train Accuracy: 0.3053, Validation Accuracy: 0.3100, Loss: 4.4807
# Epoch   0 Batch   30/134 - Train Accuracy: 0.3067, Validation Accuracy: 0.3100, Loss: 3.8328
# Epoch   0 Batch   40/134 - Train Accuracy: 0.2809, Validation Accuracy: 0.3100, Loss: 3.6183
# Epoch   0 Batch   50/134 - Train Accuracy: 0.2871, Validation Accuracy: 0.3218, Loss: 3.4804
# Epoch   0 Batch   60/134 - Train Accuracy: 0.3084, Validation Accuracy: 0.3402, Loss: 3.3711
# Epoch   0 Batch   70/134 - Train Accuracy: 0.3125, Validation Accuracy: 0.3414, Loss: 3.2937
# Epoch   0 Batch   80/134 - Train Accuracy: 0.3052, Validation Accuracy: 0.3424, Loss: 3.2663
# Epoch   0 Batch   90/134 - Train Accuracy: 0.3135, Validation Accuracy: 0.3424, Loss: 3.1928
# Epoch   0 Batch  100/134 - Train Accuracy: 0.3084, Validation Accuracy: 0.3433, Loss: 3.1539
# Epoch   0 Batch  110/134 - Train Accuracy: 0.3161, Validation Accuracy: 0.3434, Loss: 3.0675
# Epoch   0 Batch  120/134 - Train Accuracy: 0.3125, Validation Accuracy: 0.3443, Loss: 3.0600
# Epoch   0 Batch  130/134 - Train Accuracy: 0.3056, Validation Accuracy: 0.3448, Loss: 3.0375
# Epoch   1 Batch   10/134 - Train Accuracy: 0.3147, Validation Accuracy: 0.3451, Loss: 2.9613
# Epoch   1 Batch   20/134 - Train Accuracy: 0.3572, Validation Accuracy: 0.3622, Loss: 2.8168
# Epoch   1 Batch   30/134 - Train Accuracy: 0.3725, Validation Accuracy: 0.3736, Loss: 2.7840
# Epoch   1 Batch   40/134 - Train Accuracy: 0.3481, Validation Accuracy: 0.3747, Loss: 2.8484
# Epoch   1 Batch   50/134 - Train Accuracy: 0.3505, Validation Accuracy: 0.3818, Loss: 2.8187
# Epoch   1 Batch   60/134 - Train Accuracy: 0.3560, Validation Accuracy: 0.3839, Loss: 2.7720
# Epoch   1 Batch   70/134 - Train Accuracy: 0.3567, Validation Accuracy: 0.3838, Loss: 2.7204
# Epoch   1 Batch   80/134 - Train Accuracy: 0.3485, Validation Accuracy: 0.3832, Loss: 2.7212
# Epoch   1 Batch   90/134 - Train Accuracy: 0.3690, Validation Accuracy: 0.3972, Loss: 2.6554
# Epoch   1 Batch  100/134 - Train Accuracy: 0.3856, Validation Accuracy: 0.4178, Loss: 2.6313
# Epoch   1 Batch  110/134 - Train Accuracy: 0.4010, Validation Accuracy: 0.4237, Loss: 2.5518
# Epoch   1 Batch  120/134 - Train Accuracy: 0.4023, Validation Accuracy: 0.4303, Loss: 2.5419
# Epoch   1 Batch  130/134 - Train Accuracy: 0.3997, Validation Accuracy: 0.4352, Loss: 2.5520
# Epoch   2 Batch   10/134 - Train Accuracy: 0.4126, Validation Accuracy: 0.4395, Loss: 2.4939
# Epoch   2 Batch   20/134 - Train Accuracy: 0.4440, Validation Accuracy: 0.4492, Loss: 2.3675
# Epoch   2 Batch   30/134 - Train Accuracy: 0.4490, Validation Accuracy: 0.4498, Loss: 2.3363
# Epoch   2 Batch   40/134 - Train Accuracy: 0.4349, Validation Accuracy: 0.4553, Loss: 2.3961
# Epoch   2 Batch   50/134 - Train Accuracy: 0.4306, Validation Accuracy: 0.4576, Loss: 2.3815
# Epoch   2 Batch   60/134 - Train Accuracy: 0.4294, Validation Accuracy: 0.4565, Loss: 2.3459
# Epoch   2 Batch   70/134 - Train Accuracy: 0.4327, Validation Accuracy: 0.4538, Loss: 2.3034
# Epoch   2 Batch   80/134 - Train Accuracy: 0.4185, Validation Accuracy: 0.4490, Loss: 2.3324
# Epoch   2 Batch   90/134 - Train Accuracy: 0.4208, Validation Accuracy: 0.4484, Loss: 2.2837
# Epoch   2 Batch  100/134 - Train Accuracy: 0.4102, Validation Accuracy: 0.4420, Loss: 2.2884
# Epoch   2 Batch  110/134 - Train Accuracy: 0.4293, Validation Accuracy: 0.4512, Loss: 2.2083
# Epoch   2 Batch  120/134 - Train Accuracy: 0.4115, Validation Accuracy: 0.4364, Loss: 2.2057
# Epoch   2 Batch  130/134 - Train Accuracy: 0.4071, Validation Accuracy: 0.4387, Loss: 2.2204
# Epoch   3 Batch   10/134 - Train Accuracy: 0.4324, Validation Accuracy: 0.4560, Loss: 2.1751
# Epoch   3 Batch   20/134 - Train Accuracy: 0.4432, Validation Accuracy: 0.4502, Loss: 2.0602
# Epoch   3 Batch   30/134 - Train Accuracy: 0.4488, Validation Accuracy: 0.4486, Loss: 2.0320
# Epoch   3 Batch   40/134 - Train Accuracy: 0.4182, Validation Accuracy: 0.4427, Loss: 2.0862
# Epoch   3 Batch   50/134 - Train Accuracy: 0.4232, Validation Accuracy: 0.4495, Loss: 2.0735
# Epoch   3 Batch   60/134 - Train Accuracy: 0.4217, Validation Accuracy: 0.4474, Loss: 2.0401
# Epoch   3 Batch   70/134 - Train Accuracy: 0.4151, Validation Accuracy: 0.4453, Loss: 2.0051
# Epoch   3 Batch   80/134 - Train Accuracy: 0.4109, Validation Accuracy: 0.4439, Loss: 2.0327
# Epoch   3 Batch   90/134 - Train Accuracy: 0.4221, Validation Accuracy: 0.4497, Loss: 1.9703
# Epoch   3 Batch  100/134 - Train Accuracy: 0.4320, Validation Accuracy: 0.4575, Loss: 1.9639
# Epoch   3 Batch  110/134 - Train Accuracy: 0.4515, Validation Accuracy: 0.4687, Loss: 1.8875
# Epoch   3 Batch  120/134 - Train Accuracy: 0.4510, Validation Accuracy: 0.4717, Loss: 1.8809
# Epoch   3 Batch  130/134 - Train Accuracy: 0.4536, Validation Accuracy: 0.4834, Loss: 1.8850
# Epoch   4 Batch   10/134 - Train Accuracy: 0.4586, Validation Accuracy: 0.4842, Loss: 1.8344
# Epoch   4 Batch   20/134 - Train Accuracy: 0.4803, Validation Accuracy: 0.4885, Loss: 1.7283
# Epoch   4 Batch   30/134 - Train Accuracy: 0.4960, Validation Accuracy: 0.4938, Loss: 1.6989
# Epoch   4 Batch   40/134 - Train Accuracy: 0.4638, Validation Accuracy: 0.4878, Loss: 1.7361
# Epoch   4 Batch   50/134 - Train Accuracy: 0.4589, Validation Accuracy: 0.4848, Loss: 1.7149
# Epoch   4 Batch   60/134 - Train Accuracy: 0.4816, Validation Accuracy: 0.5051, Loss: 1.6744
# Epoch   4 Batch   70/134 - Train Accuracy: 0.4814, Validation Accuracy: 0.5019, Loss: 1.6270
# Epoch   4 Batch   80/134 - Train Accuracy: 0.4845, Validation Accuracy: 0.5148, Loss: 1.6425
# Epoch   4 Batch   90/134 - Train Accuracy: 0.4771, Validation Accuracy: 0.5105, Loss: 1.5980
# Epoch   4 Batch  100/134 - Train Accuracy: 0.4753, Validation Accuracy: 0.5104, Loss: 1.5825
# Epoch   4 Batch  110/134 - Train Accuracy: 0.4861, Validation Accuracy: 0.5094, Loss: 1.5145
# Epoch   4 Batch  120/134 - Train Accuracy: 0.4730, Validation Accuracy: 0.4986, Loss: 1.5070
# Epoch   4 Batch  130/134 - Train Accuracy: 0.4549, Validation Accuracy: 0.4860, Loss: 1.5068
# Epoch   5 Batch   10/134 - Train Accuracy: 0.4262, Validation Accuracy: 0.4577, Loss: 1.4637
# Epoch   5 Batch   20/134 - Train Accuracy: 0.4522, Validation Accuracy: 0.4628, Loss: 1.3728
# Epoch   5 Batch   30/134 - Train Accuracy: 0.4563, Validation Accuracy: 0.4584, Loss: 1.3535
# Epoch   5 Batch   40/134 - Train Accuracy: 0.4210, Validation Accuracy: 0.4374, Loss: 1.3806
# Epoch   5 Batch   50/134 - Train Accuracy: 0.4015, Validation Accuracy: 0.4399, Loss: 1.3679
# Epoch   5 Batch   60/134 - Train Accuracy: 0.4071, Validation Accuracy: 0.4377, Loss: 1.3370
# Epoch   5 Batch   70/134 - Train Accuracy: 0.4194, Validation Accuracy: 0.4339, Loss: 1.3047
# Epoch   5 Batch   80/134 - Train Accuracy: 0.3843, Validation Accuracy: 0.4266, Loss: 1.3243
# Epoch   5 Batch   90/134 - Train Accuracy: 0.3918, Validation Accuracy: 0.4136, Loss: 1.2993
# Epoch   5 Batch  100/134 - Train Accuracy: 0.3943, Validation Accuracy: 0.4236, Loss: 1.2886
# Epoch   5 Batch  110/134 - Train Accuracy: 0.3810, Validation Accuracy: 0.4055, Loss: 1.2345
# Epoch   5 Batch  120/134 - Train Accuracy: 0.3883, Validation Accuracy: 0.4060, Loss: 1.2373
# Epoch   5 Batch  130/134 - Train Accuracy: 0.3809, Validation Accuracy: 0.4169, Loss: 1.2411
# Epoch   6 Batch   10/134 - Train Accuracy: 0.3854, Validation Accuracy: 0.4152, Loss: 1.2124
# Epoch   6 Batch   20/134 - Train Accuracy: 0.3994, Validation Accuracy: 0.4072, Loss: 1.1441
# Epoch   6 Batch   30/134 - Train Accuracy: 0.4276, Validation Accuracy: 0.4209, Loss: 1.1290
# Epoch   6 Batch   40/134 - Train Accuracy: 0.3957, Validation Accuracy: 0.4175, Loss: 1.1553
# Epoch   6 Batch   50/134 - Train Accuracy: 0.3820, Validation Accuracy: 0.4159, Loss: 1.1474
# Epoch   6 Batch   60/134 - Train Accuracy: 0.3751, Validation Accuracy: 0.4030, Loss: 1.1229
# Epoch   6 Batch   70/134 - Train Accuracy: 0.3830, Validation Accuracy: 0.3967, Loss: 1.0986
# Epoch   6 Batch   80/134 - Train Accuracy: 0.3576, Validation Accuracy: 0.3951, Loss: 1.1181
# Epoch   6 Batch   90/134 - Train Accuracy: 0.3753, Validation Accuracy: 0.4013, Loss: 1.1025
# Epoch   6 Batch  100/134 - Train Accuracy: 0.3768, Validation Accuracy: 0.4088, Loss: 1.0912
# Epoch   6 Batch  110/134 - Train Accuracy: 0.3796, Validation Accuracy: 0.4006, Loss: 1.0477
# Epoch   6 Batch  120/134 - Train Accuracy: 0.3840, Validation Accuracy: 0.3981, Loss: 1.0540
# Epoch   6 Batch  130/134 - Train Accuracy: 0.3547, Validation Accuracy: 0.3928, Loss: 1.0576
# Epoch   7 Batch   10/134 - Train Accuracy: 0.3697, Validation Accuracy: 0.4002, Loss: 1.0353
# Epoch   7 Batch   20/134 - Train Accuracy: 0.3911, Validation Accuracy: 0.3948, Loss: 0.9821
# Epoch   7 Batch   30/134 - Train Accuracy: 0.4192, Validation Accuracy: 0.4061, Loss: 0.9689
# Epoch   7 Batch   40/134 - Train Accuracy: 0.4076, Validation Accuracy: 0.4192, Loss: 0.9958
# Epoch   7 Batch   50/134 - Train Accuracy: 0.3836, Validation Accuracy: 0.4150, Loss: 0.9926
# Epoch   7 Batch   60/134 - Train Accuracy: 0.3929, Validation Accuracy: 0.4213, Loss: 0.9732
# Epoch   7 Batch   70/134 - Train Accuracy: 0.4138, Validation Accuracy: 0.4248, Loss: 0.9520
# Epoch   7 Batch   80/134 - Train Accuracy: 0.3864, Validation Accuracy: 0.4196, Loss: 0.9709
# Epoch   7 Batch   90/134 - Train Accuracy: 0.4171, Validation Accuracy: 0.4326, Loss: 0.9627
# Epoch   7 Batch  100/134 - Train Accuracy: 0.4082, Validation Accuracy: 0.4370, Loss: 0.9497
# Epoch   7 Batch  110/134 - Train Accuracy: 0.4160, Validation Accuracy: 0.4341, Loss: 0.9186
# Epoch   7 Batch  120/134 - Train Accuracy: 0.4152, Validation Accuracy: 0.4344, Loss: 0.9260
# Epoch   7 Batch  130/134 - Train Accuracy: 0.4133, Validation Accuracy: 0.4442, Loss: 0.9295
# Epoch   8 Batch   10/134 - Train Accuracy: 0.4156, Validation Accuracy: 0.4411, Loss: 0.9099
# Epoch   8 Batch   20/134 - Train Accuracy: 0.4408, Validation Accuracy: 0.4415, Loss: 0.8670
# Epoch   8 Batch   30/134 - Train Accuracy: 0.4642, Validation Accuracy: 0.4531, Loss: 0.8532
# Epoch   8 Batch   40/134 - Train Accuracy: 0.4565, Validation Accuracy: 0.4602, Loss: 0.8790
# Epoch   8 Batch   50/134 - Train Accuracy: 0.4358, Validation Accuracy: 0.4581, Loss: 0.8791
# Epoch   8 Batch   60/134 - Train Accuracy: 0.4417, Validation Accuracy: 0.4625, Loss: 0.8625
# Epoch   8 Batch   70/134 - Train Accuracy: 0.4656, Validation Accuracy: 0.4691, Loss: 0.8456
# Epoch   8 Batch   80/134 - Train Accuracy: 0.4342, Validation Accuracy: 0.4650, Loss: 0.8641
# Epoch   8 Batch   90/134 - Train Accuracy: 0.4583, Validation Accuracy: 0.4692, Loss: 0.8577
# Epoch   8 Batch  100/134 - Train Accuracy: 0.4502, Validation Accuracy: 0.4738, Loss: 0.8466
# Epoch   8 Batch  110/134 - Train Accuracy: 0.4521, Validation Accuracy: 0.4698, Loss: 0.8208
# Epoch   8 Batch  120/134 - Train Accuracy: 0.4560, Validation Accuracy: 0.4699, Loss: 0.8325
# Epoch   8 Batch  130/134 - Train Accuracy: 0.4563, Validation Accuracy: 0.4821, Loss: 0.8340
# Epoch   9 Batch   10/134 - Train Accuracy: 0.4730, Validation Accuracy: 0.4884, Loss: 0.8156
# Epoch   9 Batch   20/134 - Train Accuracy: 0.4786, Validation Accuracy: 0.4795, Loss: 0.7813
# Epoch   9 Batch   30/134 - Train Accuracy: 0.5095, Validation Accuracy: 0.4895, Loss: 0.7692
# Epoch   9 Batch   40/134 - Train Accuracy: 0.4921, Validation Accuracy: 0.4946, Loss: 0.7906
# Epoch   9 Batch   50/134 - Train Accuracy: 0.4823, Validation Accuracy: 0.5014, Loss: 0.7956
# Epoch   9 Batch   60/134 - Train Accuracy: 0.4851, Validation Accuracy: 0.4983, Loss: 0.7816
# Epoch   9 Batch   70/134 - Train Accuracy: 0.4940, Validation Accuracy: 0.4969, Loss: 0.7647
# Epoch   9 Batch   80/134 - Train Accuracy: 0.4803, Validation Accuracy: 0.5017, Loss: 0.7816
# Epoch   9 Batch   90/134 - Train Accuracy: 0.4967, Validation Accuracy: 0.5011, Loss: 0.7762
# Epoch   9 Batch  100/134 - Train Accuracy: 0.4942, Validation Accuracy: 0.5145, Loss: 0.7658
# Epoch   9 Batch  110/134 - Train Accuracy: 0.4938, Validation Accuracy: 0.5050, Loss: 0.7445
# Epoch   9 Batch  120/134 - Train Accuracy: 0.4967, Validation Accuracy: 0.5097, Loss: 0.7533
# Epoch   9 Batch  130/134 - Train Accuracy: 0.4989, Validation Accuracy: 0.5150, Loss: 0.7549
# Epoch  10 Batch   10/134 - Train Accuracy: 0.5053, Validation Accuracy: 0.5197, Loss: 0.7368
# Epoch  10 Batch   20/134 - Train Accuracy: 0.5245, Validation Accuracy: 0.5239, Loss: 0.7067
# Epoch  10 Batch   30/134 - Train Accuracy: 0.5660, Validation Accuracy: 0.5476, Loss: 0.6949
# Epoch  10 Batch   40/134 - Train Accuracy: 0.5511, Validation Accuracy: 0.5546, Loss: 0.7160
# Epoch  10 Batch   50/134 - Train Accuracy: 0.5514, Validation Accuracy: 0.5725, Loss: 0.7221
# Epoch  10 Batch   60/134 - Train Accuracy: 0.5665, Validation Accuracy: 0.5870, Loss: 0.7088
# Epoch  10 Batch   70/134 - Train Accuracy: 0.5881, Validation Accuracy: 0.5898, Loss: 0.6952
# Epoch  10 Batch   80/134 - Train Accuracy: 0.5850, Validation Accuracy: 0.6051, Loss: 0.7092
# Epoch  10 Batch   90/134 - Train Accuracy: 0.5865, Validation Accuracy: 0.6036, Loss: 0.7043
# Epoch  10 Batch  100/134 - Train Accuracy: 0.6027, Validation Accuracy: 0.6131, Loss: 0.6976
# Epoch  10 Batch  110/134 - Train Accuracy: 0.6188, Validation Accuracy: 0.6115, Loss: 0.6792
# Epoch  10 Batch  120/134 - Train Accuracy: 0.5997, Validation Accuracy: 0.6114, Loss: 0.6892
# Epoch  10 Batch  130/134 - Train Accuracy: 0.6011, Validation Accuracy: 0.6194, Loss: 0.6897
# Epoch  11 Batch   10/134 - Train Accuracy: 0.6117, Validation Accuracy: 0.6160, Loss: 0.6761
# Epoch  11 Batch   20/134 - Train Accuracy: 0.6270, Validation Accuracy: 0.6236, Loss: 0.6500
# Epoch  11 Batch   30/134 - Train Accuracy: 0.6290, Validation Accuracy: 0.6245, Loss: 0.6371
# Epoch  11 Batch   40/134 - Train Accuracy: 0.6170, Validation Accuracy: 0.6233, Loss: 0.6577
# Epoch  11 Batch   50/134 - Train Accuracy: 0.6041, Validation Accuracy: 0.6246, Loss: 0.6626
# Epoch  11 Batch   60/134 - Train Accuracy: 0.6096, Validation Accuracy: 0.6265, Loss: 0.6533
# Epoch  11 Batch   70/134 - Train Accuracy: 0.6286, Validation Accuracy: 0.6282, Loss: 0.6409
# Epoch  11 Batch   80/134 - Train Accuracy: 0.6177, Validation Accuracy: 0.6336, Loss: 0.6532
# Epoch  11 Batch   90/134 - Train Accuracy: 0.6176, Validation Accuracy: 0.6350, Loss: 0.6496
# Epoch  11 Batch  100/134 - Train Accuracy: 0.6216, Validation Accuracy: 0.6345, Loss: 0.6429
# Epoch  11 Batch  110/134 - Train Accuracy: 0.6458, Validation Accuracy: 0.6340, Loss: 0.6292
# Epoch  11 Batch  120/134 - Train Accuracy: 0.6285, Validation Accuracy: 0.6393, Loss: 0.6370
# Epoch  11 Batch  130/134 - Train Accuracy: 0.6267, Validation Accuracy: 0.6404, Loss: 0.6366
# Epoch  12 Batch   10/134 - Train Accuracy: 0.6348, Validation Accuracy: 0.6369, Loss: 0.6246
# Epoch  12 Batch   20/134 - Train Accuracy: 0.6493, Validation Accuracy: 0.6434, Loss: 0.6017
# Epoch  12 Batch   30/134 - Train Accuracy: 0.6524, Validation Accuracy: 0.6460, Loss: 0.5912
# Epoch  12 Batch   40/134 - Train Accuracy: 0.6340, Validation Accuracy: 0.6431, Loss: 0.6107
# Epoch  12 Batch   50/134 - Train Accuracy: 0.6318, Validation Accuracy: 0.6479, Loss: 0.6144
# Epoch  12 Batch   60/134 - Train Accuracy: 0.6205, Validation Accuracy: 0.6458, Loss: 0.6043
# Epoch  12 Batch   70/134 - Train Accuracy: 0.6503, Validation Accuracy: 0.6499, Loss: 0.5955
# Epoch  12 Batch   80/134 - Train Accuracy: 0.6308, Validation Accuracy: 0.6539, Loss: 0.6050
# Epoch  12 Batch   90/134 - Train Accuracy: 0.6411, Validation Accuracy: 0.6538, Loss: 0.6025
# Epoch  12 Batch  100/134 - Train Accuracy: 0.6405, Validation Accuracy: 0.6559, Loss: 0.5954
# Epoch  12 Batch  110/134 - Train Accuracy: 0.6640, Validation Accuracy: 0.6547, Loss: 0.5836
# Epoch  12 Batch  120/134 - Train Accuracy: 0.6465, Validation Accuracy: 0.6570, Loss: 0.5906
# Epoch  12 Batch  130/134 - Train Accuracy: 0.6481, Validation Accuracy: 0.6578, Loss: 0.5897
# Epoch  13 Batch   10/134 - Train Accuracy: 0.6476, Validation Accuracy: 0.6534, Loss: 0.5804
# Epoch  13 Batch   20/134 - Train Accuracy: 0.6625, Validation Accuracy: 0.6642, Loss: 0.5562
# Epoch  13 Batch   30/134 - Train Accuracy: 0.6661, Validation Accuracy: 0.6647, Loss: 0.5489
# Epoch  13 Batch   40/134 - Train Accuracy: 0.6540, Validation Accuracy: 0.6644, Loss: 0.5671
# Epoch  13 Batch   50/134 - Train Accuracy: 0.6416, Validation Accuracy: 0.6664, Loss: 0.5709
# Epoch  13 Batch   60/134 - Train Accuracy: 0.6363, Validation Accuracy: 0.6610, Loss: 0.5595
# Epoch  13 Batch   70/134 - Train Accuracy: 0.6656, Validation Accuracy: 0.6678, Loss: 0.5532
# Epoch  13 Batch   80/134 - Train Accuracy: 0.6468, Validation Accuracy: 0.6665, Loss: 0.5610
# Epoch  13 Batch   90/134 - Train Accuracy: 0.6509, Validation Accuracy: 0.6627, Loss: 0.5564
# Epoch  13 Batch  100/134 - Train Accuracy: 0.6535, Validation Accuracy: 0.6687, Loss: 0.5508
# Epoch  13 Batch  110/134 - Train Accuracy: 0.6707, Validation Accuracy: 0.6683, Loss: 0.5418
# Epoch  13 Batch  120/134 - Train Accuracy: 0.6526, Validation Accuracy: 0.6693, Loss: 0.5475
# Epoch  13 Batch  130/134 - Train Accuracy: 0.6630, Validation Accuracy: 0.6696, Loss: 0.5453
# Epoch  14 Batch   10/134 - Train Accuracy: 0.6666, Validation Accuracy: 0.6700, Loss: 0.5392
# Epoch  14 Batch   20/134 - Train Accuracy: 0.6748, Validation Accuracy: 0.6767, Loss: 0.5148
# Epoch  14 Batch   30/134 - Train Accuracy: 0.6828, Validation Accuracy: 0.6748, Loss: 0.5087
# Epoch  14 Batch   40/134 - Train Accuracy: 0.6577, Validation Accuracy: 0.6605, Loss: 0.5258
# Epoch  14 Batch   50/134 - Train Accuracy: 0.6571, Validation Accuracy: 0.6764, Loss: 0.5335
# Epoch  14 Batch   60/134 - Train Accuracy: 0.6455, Validation Accuracy: 0.6733, Loss: 0.5210
# Epoch  14 Batch   70/134 - Train Accuracy: 0.6733, Validation Accuracy: 0.6747, Loss: 0.5143
# Epoch  14 Batch   80/134 - Train Accuracy: 0.6538, Validation Accuracy: 0.6797, Loss: 0.5230
# Epoch  14 Batch   90/134 - Train Accuracy: 0.6661, Validation Accuracy: 0.6805, Loss: 0.5195
# Epoch  14 Batch  100/134 - Train Accuracy: 0.6614, Validation Accuracy: 0.6841, Loss: 0.5155
# Epoch  14 Batch  110/134 - Train Accuracy: 0.6859, Validation Accuracy: 0.6833, Loss: 0.5035
# Epoch  14 Batch  120/134 - Train Accuracy: 0.6651, Validation Accuracy: 0.6780, Loss: 0.5102
# Epoch  14 Batch  130/134 - Train Accuracy: 0.6702, Validation Accuracy: 0.6851, Loss: 0.5089
# Epoch  15 Batch   10/134 - Train Accuracy: 0.6787, Validation Accuracy: 0.6843, Loss: 0.5024
# Epoch  15 Batch   20/134 - Train Accuracy: 0.6908, Validation Accuracy: 0.6859, Loss: 0.4805
# Epoch  15 Batch   30/134 - Train Accuracy: 0.6905, Validation Accuracy: 0.6828, Loss: 0.4763
# Epoch  15 Batch   40/134 - Train Accuracy: 0.6815, Validation Accuracy: 0.6867, Loss: 0.4968
# Epoch  15 Batch   50/134 - Train Accuracy: 0.6650, Validation Accuracy: 0.6917, Loss: 0.4965
# Epoch  15 Batch   60/134 - Train Accuracy: 0.6592, Validation Accuracy: 0.6900, Loss: 0.4852
# Epoch  15 Batch   70/134 - Train Accuracy: 0.6877, Validation Accuracy: 0.6887, Loss: 0.4816
# Epoch  15 Batch   80/134 - Train Accuracy: 0.6564, Validation Accuracy: 0.6917, Loss: 0.4885
# Epoch  15 Batch   90/134 - Train Accuracy: 0.6789, Validation Accuracy: 0.6918, Loss: 0.4866
# Epoch  15 Batch  100/134 - Train Accuracy: 0.6662, Validation Accuracy: 0.6911, Loss: 0.4825
# Epoch  15 Batch  110/134 - Train Accuracy: 0.6894, Validation Accuracy: 0.6875, Loss: 0.4740
# Epoch  15 Batch  120/134 - Train Accuracy: 0.6721, Validation Accuracy: 0.6930, Loss: 0.4779
# Epoch  15 Batch  130/134 - Train Accuracy: 0.6716, Validation Accuracy: 0.6908, Loss: 0.4769
# Epoch  16 Batch   10/134 - Train Accuracy: 0.6824, Validation Accuracy: 0.6909, Loss: 0.4727
# Epoch  16 Batch   20/134 - Train Accuracy: 0.6897, Validation Accuracy: 0.6974, Loss: 0.4510
# Epoch  16 Batch   30/134 - Train Accuracy: 0.7029, Validation Accuracy: 0.6878, Loss: 0.4480
# Epoch  16 Batch   40/134 - Train Accuracy: 0.6886, Validation Accuracy: 0.6909, Loss: 0.4646
# Epoch  16 Batch   50/134 - Train Accuracy: 0.6701, Validation Accuracy: 0.6977, Loss: 0.4659
# Epoch  16 Batch   60/134 - Train Accuracy: 0.6739, Validation Accuracy: 0.6940, Loss: 0.4577
# Epoch  16 Batch   70/134 - Train Accuracy: 0.6833, Validation Accuracy: 0.6990, Loss: 0.4546
# Epoch  16 Batch   80/134 - Train Accuracy: 0.6726, Validation Accuracy: 0.7037, Loss: 0.4606
# Epoch  16 Batch   90/134 - Train Accuracy: 0.6862, Validation Accuracy: 0.6958, Loss: 0.4602
# Epoch  16 Batch  100/134 - Train Accuracy: 0.6766, Validation Accuracy: 0.6957, Loss: 0.4543
# Epoch  16 Batch  110/134 - Train Accuracy: 0.6958, Validation Accuracy: 0.6978, Loss: 0.4473
# Epoch  16 Batch  120/134 - Train Accuracy: 0.6824, Validation Accuracy: 0.6951, Loss: 0.4511
# Epoch  16 Batch  130/134 - Train Accuracy: 0.6791, Validation Accuracy: 0.6970, Loss: 0.4516
# Epoch  17 Batch   10/134 - Train Accuracy: 0.6902, Validation Accuracy: 0.6955, Loss: 0.4458
# Epoch  17 Batch   20/134 - Train Accuracy: 0.6913, Validation Accuracy: 0.6979, Loss: 0.4264
# Epoch  17 Batch   30/134 - Train Accuracy: 0.7082, Validation Accuracy: 0.6949, Loss: 0.4246
# Epoch  17 Batch   40/134 - Train Accuracy: 0.6860, Validation Accuracy: 0.7031, Loss: 0.4383
# Epoch  17 Batch   50/134 - Train Accuracy: 0.6766, Validation Accuracy: 0.6985, Loss: 0.4398
# Epoch  17 Batch   60/134 - Train Accuracy: 0.6838, Validation Accuracy: 0.7021, Loss: 0.4310
# Epoch  17 Batch   70/134 - Train Accuracy: 0.6873, Validation Accuracy: 0.7009, Loss: 0.4304
# Epoch  17 Batch   80/134 - Train Accuracy: 0.6850, Validation Accuracy: 0.7039, Loss: 0.4344
# Epoch  17 Batch   90/134 - Train Accuracy: 0.6902, Validation Accuracy: 0.7025, Loss: 0.4372
# Epoch  17 Batch  100/134 - Train Accuracy: 0.6746, Validation Accuracy: 0.7014, Loss: 0.4287
# Epoch  17 Batch  110/134 - Train Accuracy: 0.7047, Validation Accuracy: 0.7035, Loss: 0.4217
# Epoch  17 Batch  120/134 - Train Accuracy: 0.6854, Validation Accuracy: 0.7063, Loss: 0.4266
# Epoch  17 Batch  130/134 - Train Accuracy: 0.6905, Validation Accuracy: 0.7029, Loss: 0.4277
# Epoch  18 Batch   10/134 - Train Accuracy: 0.6892, Validation Accuracy: 0.7056, Loss: 0.4232
# Epoch  18 Batch   20/134 - Train Accuracy: 0.6995, Validation Accuracy: 0.7079, Loss: 0.4049
# Epoch  18 Batch   30/134 - Train Accuracy: 0.7109, Validation Accuracy: 0.7037, Loss: 0.4016
# Epoch  18 Batch   40/134 - Train Accuracy: 0.6938, Validation Accuracy: 0.7021, Loss: 0.4166
# Epoch  18 Batch   50/134 - Train Accuracy: 0.6871, Validation Accuracy: 0.7097, Loss: 0.4182
# Epoch  18 Batch   60/134 - Train Accuracy: 0.6916, Validation Accuracy: 0.7055, Loss: 0.4085
# Epoch  18 Batch   70/134 - Train Accuracy: 0.6946, Validation Accuracy: 0.7097, Loss: 0.4110
# Epoch  18 Batch   80/134 - Train Accuracy: 0.6901, Validation Accuracy: 0.7077, Loss: 0.4116
# Epoch  18 Batch   90/134 - Train Accuracy: 0.6923, Validation Accuracy: 0.7096, Loss: 0.4158
# Epoch  18 Batch  100/134 - Train Accuracy: 0.6819, Validation Accuracy: 0.7117, Loss: 0.4075
# Epoch  18 Batch  110/134 - Train Accuracy: 0.7215, Validation Accuracy: 0.7063, Loss: 0.4017
# Epoch  18 Batch  120/134 - Train Accuracy: 0.6988, Validation Accuracy: 0.7111, Loss: 0.4072
# Epoch  18 Batch  130/134 - Train Accuracy: 0.7001, Validation Accuracy: 0.7090, Loss: 0.4044
# Epoch  19 Batch   10/134 - Train Accuracy: 0.6990, Validation Accuracy: 0.7093, Loss: 0.4035
# Epoch  19 Batch   20/134 - Train Accuracy: 0.7053, Validation Accuracy: 0.7106, Loss: 0.3811
# Epoch  19 Batch   30/134 - Train Accuracy: 0.7203, Validation Accuracy: 0.7127, Loss: 0.3816
# Epoch  19 Batch   40/134 - Train Accuracy: 0.7065, Validation Accuracy: 0.7114, Loss: 0.3946
# Epoch  19 Batch   50/134 - Train Accuracy: 0.6962, Validation Accuracy: 0.7120, Loss: 0.3986
# Epoch  19 Batch   60/134 - Train Accuracy: 0.6973, Validation Accuracy: 0.7081, Loss: 0.3889
# Epoch  19 Batch   70/134 - Train Accuracy: 0.7025, Validation Accuracy: 0.7087, Loss: 0.3889
# Epoch  19 Batch   80/134 - Train Accuracy: 0.7006, Validation Accuracy: 0.7115, Loss: 0.3930
# Epoch  19 Batch   90/134 - Train Accuracy: 0.6949, Validation Accuracy: 0.7124, Loss: 0.3916
# Epoch  19 Batch  100/134 - Train Accuracy: 0.6922, Validation Accuracy: 0.7150, Loss: 0.3903
# Epoch  19 Batch  110/134 - Train Accuracy: 0.7264, Validation Accuracy: 0.7183, Loss: 0.3831
# Epoch  19 Batch  120/134 - Train Accuracy: 0.7113, Validation Accuracy: 0.7277, Loss: 0.3843
# Epoch  19 Batch  130/134 - Train Accuracy: 0.7053, Validation Accuracy: 0.7204, Loss: 0.3869
# Epoch  20 Batch   10/134 - Train Accuracy: 0.7059, Validation Accuracy: 0.7102, Loss: 0.3842
# Epoch  20 Batch   20/134 - Train Accuracy: 0.7089, Validation Accuracy: 0.7208, Loss: 0.3642
# Epoch  20 Batch   30/134 - Train Accuracy: 0.7241, Validation Accuracy: 0.7243, Loss: 0.3638
# Epoch  20 Batch   40/134 - Train Accuracy: 0.7170, Validation Accuracy: 0.7266, Loss: 0.3762
# Epoch  20 Batch   50/134 - Train Accuracy: 0.7085, Validation Accuracy: 0.7311, Loss: 0.3761
# Epoch  20 Batch   60/134 - Train Accuracy: 0.7094, Validation Accuracy: 0.7314, Loss: 0.3698
# Epoch  20 Batch   70/134 - Train Accuracy: 0.7158, Validation Accuracy: 0.7329, Loss: 0.3704
# Epoch  20 Batch   80/134 - Train Accuracy: 0.7072, Validation Accuracy: 0.7265, Loss: 0.3737
# Epoch  20 Batch   90/134 - Train Accuracy: 0.7147, Validation Accuracy: 0.7351, Loss: 0.3747
# Epoch  20 Batch  100/134 - Train Accuracy: 0.7092, Validation Accuracy: 0.7322, Loss: 0.3677
# Epoch  20 Batch  110/134 - Train Accuracy: 0.7429, Validation Accuracy: 0.7374, Loss: 0.3624
# Epoch  20 Batch  120/134 - Train Accuracy: 0.7281, Validation Accuracy: 0.7326, Loss: 0.3653
# Epoch  20 Batch  130/134 - Train Accuracy: 0.7175, Validation Accuracy: 0.7308, Loss: 0.3636
# Epoch  21 Batch   10/134 - Train Accuracy: 0.7182, Validation Accuracy: 0.7275, Loss: 0.3626
# Epoch  21 Batch   20/134 - Train Accuracy: 0.7248, Validation Accuracy: 0.7344, Loss: 0.3468
# Epoch  21 Batch   30/134 - Train Accuracy: 0.7443, Validation Accuracy: 0.7360, Loss: 0.3444
# Epoch  21 Batch   40/134 - Train Accuracy: 0.7286, Validation Accuracy: 0.7434, Loss: 0.3570
# Epoch  21 Batch   50/134 - Train Accuracy: 0.7173, Validation Accuracy: 0.7359, Loss: 0.3593
# Epoch  21 Batch   60/134 - Train Accuracy: 0.7152, Validation Accuracy: 0.7425, Loss: 0.3512
# Epoch  21 Batch   70/134 - Train Accuracy: 0.7333, Validation Accuracy: 0.7456, Loss: 0.3526
# Epoch  21 Batch   80/134 - Train Accuracy: 0.7207, Validation Accuracy: 0.7399, Loss: 0.3541
# Epoch  21 Batch   90/134 - Train Accuracy: 0.7255, Validation Accuracy: 0.7433, Loss: 0.3548
# Epoch  21 Batch  100/134 - Train Accuracy: 0.7151, Validation Accuracy: 0.7436, Loss: 0.3514
# Epoch  21 Batch  110/134 - Train Accuracy: 0.7589, Validation Accuracy: 0.7456, Loss: 0.3440
# Epoch  21 Batch  120/134 - Train Accuracy: 0.7417, Validation Accuracy: 0.7502, Loss: 0.3469
# Epoch  21 Batch  130/134 - Train Accuracy: 0.7300, Validation Accuracy: 0.7484, Loss: 0.3479
# Epoch  22 Batch   10/134 - Train Accuracy: 0.7384, Validation Accuracy: 0.7438, Loss: 0.3453
# Epoch  22 Batch   20/134 - Train Accuracy: 0.7494, Validation Accuracy: 0.7515, Loss: 0.3292
# Epoch  22 Batch   30/134 - Train Accuracy: 0.7537, Validation Accuracy: 0.7554, Loss: 0.3282
# Epoch  22 Batch   40/134 - Train Accuracy: 0.7408, Validation Accuracy: 0.7547, Loss: 0.3397
# Epoch  22 Batch   50/134 - Train Accuracy: 0.7291, Validation Accuracy: 0.7475, Loss: 0.3417
# Epoch  22 Batch   60/134 - Train Accuracy: 0.7309, Validation Accuracy: 0.7577, Loss: 0.3324
# Epoch  22 Batch   70/134 - Train Accuracy: 0.7458, Validation Accuracy: 0.7522, Loss: 0.3339
# Epoch  22 Batch   80/134 - Train Accuracy: 0.7295, Validation Accuracy: 0.7584, Loss: 0.3363
# Epoch  22 Batch   90/134 - Train Accuracy: 0.7458, Validation Accuracy: 0.7570, Loss: 0.3361
# Epoch  22 Batch  100/134 - Train Accuracy: 0.7255, Validation Accuracy: 0.7551, Loss: 0.3326
# Epoch  22 Batch  110/134 - Train Accuracy: 0.7639, Validation Accuracy: 0.7566, Loss: 0.3255
# Epoch  22 Batch  120/134 - Train Accuracy: 0.7540, Validation Accuracy: 0.7594, Loss: 0.3293
# Epoch  22 Batch  130/134 - Train Accuracy: 0.7494, Validation Accuracy: 0.7594, Loss: 0.3290
# Epoch  23 Batch   10/134 - Train Accuracy: 0.7573, Validation Accuracy: 0.7571, Loss: 0.3263
# Epoch  23 Batch   20/134 - Train Accuracy: 0.7563, Validation Accuracy: 0.7560, Loss: 0.3118
# Epoch  23 Batch   30/134 - Train Accuracy: 0.7676, Validation Accuracy: 0.7638, Loss: 0.3105
# Epoch  23 Batch   40/134 - Train Accuracy: 0.7565, Validation Accuracy: 0.7608, Loss: 0.3227
# Epoch  23 Batch   50/134 - Train Accuracy: 0.7427, Validation Accuracy: 0.7608, Loss: 0.3242
# Epoch  23 Batch   60/134 - Train Accuracy: 0.7465, Validation Accuracy: 0.7580, Loss: 0.3171
# Epoch  23 Batch   70/134 - Train Accuracy: 0.7640, Validation Accuracy: 0.7632, Loss: 0.3193
# Epoch  23 Batch   80/134 - Train Accuracy: 0.7454, Validation Accuracy: 0.7695, Loss: 0.3223
# Epoch  23 Batch   90/134 - Train Accuracy: 0.7572, Validation Accuracy: 0.7649, Loss: 0.3228
# Epoch  23 Batch  100/134 - Train Accuracy: 0.7325, Validation Accuracy: 0.7632, Loss: 0.3175
# Epoch  23 Batch  110/134 - Train Accuracy: 0.7740, Validation Accuracy: 0.7630, Loss: 0.3101
# Epoch  23 Batch  120/134 - Train Accuracy: 0.7678, Validation Accuracy: 0.7695, Loss: 0.3169
# Epoch  23 Batch  130/134 - Train Accuracy: 0.7592, Validation Accuracy: 0.7602, Loss: 0.3119
# Epoch  24 Batch   10/134 - Train Accuracy: 0.7583, Validation Accuracy: 0.7627, Loss: 0.3151
# Epoch  24 Batch   20/134 - Train Accuracy: 0.7596, Validation Accuracy: 0.7627, Loss: 0.2960
# Epoch  24 Batch   30/134 - Train Accuracy: 0.7730, Validation Accuracy: 0.7672, Loss: 0.2936
# Epoch  24 Batch   40/134 - Train Accuracy: 0.7633, Validation Accuracy: 0.7625, Loss: 0.3059
# Epoch  24 Batch   50/134 - Train Accuracy: 0.7541, Validation Accuracy: 0.7687, Loss: 0.3079
# Epoch  24 Batch   60/134 - Train Accuracy: 0.7523, Validation Accuracy: 0.7639, Loss: 0.3014
# Epoch  24 Batch   70/134 - Train Accuracy: 0.7649, Validation Accuracy: 0.7688, Loss: 0.3025
# Epoch  24 Batch   80/134 - Train Accuracy: 0.7570, Validation Accuracy: 0.7720, Loss: 0.3063
# Epoch  24 Batch   90/134 - Train Accuracy: 0.7619, Validation Accuracy: 0.7648, Loss: 0.3063
# Epoch  24 Batch  100/134 - Train Accuracy: 0.7445, Validation Accuracy: 0.7653, Loss: 0.3012
# Epoch  24 Batch  110/134 - Train Accuracy: 0.7812, Validation Accuracy: 0.7684, Loss: 0.2926
# Epoch  24 Batch  120/134 - Train Accuracy: 0.7705, Validation Accuracy: 0.7689, Loss: 0.3015
# Epoch  24 Batch  130/134 - Train Accuracy: 0.7640, Validation Accuracy: 0.7680, Loss: 0.2975
# Epoch  25 Batch   10/134 - Train Accuracy: 0.7686, Validation Accuracy: 0.7718, Loss: 0.2964
# Epoch  25 Batch   20/134 - Train Accuracy: 0.7702, Validation Accuracy: 0.7719, Loss: 0.2816
# Epoch  25 Batch   30/134 - Train Accuracy: 0.7768, Validation Accuracy: 0.7733, Loss: 0.2806
# Epoch  25 Batch   40/134 - Train Accuracy: 0.7590, Validation Accuracy: 0.7689, Loss: 0.2921
# Epoch  25 Batch   50/134 - Train Accuracy: 0.7578, Validation Accuracy: 0.7654, Loss: 0.2941
# Epoch  25 Batch   60/134 - Train Accuracy: 0.7594, Validation Accuracy: 0.7710, Loss: 0.2861
# Epoch  25 Batch   70/134 - Train Accuracy: 0.7704, Validation Accuracy: 0.7703, Loss: 0.2876
# Epoch  25 Batch   80/134 - Train Accuracy: 0.7604, Validation Accuracy: 0.7741, Loss: 0.2888
# Epoch  25 Batch   90/134 - Train Accuracy: 0.7715, Validation Accuracy: 0.7726, Loss: 0.2900
# Epoch  25 Batch  100/134 - Train Accuracy: 0.7507, Validation Accuracy: 0.7691, Loss: 0.2892
# Epoch  25 Batch  110/134 - Train Accuracy: 0.7862, Validation Accuracy: 0.7725, Loss: 0.2807
# Epoch  25 Batch  120/134 - Train Accuracy: 0.7757, Validation Accuracy: 0.7749, Loss: 0.2859
# Epoch  25 Batch  130/134 - Train Accuracy: 0.7702, Validation Accuracy: 0.7751, Loss: 0.2815
# Epoch  26 Batch   10/134 - Train Accuracy: 0.7754, Validation Accuracy: 0.7753, Loss: 0.2851
# Epoch  26 Batch   20/134 - Train Accuracy: 0.7866, Validation Accuracy: 0.7757, Loss: 0.2687
# Epoch  26 Batch   30/134 - Train Accuracy: 0.7895, Validation Accuracy: 0.7778, Loss: 0.2665
# Epoch  26 Batch   40/134 - Train Accuracy: 0.7736, Validation Accuracy: 0.7751, Loss: 0.2772
# Epoch  26 Batch   50/134 - Train Accuracy: 0.7648, Validation Accuracy: 0.7712, Loss: 0.2795
# Epoch  26 Batch   60/134 - Train Accuracy: 0.7631, Validation Accuracy: 0.7741, Loss: 0.2748
# Epoch  26 Batch   70/134 - Train Accuracy: 0.7780, Validation Accuracy: 0.7756, Loss: 0.2741
# Epoch  26 Batch   80/134 - Train Accuracy: 0.7697, Validation Accuracy: 0.7748, Loss: 0.2779
# Epoch  26 Batch   90/134 - Train Accuracy: 0.7733, Validation Accuracy: 0.7743, Loss: 0.2831
# Epoch  26 Batch  100/134 - Train Accuracy: 0.7668, Validation Accuracy: 0.7766, Loss: 0.2758
# Epoch  26 Batch  110/134 - Train Accuracy: 0.7959, Validation Accuracy: 0.7788, Loss: 0.2666
# Epoch  26 Batch  120/134 - Train Accuracy: 0.7825, Validation Accuracy: 0.7785, Loss: 0.2726
# Epoch  26 Batch  130/134 - Train Accuracy: 0.7811, Validation Accuracy: 0.7805, Loss: 0.2710
# Epoch  27 Batch   10/134 - Train Accuracy: 0.7806, Validation Accuracy: 0.7754, Loss: 0.2745
# Epoch  27 Batch   20/134 - Train Accuracy: 0.7839, Validation Accuracy: 0.7782, Loss: 0.2580
# Epoch  27 Batch   30/134 - Train Accuracy: 0.7893, Validation Accuracy: 0.7817, Loss: 0.2558
# Epoch  27 Batch   40/134 - Train Accuracy: 0.7798, Validation Accuracy: 0.7809, Loss: 0.2660
# Epoch  27 Batch   50/134 - Train Accuracy: 0.7666, Validation Accuracy: 0.7787, Loss: 0.2669
# Epoch  27 Batch   60/134 - Train Accuracy: 0.7733, Validation Accuracy: 0.7821, Loss: 0.2622
# Epoch  27 Batch   70/134 - Train Accuracy: 0.7875, Validation Accuracy: 0.7799, Loss: 0.2618
# Epoch  27 Batch   80/134 - Train Accuracy: 0.7800, Validation Accuracy: 0.7835, Loss: 0.2631
# Epoch  27 Batch   90/134 - Train Accuracy: 0.7845, Validation Accuracy: 0.7805, Loss: 0.2652
# Epoch  27 Batch  100/134 - Train Accuracy: 0.7700, Validation Accuracy: 0.7827, Loss: 0.2628
# Epoch  27 Batch  110/134 - Train Accuracy: 0.8004, Validation Accuracy: 0.7808, Loss: 0.2570
# Epoch  27 Batch  120/134 - Train Accuracy: 0.7860, Validation Accuracy: 0.7789, Loss: 0.2637
# Epoch  27 Batch  130/134 - Train Accuracy: 0.7862, Validation Accuracy: 0.7809, Loss: 0.2617
# Epoch  28 Batch   10/134 - Train Accuracy: 0.7797, Validation Accuracy: 0.7801, Loss: 0.2633
# Epoch  28 Batch   20/134 - Train Accuracy: 0.7883, Validation Accuracy: 0.7861, Loss: 0.2463
# Epoch  28 Batch   30/134 - Train Accuracy: 0.7947, Validation Accuracy: 0.7856, Loss: 0.2443
# Epoch  28 Batch   40/134 - Train Accuracy: 0.7855, Validation Accuracy: 0.7877, Loss: 0.2546
# Epoch  28 Batch   50/134 - Train Accuracy: 0.7753, Validation Accuracy: 0.7853, Loss: 0.2559
# Epoch  28 Batch   60/134 - Train Accuracy: 0.7805, Validation Accuracy: 0.7876, Loss: 0.2513
# Epoch  28 Batch   70/134 - Train Accuracy: 0.7947, Validation Accuracy: 0.7862, Loss: 0.2496
# Epoch  28 Batch   80/134 - Train Accuracy: 0.7920, Validation Accuracy: 0.7897, Loss: 0.2517
# Epoch  28 Batch   90/134 - Train Accuracy: 0.7872, Validation Accuracy: 0.7897, Loss: 0.2531
# Epoch  28 Batch  100/134 - Train Accuracy: 0.7836, Validation Accuracy: 0.7886, Loss: 0.2526
# Epoch  28 Batch  110/134 - Train Accuracy: 0.8054, Validation Accuracy: 0.7869, Loss: 0.2455
# Epoch  28 Batch  120/134 - Train Accuracy: 0.7934, Validation Accuracy: 0.7904, Loss: 0.2510
# Epoch  28 Batch  130/134 - Train Accuracy: 0.7906, Validation Accuracy: 0.7917, Loss: 0.2467
# Epoch  29 Batch   10/134 - Train Accuracy: 0.7913, Validation Accuracy: 0.7868, Loss: 0.2473
# Epoch  29 Batch   20/134 - Train Accuracy: 0.7978, Validation Accuracy: 0.7900, Loss: 0.2364
# Epoch  29 Batch   30/134 - Train Accuracy: 0.8050, Validation Accuracy: 0.7971, Loss: 0.2331
# Epoch  29 Batch   40/134 - Train Accuracy: 0.7878, Validation Accuracy: 0.7919, Loss: 0.2427
# Epoch  29 Batch   50/134 - Train Accuracy: 0.7837, Validation Accuracy: 0.7910, Loss: 0.2449
# Epoch  29 Batch   60/134 - Train Accuracy: 0.7897, Validation Accuracy: 0.7906, Loss: 0.2401
# Epoch  29 Batch   70/134 - Train Accuracy: 0.7924, Validation Accuracy: 0.7905, Loss: 0.2387
# Epoch  29 Batch   80/134 - Train Accuracy: 0.7918, Validation Accuracy: 0.7912, Loss: 0.2418
# Epoch  29 Batch   90/134 - Train Accuracy: 0.7974, Validation Accuracy: 0.7989, Loss: 0.2447
# Epoch  29 Batch  100/134 - Train Accuracy: 0.7893, Validation Accuracy: 0.7941, Loss: 0.2410
# Epoch  29 Batch  110/134 - Train Accuracy: 0.8078, Validation Accuracy: 0.7922, Loss: 0.2345
# Epoch  29 Batch  120/134 - Train Accuracy: 0.7986, Validation Accuracy: 0.7955, Loss: 0.2422
# Epoch  29 Batch  130/134 - Train Accuracy: 0.7950, Validation Accuracy: 0.7962, Loss: 0.2359
# Epoch  30 Batch   10/134 - Train Accuracy: 0.7987, Validation Accuracy: 0.7957, Loss: 0.2392
# Epoch  30 Batch   20/134 - Train Accuracy: 0.8034, Validation Accuracy: 0.7996, Loss: 0.2267
# Epoch  30 Batch   30/134 - Train Accuracy: 0.8063, Validation Accuracy: 0.8007, Loss: 0.2269
# Epoch  30 Batch   40/134 - Train Accuracy: 0.7969, Validation Accuracy: 0.7956, Loss: 0.2338
# Epoch  30 Batch   50/134 - Train Accuracy: 0.7905, Validation Accuracy: 0.7964, Loss: 0.2364
# Epoch  30 Batch   60/134 - Train Accuracy: 0.7926, Validation Accuracy: 0.7947, Loss: 0.2332
# Epoch  30 Batch   70/134 - Train Accuracy: 0.8046, Validation Accuracy: 0.8014, Loss: 0.2274
# Epoch  30 Batch   80/134 - Train Accuracy: 0.7935, Validation Accuracy: 0.7975, Loss: 0.2316
# Epoch  30 Batch   90/134 - Train Accuracy: 0.8017, Validation Accuracy: 0.7960, Loss: 0.2332
# Epoch  30 Batch  100/134 - Train Accuracy: 0.7970, Validation Accuracy: 0.8062, Loss: 0.2336
# Epoch  30 Batch  110/134 - Train Accuracy: 0.8112, Validation Accuracy: 0.7968, Loss: 0.2247
# Epoch  30 Batch  120/134 - Train Accuracy: 0.8046, Validation Accuracy: 0.8012, Loss: 0.2310
# Epoch  30 Batch  130/134 - Train Accuracy: 0.8025, Validation Accuracy: 0.8031, Loss: 0.2285
# Epoch  31 Batch   10/134 - Train Accuracy: 0.8046, Validation Accuracy: 0.8022, Loss: 0.2280
# Epoch  31 Batch   20/134 - Train Accuracy: 0.8173, Validation Accuracy: 0.8080, Loss: 0.2178
# Epoch  31 Batch   30/134 - Train Accuracy: 0.8148, Validation Accuracy: 0.8078, Loss: 0.2137
# Epoch  31 Batch   40/134 - Train Accuracy: 0.8033, Validation Accuracy: 0.8031, Loss: 0.2208
# Epoch  31 Batch   50/134 - Train Accuracy: 0.7989, Validation Accuracy: 0.8088, Loss: 0.2258
# Epoch  31 Batch   60/134 - Train Accuracy: 0.8019, Validation Accuracy: 0.8092, Loss: 0.2222
# Epoch  31 Batch   70/134 - Train Accuracy: 0.8126, Validation Accuracy: 0.8041, Loss: 0.2204
# Epoch  31 Batch   80/134 - Train Accuracy: 0.8012, Validation Accuracy: 0.8073, Loss: 0.2262
# Epoch  31 Batch   90/134 - Train Accuracy: 0.8069, Validation Accuracy: 0.8079, Loss: 0.2250
# Epoch  31 Batch  100/134 - Train Accuracy: 0.8032, Validation Accuracy: 0.8090, Loss: 0.2210
# Epoch  31 Batch  110/134 - Train Accuracy: 0.8199, Validation Accuracy: 0.8100, Loss: 0.2159
# Epoch  31 Batch  120/134 - Train Accuracy: 0.8103, Validation Accuracy: 0.8129, Loss: 0.2244
# Epoch  31 Batch  130/134 - Train Accuracy: 0.8074, Validation Accuracy: 0.8088, Loss: 0.2177
# Epoch  32 Batch   10/134 - Train Accuracy: 0.8060, Validation Accuracy: 0.8128, Loss: 0.2218
# Epoch  32 Batch   20/134 - Train Accuracy: 0.8181, Validation Accuracy: 0.8106, Loss: 0.2106
# Epoch  32 Batch   30/134 - Train Accuracy: 0.8236, Validation Accuracy: 0.8146, Loss: 0.2072
# Epoch  32 Batch   40/134 - Train Accuracy: 0.8065, Validation Accuracy: 0.8119, Loss: 0.2145
# Epoch  32 Batch   50/134 - Train Accuracy: 0.8013, Validation Accuracy: 0.8134, Loss: 0.2177
# Epoch  32 Batch   60/134 - Train Accuracy: 0.8090, Validation Accuracy: 0.8182, Loss: 0.2142
# Epoch  32 Batch   70/134 - Train Accuracy: 0.8062, Validation Accuracy: 0.8141, Loss: 0.2126
# Epoch  32 Batch   80/134 - Train Accuracy: 0.8130, Validation Accuracy: 0.8192, Loss: 0.2142
# Epoch  32 Batch   90/134 - Train Accuracy: 0.8108, Validation Accuracy: 0.8146, Loss: 0.2159
# Epoch  32 Batch  100/134 - Train Accuracy: 0.8090, Validation Accuracy: 0.8236, Loss: 0.2156
# Epoch  32 Batch  110/134 - Train Accuracy: 0.8271, Validation Accuracy: 0.8171, Loss: 0.2091
# Epoch  32 Batch  120/134 - Train Accuracy: 0.8157, Validation Accuracy: 0.8180, Loss: 0.2150
# Epoch  32 Batch  130/134 - Train Accuracy: 0.8154, Validation Accuracy: 0.8204, Loss: 0.2096
# Epoch  33 Batch   10/134 - Train Accuracy: 0.8117, Validation Accuracy: 0.8163, Loss: 0.2148
# Epoch  33 Batch   20/134 - Train Accuracy: 0.8262, Validation Accuracy: 0.8164, Loss: 0.2029
# Epoch  33 Batch   30/134 - Train Accuracy: 0.8290, Validation Accuracy: 0.8219, Loss: 0.1987
# Epoch  33 Batch   40/134 - Train Accuracy: 0.8185, Validation Accuracy: 0.8188, Loss: 0.2066
# Epoch  33 Batch   50/134 - Train Accuracy: 0.8123, Validation Accuracy: 0.8225, Loss: 0.2090
# Epoch  33 Batch   60/134 - Train Accuracy: 0.8120, Validation Accuracy: 0.8211, Loss: 0.2062
# Epoch  33 Batch   70/134 - Train Accuracy: 0.8141, Validation Accuracy: 0.8236, Loss: 0.2040
# Epoch  33 Batch   80/134 - Train Accuracy: 0.8190, Validation Accuracy: 0.8215, Loss: 0.2045
# Epoch  33 Batch   90/134 - Train Accuracy: 0.8157, Validation Accuracy: 0.8187, Loss: 0.2088
# Epoch  33 Batch  100/134 - Train Accuracy: 0.8146, Validation Accuracy: 0.8269, Loss: 0.2055
# Epoch  33 Batch  110/134 - Train Accuracy: 0.8319, Validation Accuracy: 0.8176, Loss: 0.1984
# Epoch  33 Batch  120/134 - Train Accuracy: 0.8183, Validation Accuracy: 0.8238, Loss: 0.2074
# Epoch  33 Batch  130/134 - Train Accuracy: 0.8187, Validation Accuracy: 0.8281, Loss: 0.2015
# Epoch  34 Batch   10/134 - Train Accuracy: 0.8237, Validation Accuracy: 0.8240, Loss: 0.2053
# Epoch  34 Batch   20/134 - Train Accuracy: 0.8301, Validation Accuracy: 0.8271, Loss: 0.1946
# Epoch  34 Batch   30/134 - Train Accuracy: 0.8330, Validation Accuracy: 0.8243, Loss: 0.1921
# Epoch  34 Batch   40/134 - Train Accuracy: 0.8219, Validation Accuracy: 0.8238, Loss: 0.1969
# Epoch  34 Batch   50/134 - Train Accuracy: 0.8173, Validation Accuracy: 0.8284, Loss: 0.2022
# Epoch  34 Batch   60/134 - Train Accuracy: 0.8174, Validation Accuracy: 0.8301, Loss: 0.1977
# Epoch  34 Batch   70/134 - Train Accuracy: 0.8240, Validation Accuracy: 0.8282, Loss: 0.1955
# Epoch  34 Batch   80/134 - Train Accuracy: 0.8240, Validation Accuracy: 0.8263, Loss: 0.1985
# Epoch  34 Batch   90/134 - Train Accuracy: 0.8205, Validation Accuracy: 0.8291, Loss: 0.1988
# Epoch  34 Batch  100/134 - Train Accuracy: 0.8183, Validation Accuracy: 0.8263, Loss: 0.1981
# Epoch  34 Batch  110/134 - Train Accuracy: 0.8348, Validation Accuracy: 0.8251, Loss: 0.1936
# Epoch  34 Batch  120/134 - Train Accuracy: 0.8214, Validation Accuracy: 0.8280, Loss: 0.2040
# Epoch  34 Batch  130/134 - Train Accuracy: 0.8175, Validation Accuracy: 0.8267, Loss: 0.1945
# Epoch  35 Batch   10/134 - Train Accuracy: 0.8310, Validation Accuracy: 0.8296, Loss: 0.1991
# Epoch  35 Batch   20/134 - Train Accuracy: 0.8332, Validation Accuracy: 0.8326, Loss: 0.1876
# Epoch  35 Batch   30/134 - Train Accuracy: 0.8357, Validation Accuracy: 0.8326, Loss: 0.1865
# Epoch  35 Batch   40/134 - Train Accuracy: 0.8270, Validation Accuracy: 0.8290, Loss: 0.1910
# Epoch  35 Batch   50/134 - Train Accuracy: 0.8207, Validation Accuracy: 0.8299, Loss: 0.1942
# Epoch  35 Batch   60/134 - Train Accuracy: 0.8220, Validation Accuracy: 0.8270, Loss: 0.1909
# Epoch  35 Batch   70/134 - Train Accuracy: 0.8330, Validation Accuracy: 0.8327, Loss: 0.1895
# Epoch  35 Batch   80/134 - Train Accuracy: 0.8285, Validation Accuracy: 0.8319, Loss: 0.1890
# Epoch  35 Batch   90/134 - Train Accuracy: 0.8258, Validation Accuracy: 0.8294, Loss: 0.1941
# Epoch  35 Batch  100/134 - Train Accuracy: 0.8201, Validation Accuracy: 0.8305, Loss: 0.1913
# Epoch  35 Batch  110/134 - Train Accuracy: 0.8385, Validation Accuracy: 0.8299, Loss: 0.1880
# Epoch  35 Batch  120/134 - Train Accuracy: 0.8267, Validation Accuracy: 0.8324, Loss: 0.1946
# Epoch  35 Batch  130/134 - Train Accuracy: 0.8307, Validation Accuracy: 0.8364, Loss: 0.1866
# Epoch  36 Batch   10/134 - Train Accuracy: 0.8314, Validation Accuracy: 0.8297, Loss: 0.1913
# Epoch  36 Batch   20/134 - Train Accuracy: 0.8406, Validation Accuracy: 0.8293, Loss: 0.1792
# Epoch  36 Batch   30/134 - Train Accuracy: 0.8421, Validation Accuracy: 0.8377, Loss: 0.1797
# Epoch  36 Batch   40/134 - Train Accuracy: 0.8331, Validation Accuracy: 0.8360, Loss: 0.1828
# Epoch  36 Batch   50/134 - Train Accuracy: 0.8268, Validation Accuracy: 0.8339, Loss: 0.1865
# Epoch  36 Batch   60/134 - Train Accuracy: 0.8240, Validation Accuracy: 0.8307, Loss: 0.1843
# Epoch  36 Batch   70/134 - Train Accuracy: 0.8322, Validation Accuracy: 0.8347, Loss: 0.1835
# Epoch  36 Batch   80/134 - Train Accuracy: 0.8365, Validation Accuracy: 0.8389, Loss: 0.1828
# Epoch  36 Batch   90/134 - Train Accuracy: 0.8282, Validation Accuracy: 0.8328, Loss: 0.1869
# Epoch  36 Batch  100/134 - Train Accuracy: 0.8263, Validation Accuracy: 0.8362, Loss: 0.1852
# Epoch  36 Batch  110/134 - Train Accuracy: 0.8371, Validation Accuracy: 0.8279, Loss: 0.1809
# Epoch  36 Batch  120/134 - Train Accuracy: 0.8290, Validation Accuracy: 0.8358, Loss: 0.1867
# Epoch  36 Batch  130/134 - Train Accuracy: 0.8311, Validation Accuracy: 0.8331, Loss: 0.1796
# Epoch  37 Batch   10/134 - Train Accuracy: 0.8386, Validation Accuracy: 0.8352, Loss: 0.1859
# Epoch  37 Batch   20/134 - Train Accuracy: 0.8394, Validation Accuracy: 0.8341, Loss: 0.1750
# Epoch  37 Batch   30/134 - Train Accuracy: 0.8410, Validation Accuracy: 0.8347, Loss: 0.1716
# Epoch  37 Batch   40/134 - Train Accuracy: 0.8329, Validation Accuracy: 0.8389, Loss: 0.1766
# Epoch  37 Batch   50/134 - Train Accuracy: 0.8279, Validation Accuracy: 0.8366, Loss: 0.1823
# Epoch  37 Batch   60/134 - Train Accuracy: 0.8261, Validation Accuracy: 0.8424, Loss: 0.1773
# Epoch  37 Batch   70/134 - Train Accuracy: 0.8340, Validation Accuracy: 0.8359, Loss: 0.1769
# Epoch  37 Batch   80/134 - Train Accuracy: 0.8355, Validation Accuracy: 0.8426, Loss: 0.1804
# Epoch  37 Batch   90/134 - Train Accuracy: 0.8304, Validation Accuracy: 0.8376, Loss: 0.1813
# Epoch  37 Batch  100/134 - Train Accuracy: 0.8287, Validation Accuracy: 0.8386, Loss: 0.1784
# Epoch  37 Batch  110/134 - Train Accuracy: 0.8450, Validation Accuracy: 0.8343, Loss: 0.1733
# Epoch  37 Batch  120/134 - Train Accuracy: 0.8317, Validation Accuracy: 0.8359, Loss: 0.1802
# Epoch  37 Batch  130/134 - Train Accuracy: 0.8331, Validation Accuracy: 0.8445, Loss: 0.1776
# Epoch  38 Batch   10/134 - Train Accuracy: 0.8368, Validation Accuracy: 0.8392, Loss: 0.1763
# Epoch  38 Batch   20/134 - Train Accuracy: 0.8496, Validation Accuracy: 0.8363, Loss: 0.1697
# Epoch  38 Batch   30/134 - Train Accuracy: 0.8470, Validation Accuracy: 0.8401, Loss: 0.1660
# Epoch  38 Batch   40/134 - Train Accuracy: 0.8334, Validation Accuracy: 0.8385, Loss: 0.1703
# Epoch  38 Batch   50/134 - Train Accuracy: 0.8279, Validation Accuracy: 0.8362, Loss: 0.1738
# Epoch  38 Batch   60/134 - Train Accuracy: 0.8287, Validation Accuracy: 0.8413, Loss: 0.1740
# Epoch  38 Batch   70/134 - Train Accuracy: 0.8388, Validation Accuracy: 0.8406, Loss: 0.1685
# Epoch  38 Batch   80/134 - Train Accuracy: 0.8406, Validation Accuracy: 0.8366, Loss: 0.1727
# Epoch  38 Batch   90/134 - Train Accuracy: 0.8310, Validation Accuracy: 0.8356, Loss: 0.1777
# Epoch  38 Batch  100/134 - Train Accuracy: 0.8297, Validation Accuracy: 0.8393, Loss: 0.1750
# Epoch  38 Batch  110/134 - Train Accuracy: 0.8485, Validation Accuracy: 0.8394, Loss: 0.1684
# Epoch  38 Batch  120/134 - Train Accuracy: 0.8375, Validation Accuracy: 0.8415, Loss: 0.1772
# Epoch  38 Batch  130/134 - Train Accuracy: 0.8368, Validation Accuracy: 0.8411, Loss: 0.1698
# Epoch  39 Batch   10/134 - Train Accuracy: 0.8382, Validation Accuracy: 0.8382, Loss: 0.1720
# Epoch  39 Batch   20/134 - Train Accuracy: 0.8495, Validation Accuracy: 0.8386, Loss: 0.1606
# Epoch  39 Batch   30/134 - Train Accuracy: 0.8474, Validation Accuracy: 0.8429, Loss: 0.1607
# Epoch  39 Batch   40/134 - Train Accuracy: 0.8376, Validation Accuracy: 0.8414, Loss: 0.1649
# Epoch  39 Batch   50/134 - Train Accuracy: 0.8384, Validation Accuracy: 0.8411, Loss: 0.1695
# Epoch  39 Batch   60/134 - Train Accuracy: 0.8326, Validation Accuracy: 0.8450, Loss: 0.1653
# Epoch  39 Batch   70/134 - Train Accuracy: 0.8425, Validation Accuracy: 0.8430, Loss: 0.1671
# Epoch  39 Batch   80/134 - Train Accuracy: 0.8435, Validation Accuracy: 0.8450, Loss: 0.1670
# Epoch  39 Batch   90/134 - Train Accuracy: 0.8362, Validation Accuracy: 0.8431, Loss: 0.1713
# ...
# Epoch 136 Batch  120/134 - Train Accuracy: 0.9500, Validation Accuracy: 0.9544, Loss: 0.0319
# Epoch 136 Batch  130/134 - Train Accuracy: 0.9488, Validation Accuracy: 0.9546, Loss: 0.0299
# Epoch 137 Batch   10/134 - Train Accuracy: 0.9396, Validation Accuracy: 0.9526, Loss: 0.0309
# Epoch 137 Batch   20/134 - Train Accuracy: 0.9512, Validation Accuracy: 0.9544, Loss: 0.0269
# Epoch 137 Batch   30/134 - Train Accuracy: 0.9359, Validation Accuracy: 0.9519, Loss: 0.0329
# Epoch 137 Batch   40/134 - Train Accuracy: 0.9508, Validation Accuracy: 0.9531, Loss: 0.0291
# Epoch 137 Batch   50/134 - Train Accuracy: 0.9442, Validation Accuracy: 0.9494, Loss: 0.0329
# Epoch 137 Batch   60/134 - Train Accuracy: 0.9412, Validation Accuracy: 0.9521, Loss: 0.0297
# Epoch 137 Batch   70/134 - Train Accuracy: 0.9447, Validation Accuracy: 0.9522, Loss: 0.0315
# Epoch 137 Batch   80/134 - Train Accuracy: 0.9553, Validation Accuracy: 0.9552, Loss: 0.0305
# Epoch 137 Batch   90/134 - Train Accuracy: 0.9431, Validation Accuracy: 0.9502, Loss: 0.0307
# Epoch 137 Batch  100/134 - Train Accuracy: 0.9545, Validation Accuracy: 0.9532, Loss: 0.0323
# Epoch 137 Batch  110/134 - Train Accuracy: 0.9495, Validation Accuracy: 0.9533, Loss: 0.0293
# Epoch 137 Batch  120/134 - Train Accuracy: 0.9495, Validation Accuracy: 0.9551, Loss: 0.0323
# Epoch 137 Batch  130/134 - Train Accuracy: 0.9472, Validation Accuracy: 0.9552, Loss: 0.0286
# Epoch 138 Batch   10/134 - Train Accuracy: 0.9435, Validation Accuracy: 0.9590, Loss: 0.0330
# Epoch 138 Batch   20/134 - Train Accuracy: 0.9517, Validation Accuracy: 0.9511, Loss: 0.0283
# Epoch 138 Batch   30/134 - Train Accuracy: 0.9355, Validation Accuracy: 0.9521, Loss: 0.0323
# Epoch 138 Batch   40/134 - Train Accuracy: 0.9477, Validation Accuracy: 0.9522, Loss: 0.0290
# Epoch 138 Batch   50/134 - Train Accuracy: 0.9494, Validation Accuracy: 0.9548, Loss: 0.0332
# Epoch 138 Batch   60/134 - Train Accuracy: 0.9422, Validation Accuracy: 0.9498, Loss: 0.0289
# Epoch 138 Batch   70/134 - Train Accuracy: 0.9448, Validation Accuracy: 0.9542, Loss: 0.0316
# Epoch 138 Batch   80/134 - Train Accuracy: 0.9568, Validation Accuracy: 0.9555, Loss: 0.0296
# Epoch 138 Batch   90/134 - Train Accuracy: 0.9464, Validation Accuracy: 0.9495, Loss: 0.0314
# Epoch 138 Batch  100/134 - Train Accuracy: 0.9546, Validation Accuracy: 0.9538, Loss: 0.0314
# Epoch 138 Batch  110/134 - Train Accuracy: 0.9528, Validation Accuracy: 0.9524, Loss: 0.0283
# Epoch 138 Batch  120/134 - Train Accuracy: 0.9508, Validation Accuracy: 0.9565, Loss: 0.0300
# Epoch 138 Batch  130/134 - Train Accuracy: 0.9529, Validation Accuracy: 0.9552, Loss: 0.0282
# Epoch 139 Batch   10/134 - Train Accuracy: 0.9419, Validation Accuracy: 0.9569, Loss: 0.0323
# Epoch 139 Batch   20/134 - Train Accuracy: 0.9546, Validation Accuracy: 0.9550, Loss: 0.0265
# Epoch 139 Batch   30/134 - Train Accuracy: 0.9372, Validation Accuracy: 0.9533, Loss: 0.0298
# Epoch 139 Batch   40/134 - Train Accuracy: 0.9488, Validation Accuracy: 0.9500, Loss: 0.0272
# Epoch 139 Batch   50/134 - Train Accuracy: 0.9465, Validation Accuracy: 0.9555, Loss: 0.0317
# Epoch 139 Batch   60/134 - Train Accuracy: 0.9414, Validation Accuracy: 0.9490, Loss: 0.0305
# Epoch 139 Batch   70/134 - Train Accuracy: 0.9484, Validation Accuracy: 0.9530, Loss: 0.0315
# Epoch 139 Batch   80/134 - Train Accuracy: 0.9557, Validation Accuracy: 0.9504, Loss: 0.0279
# Epoch 139 Batch   90/134 - Train Accuracy: 0.9451, Validation Accuracy: 0.9545, Loss: 0.0301
# Epoch 139 Batch  100/134 - Train Accuracy: 0.9526, Validation Accuracy: 0.9546, Loss: 0.0325
# Epoch 139 Batch  110/134 - Train Accuracy: 0.9542, Validation Accuracy: 0.9526, Loss: 0.0295
# Epoch 139 Batch  120/134 - Train Accuracy: 0.9510, Validation Accuracy: 0.9552, Loss: 0.0308
# Epoch 139 Batch  130/134 - Train Accuracy: 0.9507, Validation Accuracy: 0.9574, Loss: 0.0276
# Epoch 140 Batch   10/134 - Train Accuracy: 0.9403, Validation Accuracy: 0.9590, Loss: 0.0316
# Epoch 140 Batch   20/134 - Train Accuracy: 0.9478, Validation Accuracy: 0.9541, Loss: 0.0274
# Epoch 140 Batch   30/134 - Train Accuracy: 0.9361, Validation Accuracy: 0.9555, Loss: 0.0321
# Epoch 140 Batch   40/134 - Train Accuracy: 0.9521, Validation Accuracy: 0.9496, Loss: 0.0273
# Epoch 140 Batch   50/134 - Train Accuracy: 0.9429, Validation Accuracy: 0.9540, Loss: 0.0319
# Epoch 140 Batch   60/134 - Train Accuracy: 0.9447, Validation Accuracy: 0.9520, Loss: 0.0292
# Epoch 140 Batch   70/134 - Train Accuracy: 0.9455, Validation Accuracy: 0.9547, Loss: 0.0317
# Epoch 140 Batch   80/134 - Train Accuracy: 0.8850, Validation Accuracy: 0.8829, Loss: 0.3230
# Epoch 140 Batch   90/134 - Train Accuracy: 0.8977, Validation Accuracy: 0.9070, Loss: 0.0917
# Epoch 140 Batch  100/134 - Train Accuracy: 0.9253, Validation Accuracy: 0.9324, Loss: 0.0657
# Epoch 140 Batch  110/134 - Train Accuracy: 0.9409, Validation Accuracy: 0.9457, Loss: 0.0437
# Epoch 140 Batch  120/134 - Train Accuracy: 0.9462, Validation Accuracy: 0.9463, Loss: 0.0367
# Epoch 140 Batch  130/134 - Train Accuracy: 0.9466, Validation Accuracy: 0.9490, Loss: 0.0326
# Epoch 141 Batch   10/134 - Train Accuracy: 0.9394, Validation Accuracy: 0.9558, Loss: 0.0316
# Epoch 141 Batch   20/134 - Train Accuracy: 0.9494, Validation Accuracy: 0.9544, Loss: 0.0270
# Epoch 141 Batch   30/134 - Train Accuracy: 0.9403, Validation Accuracy: 0.9531, Loss: 0.0320
# Epoch 141 Batch   40/134 - Train Accuracy: 0.9469, Validation Accuracy: 0.9539, Loss: 0.0290
# Epoch 141 Batch   50/134 - Train Accuracy: 0.9478, Validation Accuracy: 0.9545, Loss: 0.0315
# Epoch 141 Batch   60/134 - Train Accuracy: 0.9439, Validation Accuracy: 0.9515, Loss: 0.0284
# Epoch 141 Batch   70/134 - Train Accuracy: 0.9479, Validation Accuracy: 0.9541, Loss: 0.0313
# Epoch 141 Batch   80/134 - Train Accuracy: 0.9560, Validation Accuracy: 0.9554, Loss: 0.0295
# Epoch 141 Batch   90/134 - Train Accuracy: 0.9445, Validation Accuracy: 0.9546, Loss: 0.0316
# Epoch 141 Batch  100/134 - Train Accuracy: 0.9508, Validation Accuracy: 0.9568, Loss: 0.0330
# Epoch 141 Batch  110/134 - Train Accuracy: 0.9525, Validation Accuracy: 0.9532, Loss: 0.0277
# Epoch 141 Batch  120/134 - Train Accuracy: 0.9480, Validation Accuracy: 0.9542, Loss: 0.0298
# Epoch 141 Batch  130/134 - Train Accuracy: 0.9507, Validation Accuracy: 0.9558, Loss: 0.0280
# Epoch 142 Batch   10/134 - Train Accuracy: 0.9400, Validation Accuracy: 0.9551, Loss: 0.0294
# Epoch 142 Batch   20/134 - Train Accuracy: 0.9529, Validation Accuracy: 0.9542, Loss: 0.0277
# Epoch 142 Batch   30/134 - Train Accuracy: 0.9434, Validation Accuracy: 0.9528, Loss: 0.0306
# Epoch 142 Batch   40/134 - Train Accuracy: 0.9484, Validation Accuracy: 0.9540, Loss: 0.0280
# Epoch 142 Batch   50/134 - Train Accuracy: 0.9484, Validation Accuracy: 0.9565, Loss: 0.0323
# Epoch 142 Batch   60/134 - Train Accuracy: 0.9441, Validation Accuracy: 0.9511, Loss: 0.0288
# Epoch 142 Batch   70/134 - Train Accuracy: 0.9475, Validation Accuracy: 0.9531, Loss: 0.0284
# Epoch 142 Batch   80/134 - Train Accuracy: 0.9553, Validation Accuracy: 0.9548, Loss: 0.0294
# Epoch 142 Batch   90/134 - Train Accuracy: 0.9482, Validation Accuracy: 0.9547, Loss: 0.0294
# Epoch 142 Batch  100/134 - Train Accuracy: 0.9537, Validation Accuracy: 0.9544, Loss: 0.0309
# Epoch 142 Batch  110/134 - Train Accuracy: 0.9522, Validation Accuracy: 0.9524, Loss: 0.0274
# Epoch 142 Batch  120/134 - Train Accuracy: 0.9513, Validation Accuracy: 0.9535, Loss: 0.0304
# Epoch 142 Batch  130/134 - Train Accuracy: 0.9497, Validation Accuracy: 0.9529, Loss: 0.0283
# Epoch 143 Batch   10/134 - Train Accuracy: 0.9420, Validation Accuracy: 0.9582, Loss: 0.0301
# Epoch 143 Batch   20/134 - Train Accuracy: 0.9546, Validation Accuracy: 0.9569, Loss: 0.0245
# Epoch 143 Batch   30/134 - Train Accuracy: 0.9422, Validation Accuracy: 0.9571, Loss: 0.0299
# Epoch 143 Batch   40/134 - Train Accuracy: 0.9503, Validation Accuracy: 0.9499, Loss: 0.0262
# Epoch 143 Batch   50/134 - Train Accuracy: 0.9515, Validation Accuracy: 0.9557, Loss: 0.0316
# Epoch 143 Batch   60/134 - Train Accuracy: 0.9432, Validation Accuracy: 0.9566, Loss: 0.0270
# Epoch 143 Batch   70/134 - Train Accuracy: 0.9495, Validation Accuracy: 0.9564, Loss: 0.0283
# Epoch 143 Batch   80/134 - Train Accuracy: 0.9573, Validation Accuracy: 0.9560, Loss: 0.0286
# Epoch 143 Batch   90/134 - Train Accuracy: 0.9489, Validation Accuracy: 0.9532, Loss: 0.0311
# Epoch 143 Batch  100/134 - Train Accuracy: 0.9539, Validation Accuracy: 0.9556, Loss: 0.0293
# Epoch 143 Batch  110/134 - Train Accuracy: 0.9535, Validation Accuracy: 0.9567, Loss: 0.0278
# Epoch 143 Batch  120/134 - Train Accuracy: 0.9538, Validation Accuracy: 0.9552, Loss: 0.0298
# Epoch 143 Batch  130/134 - Train Accuracy: 0.9532, Validation Accuracy: 0.9575, Loss: 0.0277
# Epoch 144 Batch   10/134 - Train Accuracy: 0.9427, Validation Accuracy: 0.9573, Loss: 0.0292
# Epoch 144 Batch   20/134 - Train Accuracy: 0.9554, Validation Accuracy: 0.9557, Loss: 0.0284
# Epoch 144 Batch   30/134 - Train Accuracy: 0.9434, Validation Accuracy: 0.9568, Loss: 0.0305
# Epoch 144 Batch   40/134 - Train Accuracy: 0.9544, Validation Accuracy: 0.9490, Loss: 0.0262
# Epoch 144 Batch   50/134 - Train Accuracy: 0.9463, Validation Accuracy: 0.9531, Loss: 0.0303
# Epoch 144 Batch   60/134 - Train Accuracy: 0.9461, Validation Accuracy: 0.9520, Loss: 0.0277
# Epoch 144 Batch   70/134 - Train Accuracy: 0.9475, Validation Accuracy: 0.9525, Loss: 0.0301
# Epoch 144 Batch   80/134 - Train Accuracy: 0.9618, Validation Accuracy: 0.9571, Loss: 0.0284
# Epoch 144 Batch   90/134 - Train Accuracy: 0.9440, Validation Accuracy: 0.9569, Loss: 0.0320
# Epoch 144 Batch  100/134 - Train Accuracy: 0.9526, Validation Accuracy: 0.9536, Loss: 0.0305
# Epoch 144 Batch  110/134 - Train Accuracy: 0.9524, Validation Accuracy: 0.9527, Loss: 0.0299
# Epoch 144 Batch  120/134 - Train Accuracy: 0.9517, Validation Accuracy: 0.9587, Loss: 0.0294
# Epoch 144 Batch  130/134 - Train Accuracy: 0.9490, Validation Accuracy: 0.9580, Loss: 0.0285
# Epoch 145 Batch   10/134 - Train Accuracy: 0.9437, Validation Accuracy: 0.9585, Loss: 0.0288
# Epoch 145 Batch   20/134 - Train Accuracy: 0.9525, Validation Accuracy: 0.9597, Loss: 0.0256
# Epoch 145 Batch   30/134 - Train Accuracy: 0.9444, Validation Accuracy: 0.9557, Loss: 0.0297
# Epoch 145 Batch   40/134 - Train Accuracy: 0.9512, Validation Accuracy: 0.9527, Loss: 0.0273
# Epoch 145 Batch   50/134 - Train Accuracy: 0.9486, Validation Accuracy: 0.9569, Loss: 0.0297
# Epoch 145 Batch   60/134 - Train Accuracy: 0.9468, Validation Accuracy: 0.9507, Loss: 0.0276
# Epoch 145 Batch   70/134 - Train Accuracy: 0.9484, Validation Accuracy: 0.9577, Loss: 0.0302
# Epoch 145 Batch   80/134 - Train Accuracy: 0.9594, Validation Accuracy: 0.9605, Loss: 0.0283
# Epoch 145 Batch   90/134 - Train Accuracy: 0.9459, Validation Accuracy: 0.9543, Loss: 0.0300
# Epoch 145 Batch  100/134 - Train Accuracy: 0.9531, Validation Accuracy: 0.9551, Loss: 0.0305
# Epoch 145 Batch  110/134 - Train Accuracy: 0.9538, Validation Accuracy: 0.9567, Loss: 0.0278
# Epoch 145 Batch  120/134 - Train Accuracy: 0.9555, Validation Accuracy: 0.9576, Loss: 0.0294
# Epoch 145 Batch  130/134 - Train Accuracy: 0.9502, Validation Accuracy: 0.9548, Loss: 0.0295
# Epoch 146 Batch   10/134 - Train Accuracy: 0.9441, Validation Accuracy: 0.9576, Loss: 0.0282
# Epoch 146 Batch   20/134 - Train Accuracy: 0.9543, Validation Accuracy: 0.9580, Loss: 0.0253
# Epoch 146 Batch   30/134 - Train Accuracy: 0.9439, Validation Accuracy: 0.9536, Loss: 0.0298
# Epoch 146 Batch   40/134 - Train Accuracy: 0.9527, Validation Accuracy: 0.9547, Loss: 0.0256
# Epoch 146 Batch   50/134 - Train Accuracy: 0.9472, Validation Accuracy: 0.9571, Loss: 0.0299
# Epoch 146 Batch   60/134 - Train Accuracy: 0.9418, Validation Accuracy: 0.9511, Loss: 0.0270
# Epoch 146 Batch   70/134 - Train Accuracy: 0.9483, Validation Accuracy: 0.9537, Loss: 0.0289
# Epoch 146 Batch   80/134 - Train Accuracy: 0.9570, Validation Accuracy: 0.9596, Loss: 0.0274
# Epoch 146 Batch   90/134 - Train Accuracy: 0.9486, Validation Accuracy: 0.9581, Loss: 0.0308
# Epoch 146 Batch  100/134 - Train Accuracy: 0.9539, Validation Accuracy: 0.9537, Loss: 0.0290
# Epoch 146 Batch  110/134 - Train Accuracy: 0.9548, Validation Accuracy: 0.9535, Loss: 0.0274
# Epoch 146 Batch  120/134 - Train Accuracy: 0.9522, Validation Accuracy: 0.9576, Loss: 0.0300
# Epoch 146 Batch  130/134 - Train Accuracy: 0.9539, Validation Accuracy: 0.9590, Loss: 0.0265
# Epoch 147 Batch   10/134 - Train Accuracy: 0.9425, Validation Accuracy: 0.9601, Loss: 0.0282
# Epoch 147 Batch   20/134 - Train Accuracy: 0.9543, Validation Accuracy: 0.9541, Loss: 0.0258
# Epoch 147 Batch   30/134 - Train Accuracy: 0.9412, Validation Accuracy: 0.9557, Loss: 0.0285
# Epoch 147 Batch   40/134 - Train Accuracy: 0.9550, Validation Accuracy: 0.9527, Loss: 0.0276
# Epoch 147 Batch   50/134 - Train Accuracy: 0.9490, Validation Accuracy: 0.9545, Loss: 0.0296
# Epoch 147 Batch   60/134 - Train Accuracy: 0.9464, Validation Accuracy: 0.9507, Loss: 0.0281
# Epoch 147 Batch   70/134 - Train Accuracy: 0.9499, Validation Accuracy: 0.9577, Loss: 0.0307
# Epoch 147 Batch   80/134 - Train Accuracy: 0.9574, Validation Accuracy: 0.9595, Loss: 0.0271
# Epoch 147 Batch   90/134 - Train Accuracy: 0.9467, Validation Accuracy: 0.9603, Loss: 0.0297
# Epoch 147 Batch  100/134 - Train Accuracy: 0.9539, Validation Accuracy: 0.9556, Loss: 0.0287
# Epoch 147 Batch  110/134 - Train Accuracy: 0.9546, Validation Accuracy: 0.9523, Loss: 0.0273
# Epoch 147 Batch  120/134 - Train Accuracy: 0.9537, Validation Accuracy: 0.9597, Loss: 0.0292
# Epoch 147 Batch  130/134 - Train Accuracy: 0.9531, Validation Accuracy: 0.9578, Loss: 0.0268
# Epoch 148 Batch   10/134 - Train Accuracy: 0.9425, Validation Accuracy: 0.9592, Loss: 0.0292
# Epoch 148 Batch   20/134 - Train Accuracy: 0.9577, Validation Accuracy: 0.9548, Loss: 0.0251
# Epoch 148 Batch   30/134 - Train Accuracy: 0.9441, Validation Accuracy: 0.9553, Loss: 0.0290
# Epoch 148 Batch   40/134 - Train Accuracy: 0.9466, Validation Accuracy: 0.9557, Loss: 0.0256
# Epoch 148 Batch   50/134 - Train Accuracy: 0.9481, Validation Accuracy: 0.9577, Loss: 0.0300
# Epoch 148 Batch   60/134 - Train Accuracy: 0.9457, Validation Accuracy: 0.9525, Loss: 0.0274
# Epoch 148 Batch   70/134 - Train Accuracy: 0.9483, Validation Accuracy: 0.9536, Loss: 0.0282
# Epoch 148 Batch   80/134 - Train Accuracy: 0.9601, Validation Accuracy: 0.9576, Loss: 0.0271
# Epoch 148 Batch   90/134 - Train Accuracy: 0.9487, Validation Accuracy: 0.9558, Loss: 0.0289
# Epoch 148 Batch  100/134 - Train Accuracy: 0.9558, Validation Accuracy: 0.9564, Loss: 0.0290
# Epoch 148 Batch  110/134 - Train Accuracy: 0.9534, Validation Accuracy: 0.9564, Loss: 0.0263
# Epoch 148 Batch  120/134 - Train Accuracy: 0.9544, Validation Accuracy: 0.9547, Loss: 0.0293
# Epoch 148 Batch  130/134 - Train Accuracy: 0.9554, Validation Accuracy: 0.9529, Loss: 0.0271
# Epoch 149 Batch   10/134 - Train Accuracy: 0.9412, Validation Accuracy: 0.9596, Loss: 0.0288
# Epoch 149 Batch   20/134 - Train Accuracy: 0.9571, Validation Accuracy: 0.9577, Loss: 0.0248
# Epoch 149 Batch   30/134 - Train Accuracy: 0.9380, Validation Accuracy: 0.9542, Loss: 0.0296
# Epoch 149 Batch   40/134 - Train Accuracy: 0.9493, Validation Accuracy: 0.9548, Loss: 0.0266
# Epoch 149 Batch   50/134 - Train Accuracy: 0.9504, Validation Accuracy: 0.9590, Loss: 0.0304
# Epoch 149 Batch   60/134 - Train Accuracy: 0.9433, Validation Accuracy: 0.9523, Loss: 0.0274
# Epoch 149 Batch   70/134 - Train Accuracy: 0.9514, Validation Accuracy: 0.9541, Loss: 0.0273
# Epoch 149 Batch   80/134 - Train Accuracy: 0.9599, Validation Accuracy: 0.9559, Loss: 0.0282
# Epoch 149 Batch   90/134 - Train Accuracy: 0.9499, Validation Accuracy: 0.9593, Loss: 0.0287
# Epoch 149 Batch  100/134 - Train Accuracy: 0.9561, Validation Accuracy: 0.9559, Loss: 0.0285
# Epoch 149 Batch  110/134 - Train Accuracy: 0.9547, Validation Accuracy: 0.9581, Loss: 0.0266
# Epoch 149 Batch  120/134 - Train Accuracy: 0.9505, Validation Accuracy: 0.9545, Loss: 0.0295
# Epoch 149 Batch  130/134 - Train Accuracy: 0.9577, Validation Accuracy: 0.9563, Loss: 0.0274
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    words = sentence.lower().split()
    return [vocab_to_int[word] if word in vocab_to_int else vocab_to_int['<UNK>'] for word in words]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [134, 79, 228, 35, 150, 141, 157]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [263, 355, 31, 49, 40, 71, 65, 1]
#   French Words: il a vu un camion noir . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
