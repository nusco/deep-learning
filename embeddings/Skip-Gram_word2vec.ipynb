# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
for i in int_words[:10]:
    print(int_to_vocab[i])
# Out:
# anarchism
# originated
# as
# a
# term
# of
# abuse
# first
# used
# against

# %%
from collections import Counter
import random

word_counts = Counter(int_words)
counts = {word: count for word, count in word_counts.items()}

def should_discard(int_word):
    t = 1e-5
    frequency = counts[int_word] / len(int_words)
    discard_probability = 1 - np.sqrt(t / frequency)
    return random.random() < discard_probability

train_words = [i for i in int_words if not should_discard(i)]

# %%
print("All words: ", len(int_words))
print("Kept words: ", len(train_words))
# Out:
# All words:  16680599
# Kept words:  4627483

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = random.randint(1, window_size)
    past_start_idx = max(idx-r, 0)
    past_end_idx = idx
    future_start_idx = min(idx+1, len(words))
    future_end_idx = min(idx+r+1, len(words))
    return words[past_start_idx:past_end_idx] + words[future_start_idx:future_end_idx]

# %%
# temporarily set r to window_size (instead of a random number) in get_target() to check these results
alphabet = [chr(ord('a') + i) for i in range(0, 26)]

idx = 3 # 'd'
print(get_target(alphabet, idx, 4))

idx = 23 # 'x'
print(get_target(alphabet, idx, 4))
# Out:
# ['a', 'b', 'c', 'e', 'f', 'g']
# ['v', 'w', 'y', 'z']

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels =  tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # experiment with changing this 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1, dtype=tf.float32), name="embedding")
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1), name="softmax_weights")
    softmax_b = tf.Variable(tf.zeros([n_vocab]), name="softmax_biases")
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w,
        biases=softmax_b,
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.5850 0.3284 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5769 0.3134 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4572 0.3166 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5363 0.3278 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4373 0.3101 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4643 0.3102 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4733 0.3122 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4984 0.3104 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4353 0.3162 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4089 0.3139 sec/batch
# Nearest to an: cantatas, receiving, schedel, gardena, reynard, taiwanese, it, furry,
# Nearest to on: approach, zionist, kat, unholy, indomitable, begin, dessau, hammerheads,
# Nearest to to: infanta, ships, duesberg, quartets, hain, cumberland, incredulity, perfection,
# Nearest to however: janice, mateo, wham, exhaled, oldcastle, infinitesimally, masoretes, washington,
# Nearest to with: asymptote, spawning, taxi, hammers, eject, shema, screenplay, attends,
# Nearest to more: ambiguities, mauritania, edlin, rmb, authority, width, bracelet, kidder,
# Nearest to the: landing, nation, gibbons, three, stillwater, leh, balor, mondial,
# Nearest to four: wpm, iss, wirehaired, ascesis, conner, arminians, freire, gullit,
# Nearest to test: aqueous, golden, cuboctahedra, geraldine, barium, inr, imprecise, mexico,
# Nearest to discovered: madox, adhesives, humanity, pix, uga, dvb, spaceprobe, curettage,
# Nearest to units: overrode, horseback, diadem, meng, brief, dewitt, schizophrenia, zola,
# Nearest to shown: baraka, halacha, shandy, robards, vdc, pechenegs, wide, ioi,
# Nearest to applications: daimler, aeon, frost, sayle, affliction, drachma, sufficed, queenie,
# Nearest to bill: magister, surveying, diligently, research, warrington, radiochemistry, henrietta, pygmalion,
# Nearest to resources: debugged, traverses, collections, paracel, hoyte, qantas, reflex, reflector,
# Nearest to animals: campaign, equality, bulgarians, lowest, herbert, babcock, fellini, discouraging,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4599 0.3155 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3461 0.3144 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3106 0.3070 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2083 0.3177 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1398 0.3074 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1775 0.3083 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0663 0.3132 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0332 0.3084 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9742 0.3096 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9880 0.3182 sec/batch
# Nearest to an: receiving, it, employment, cantatas, schedel, glasses, citation, re,
# Nearest to on: approach, begin, zionist, explanation, kat, indomitable, blocks, it,
# Nearest to to: ships, quartets, duesberg, defend, infanta, kit, coordination, composed,
# Nearest to however: mateo, different, janice, build, washington, rays, exhaled, dislike,
# Nearest to with: spawning, asymptote, biologist, while, taxi, eject, screenplay, or,
# Nearest to more: width, authority, awaiting, publicly, applicable, bigger, mauritania, suicide,
# Nearest to the: nation, gibbons, landing, off, going, three, words, second,
# Nearest to four: north, iss, nas, wpm, personality, arminians, wirehaired, conner,
# Nearest to test: golden, aqueous, mexico, evolution, eradicating, imprecise, transient, oxygen,
# Nearest to discovered: humanity, adhesives, madox, him, directions, curettage, hydroponics, sawn,
# Nearest to units: brief, diadem, horseback, overrode, bonded, design, vessels, energy,
# Nearest to shown: halacha, wide, baraka, corresponding, robards, factors, practising, conditional,
# Nearest to applications: didn, sayle, asterix, sequel, presumptive, affliction, queenie, developed,
# Nearest to bill: research, surveying, magister, diligently, warrington, field, serving, aid,
# Nearest to resources: debugged, collections, hoyte, reflector, qantas, terry, carnot, together,
# Nearest to animals: lowest, campaign, equality, herbert, bulgarians, perpetrators, gate, fellini,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9229 0.3142 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8974 0.3080 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8747 0.3131 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8671 0.3067 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8407 0.3040 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7959 0.3043 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8124 0.3053 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7992 0.3030 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7669 0.3053 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7971 0.3048 sec/batch
# Nearest to an: receiving, it, reynard, cantatas, employment, citation, schedel, glasses,
# Nearest to on: approach, kat, begin, zionist, explanation, indomitable, unholy, appalled,
# Nearest to to: defend, ships, storytelling, duesberg, quartets, coordination, redemption, infanta,
# Nearest to however: janice, judiciary, tomlinson, mateo, exhaled, madness, build, wham,
# Nearest to with: spawning, taxi, asymptote, hammers, biologist, observational, while, screenplay,
# Nearest to more: ambiguities, width, suicide, bigger, forcing, mauritania, awaiting, applicable,
# Nearest to the: nation, gibbons, landing, renegade, going, words, second, concerts,
# Nearest to four: conner, nas, manpower, personality, wpm, iss, wirehaired, north,
# Nearest to test: golden, aqueous, oxygen, transient, mexico, evolution, imprecise, inheritance,
# Nearest to discovered: madox, ietf, humanity, directions, adhesives, cropland, curettage, sawn,
# Nearest to units: horseback, overrode, diadem, brief, schizophrenia, dewitt, bonded, vessels,
# Nearest to shown: baraka, halacha, corresponding, wide, robards, prosecutor, practising, conditional,
# Nearest to applications: didn, frost, presumptive, affliction, asterix, sayle, sequel, queenie,
# Nearest to bill: research, surveying, magister, serving, diligently, warrington, aid, field,
# Nearest to resources: debugged, collections, hoyte, reflector, together, terry, qantas, adamant,
# Nearest to animals: lowest, campaign, equality, herbert, bulgarians, perpetrators, accorded, fellini,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7895 0.3101 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7328 0.3021 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7351 0.3073 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7250 0.3052 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7428 0.3043 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6989 0.3042 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7130 0.3058 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7312 0.3054 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7252 0.3054 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6551 0.3043 sec/batch
# Nearest to an: receiving, reynard, cantatas, schedel, unlicensed, taiwanese, it, employment,
# Nearest to on: kat, approach, begin, zionist, unholy, indomitable, apartheid, sociologist,
# Nearest to to: defend, storytelling, duesberg, quartets, redemption, cumberland, ships, coordination,
# Nearest to however: janice, madness, judiciary, mateo, tomlinson, infinitesimally, hospitality, comintern,
# Nearest to with: spawning, hammers, taxi, recounts, asymptote, observational, integrity, screenplay,
# Nearest to more: ambiguities, bigger, mauritania, width, inconsistencies, forcing, redesign, applicable,
# Nearest to the: nation, renegade, gibbons, landing, stillwater, going, second, concerts,
# Nearest to four: manpower, charles, one, conner, nas, irrigated, wirehaired, arminians,
# Nearest to test: transient, aqueous, oxygen, imprecise, inheritance, golden, geraldine, wiens,
# Nearest to discovered: madox, ietf, adhesives, directions, hydroponics, cropland, terminator, curettage,
# Nearest to units: horseback, overrode, diadem, schizophrenia, brief, dewitt, vessels, bonded,
# Nearest to shown: halacha, baraka, robards, corresponding, factors, compounds, shandy, prosecutor,
# Nearest to applications: indochina, presumptive, affliction, asterix, didn, frost, inconvenient, sufficed,
# Nearest to bill: magister, surveying, research, serving, warrington, diligently, alcide, calais,
# Nearest to resources: debugged, collections, hoyte, qantas, bibliographic, adamant, traverses, reflex,
# Nearest to animals: lowest, bulgarians, campaign, equality, herbert, fellini, accorded, perpetrators,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6682 0.3097 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6651 0.3058 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6279 0.3043 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5997 0.3046 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6143 0.3042 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6432 0.3043 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6170 0.2233 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5615 0.3039 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5356 0.3056 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5132 0.3041 sec/batch
# Nearest to an: receiving, schedel, it, gardena, unlicensed, cantatas, reynard, arithmetical,
# Nearest to on: kat, approach, unholy, dessau, indomitable, bromley, sociologist, kahn,
# Nearest to to: cumberland, defend, storytelling, quartets, incredulity, duesberg, ships, pn,
# Nearest to however: janice, madness, hospitality, infinitesimally, fatality, purged, tomlinson, mateo,
# Nearest to with: spawning, hammers, asymptote, recounts, profitability, appalling, observational, taxi,
# Nearest to more: ambiguities, upwards, redesign, mauritania, angle, bigger, inconsistencies, awaiting,
# Nearest to the: renegade, nation, stillwater, landing, second, going, ambience, gibbons,
# Nearest to four: charles, one, manpower, conner, personality, williamson, brennan, wirehaired,
# Nearest to test: aqueous, transient, oxygen, wiens, imprecise, geraldine, golden, inheritance,
# Nearest to discovered: madox, tricking, ietf, adhesives, cropland, dvb, hydroponics, curettage,
# Nearest to units: horseback, overrode, diadem, schizophrenia, biodiversity, bonded, brief, vessels,
# Nearest to shown: halacha, baraka, corresponding, compounds, factors, robards, fornax, shandy,
# Nearest to applications: indochina, affliction, asterix, didn, presumptive, inconvenient, wheatstone, computability,
# Nearest to bill: magister, warrington, surveying, serving, alcide, research, bouvines, diligently,
# Nearest to resources: debugged, hoyte, collections, qantas, bibliographic, traverses, reflex, adamant,
# Nearest to animals: lowest, bulgarians, accorded, equality, fellini, perpetrators, campaign, babcock,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5055 0.3090 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4799 0.3038 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4563 0.3064 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5167 0.3040 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5116 0.3030 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4691 0.3033 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4724 0.3049 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4108 0.3035 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4374 0.3036 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4079 0.3037 sec/batch
# Nearest to an: receiving, schedel, it, unlicensed, gardena, binocular, arithmetical, noronha,
# Nearest to on: kat, approach, begin, dessau, unholy, kahn, subjugating, sociologist,
# Nearest to to: cumberland, defend, incredulity, ships, duesberg, pn, storytelling, quartets,
# Nearest to however: fatality, infinitesimally, madness, hospitality, exhaled, verisimilitude, judiciary, surgeries,
# Nearest to with: spawning, hammers, asymptote, profitability, while, taxi, observational, recounts,
# Nearest to more: ambiguities, upwards, tendency, width, redesign, imaging, angle, grinding,
# Nearest to the: nation, renegade, stillwater, second, landing, ambience, free, going,
# Nearest to four: manpower, conner, wpm, brennan, one, charles, gullit, north,
# Nearest to test: aqueous, transient, imprecise, oxygen, wiens, golden, geraldine, evolution,
# Nearest to discovered: adhesives, madox, dvb, hydroponics, directions, tricking, cropland, ietf,
# Nearest to units: overrode, diadem, horseback, energy, vessels, clockless, schizophrenia, biodiversity,
# Nearest to shown: halacha, baraka, compounds, factors, corresponding, robards, riffs, fornax,
# Nearest to applications: computer, didn, indochina, wheatstone, affliction, basic, asterix, computability,
# Nearest to bill: magister, warrington, alcide, serving, surveying, bouvines, joan, aalto,
# Nearest to resources: debugged, hoyte, collections, qantas, together, eukaryotes, stockpiles, reflex,
# Nearest to animals: lowest, bulgarians, accorded, fellini, equality, maximization, saskatoon, amontillado,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4337 0.3097 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4116 0.3048 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4475 0.3035 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3866 0.3046 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4095 0.3048 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4286 0.3058 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3624 0.3061 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3557 0.3031 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4185 0.3026 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3782 0.3037 sec/batch
# Nearest to an: it, unlicensed, schedel, binocular, gardena, absorbance, noronha, annihilate,
# Nearest to on: kat, approach, begin, dessau, unholy, bromley, couldn, kahn,
# Nearest to to: incredulity, cumberland, duesberg, quartets, defend, storytelling, pn, confucianism,
# Nearest to however: fatality, infinitesimally, hospitality, judiciary, devised, surgeries, verisimilitude, babi,
# Nearest to with: spawning, hammers, asymptote, profitability, while, taxi, observational, midian,
# Nearest to more: ambiguities, tendency, redesign, imaging, upwards, width, plastids, angle,
# Nearest to the: nation, stillwater, ambience, free, landing, naia, second, curran,
# Nearest to four: manpower, one, conner, wpm, brennan, gullit, charles, three,
# Nearest to test: aqueous, transient, imprecise, wiens, oxygen, torsion, inheritance, geraldine,
# Nearest to discovered: adhesives, madox, tricking, terminator, cropland, hydroponics, dvb, proportion,
# Nearest to units: overrode, horseback, diadem, energy, vessels, clockless, catapults, triangle,
# Nearest to shown: halacha, baraka, compounds, robards, volume, corresponding, fornax, factors,
# Nearest to applications: computer, computability, basic, wheatstone, inconvenient, endosymbiosis, affliction, pricing,
# Nearest to bill: warrington, magister, serving, alcide, joan, research, surveying, bouvines,
# Nearest to resources: debugged, hoyte, qantas, collections, eukaryotes, crops, earthquakes, together,
# Nearest to animals: lowest, bulgarians, amontillado, fellini, accorded, maximization, saskatoon, widths,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3737 0.3102 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3777 0.3054 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3589 0.3055 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3549 0.3043 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4099 0.3040 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3727 0.3044 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3935 0.3061 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3863 0.3044 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3120 0.3056 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3471 0.3054 sec/batch
# Nearest to an: unlicensed, it, gardena, ontologically, reynard, absorbance, noronha, khalq,
# Nearest to on: kat, bromley, couldn, orellana, unholy, approach, canberra, begin,
# Nearest to to: incredulity, defend, duesberg, cumberland, quartets, ships, storytelling, fulfill,
# Nearest to however: infinitesimally, fatality, surgeries, hospitality, judiciary, devised, babi, skelter,
# Nearest to with: spawning, asymptote, while, hammers, confine, profitability, appalling, midian,
# Nearest to more: ambiguities, tendency, redesign, kebir, width, imaging, disposable, angle,
# Nearest to the: nation, free, shirkuh, catastrophic, notions, historically, second, ambience,
# Nearest to four: one, manpower, three, conner, zero, five, wpm, six,
# Nearest to test: aqueous, transient, torsion, imprecise, oxygen, wiens, testing, inx,
# Nearest to discovered: adhesives, madox, kinney, orr, ipf, terminator, parachute, hydroponics,
# Nearest to units: overrode, diadem, horseback, triangle, vessels, energy, clockless, catapults,
# Nearest to shown: halacha, baraka, robards, shandy, fornax, compounds, workings, vdc,
# Nearest to applications: computer, basic, wheatstone, computability, endosymbiosis, inconvenient, asterix, computers,
# Nearest to bill: warrington, magister, serving, bouvines, research, surveying, calais, aalto,
# Nearest to resources: debugged, hoyte, crops, qantas, eukaryotes, collections, earthquakes, stockpiles,
# Nearest to animals: bulgarians, lowest, amontillado, saskatoon, accorded, discouraging, widths, fellini,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3342 0.3105 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2873 0.3060 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3622 0.3063 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3947 0.3048 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3597 0.3049 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2604 0.3052 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2787 0.3035 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3265 0.3050 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1975 0.3048 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2853 0.3052 sec/batch
# Nearest to an: unlicensed, it, noronha, ontologically, piazzi, scapegoats, binocular, reynard,
# Nearest to on: kat, dessau, unholy, bromley, begin, september, canberra, orellana,
# Nearest to to: defend, cumberland, incredulity, hain, duesberg, thumbnails, storytelling, ships,
# Nearest to however: infinitesimally, fatality, hospitality, madness, devised, surgeries, babi, purged,
# Nearest to with: spawning, asymptote, hammers, while, confine, midian, profitability, cournot,
# Nearest to more: ambiguities, tendency, kebir, grinding, redesign, bracelet, archetypical, apol,
# Nearest to the: nation, second, landing, degeneracy, free, neutrino, curran, silver,
# Nearest to four: one, manpower, zero, three, five, six, wpm, two,
# Nearest to test: transient, wiens, torsion, aqueous, testing, oxygen, inx, imprecise,
# Nearest to discovered: adhesives, kinney, madox, ipf, orr, tricking, terminator, parachute,
# Nearest to units: overrode, diadem, triangle, horseback, energy, catapults, vessels, projected,
# Nearest to shown: halacha, baraka, shandy, robards, fornax, workings, ioi, corresponding,
# Nearest to applications: computer, wheatstone, computability, basic, endosymbiosis, inconvenient, vm, developed,
# Nearest to bill: warrington, magister, serving, aalto, bouvines, alcide, calais, surveying,
# Nearest to resources: debugged, crops, qantas, hoyte, eukaryotes, collections, extremes, stockpiles,
# Nearest to animals: bulgarians, amontillado, discouraging, reptiles, expiry, lowest, fellini, accorded,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2482 0.3080 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2994 0.3049 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3541 0.1407 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2537 0.3049 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2189 0.3041 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1956 0.3054 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2146 0.3036 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1601 0.3055 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1908 0.3032 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1475 0.3047 sec/batch
# Nearest to an: unlicensed, schedel, it, igneous, noronha, absorbance, classicists, ontologically,
# Nearest to on: kat, dessau, september, bromley, canberra, indomitable, unholy, couldn,
# Nearest to to: defend, cumberland, incredulity, duesberg, hain, ships, comorian, thumbnails,
# Nearest to however: infinitesimally, fatality, devised, relatively, hospitality, babi, judiciary, madness,
# Nearest to with: spawning, asymptote, hammers, profitability, while, pushes, confine, megabyte,
# Nearest to more: grinding, ambiguities, tendency, plastids, disposable, upwards, rmb, bracelet,
# Nearest to the: nation, free, degeneracy, second, off, karelia, hurts, landing,
# Nearest to four: one, three, manpower, zero, five, wpm, six, two,
# Nearest to test: transient, wiens, inx, torsion, testing, airborne, inr, aqueous,
# Nearest to discovered: adhesives, secretion, orr, kinney, ipf, khaganate, spaceprobe, madox,
# Nearest to units: overrode, triangle, cormorants, projected, diadem, catapults, lumped, energy,
# Nearest to shown: halacha, workings, baraka, shandy, robards, vdc, fornax, ioi,
# Nearest to applications: basic, computer, wheatstone, computability, inconvenient, endosymbiosis, developed, vm,
# Nearest to bill: warrington, aalto, serving, magister, alcide, bouvines, calais, surveying,
# Nearest to resources: debugged, qantas, crops, hoyte, collections, eukaryotes, stockpiles, bibliographic,
# Nearest to animals: reptiles, bulgarians, animal, peritoneum, discouraging, expiry, fellini, spasms,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2226 0.3091 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2398 0.3048 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1905 0.3049 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1141 0.3056 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1623 0.3044 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1398 0.3054 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1375 0.3055 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1775 0.3622 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1862 0.3135 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1619 0.3130 sec/batch
# Nearest to an: unlicensed, it, ontologically, igneous, classicists, arithmetical, scapegoats, schedel,
# Nearest to on: kat, dessau, couldn, begin, approach, canberra, unholy, bromley,
# Nearest to to: incredulity, defend, duesberg, thumbnails, filtering, cumberland, interrupts, plectrum,
# Nearest to however: infinitesimally, fatality, relatively, devised, judiciary, hospitality, madness, babi,
# Nearest to with: spawning, asymptote, pushes, hammers, confine, while, megabyte, unison,
# Nearest to more: ambiguities, tendency, grinding, disposable, decode, imaging, archimedean, rmb,
# Nearest to the: nation, free, degeneracy, second, neutrino, dorpat, off, naia,
# Nearest to four: one, three, zero, manpower, five, six, wpm, two,
# Nearest to test: transient, wiens, testing, torsion, inx, airborne, inr, aqueous,
# Nearest to discovered: secretion, adhesives, kinney, orr, ions, ipf, squeezes, proportion,
# Nearest to units: overrode, triangle, projected, lumped, cormorants, clockless, energy, diadem,
# Nearest to shown: halacha, baraka, vdc, workings, robards, shandy, provably, fornax,
# Nearest to applications: basic, computer, wheatstone, computability, endosymbiosis, inconvenient, developed, pricing,
# Nearest to bill: warrington, magister, aalto, serving, alcide, bouvines, calais, jimmy,
# Nearest to resources: crops, qantas, collections, debugged, hoyte, stockpiles, diplomatique, bibliographic,
# Nearest to animals: reptiles, animal, bulgarians, primates, mammals, discouraging, peritoneum, lexicographers,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1475 0.3189 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1942 0.3217 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1545 0.3091 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1177 0.3186 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1643 0.3135 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1648 0.3100 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1738 0.3172 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1357 0.3110 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1075 0.3147 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1560 0.3107 sec/batch
# Nearest to an: it, unlicensed, ontologically, scapegoats, classicists, arithmetical, datamation, noronha,
# Nearest to on: kat, dessau, couldn, approach, canberra, unholy, bromley, cedes,
# Nearest to to: incredulity, duesberg, filtering, defend, thumbnails, heft, modules, crucially,
# Nearest to however: fatality, infinitesimally, judiciary, relatively, reformist, devised, purged, forcible,
# Nearest to with: spawning, asymptote, pushes, confine, hammers, while, across, profitability,
# Nearest to more: ambiguities, volap, edlin, plastids, rmb, tendency, grinding, levers,
# Nearest to the: nation, free, see, magnitude, degeneracy, neutrino, second, dorpat,
# Nearest to four: one, three, zero, five, six, two, manpower, wpm,
# Nearest to test: testing, transient, torsion, wiens, airborne, inx, inr, laziness,
# Nearest to discovered: kinney, secretion, adhesives, orr, ipf, astronomer, ions, squeezes,
# Nearest to units: overrode, triangle, projected, lumped, energy, centimetre, cormorants, factoring,
# Nearest to shown: halacha, fornax, workings, baraka, vdc, shandy, provably, lou,
# Nearest to applications: wheatstone, computer, endosymbiosis, basic, computability, inconvenient, developed, commercial,
# Nearest to bill: aalto, warrington, magister, trotter, serving, jimmy, alcide, bouvines,
# Nearest to resources: crops, debugged, collections, qantas, eukaryotes, stockpiles, bibliographic, hoyte,
# Nearest to animals: reptiles, animal, primates, mammals, spasms, bulgarians, discouraging, peritoneum,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1638 0.3161 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1562 0.3151 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1527 0.3122 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1579 0.3071 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1197 0.3163 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1094 0.3084 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1424 0.3104 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0898 0.3155 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1734 0.3105 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1899 0.3055 sec/batch
# Nearest to an: scapegoats, unlicensed, it, noronha, datamation, piazzi, ontologically, classicists,
# Nearest to on: dessau, kat, september, canberra, bromley, cedes, couldn, hanukkah,
# Nearest to to: defend, incredulity, duesberg, declares, heft, discontent, eighth, offense,
# Nearest to however: relatively, fatality, infinitesimally, judiciary, forcible, madness, reformist, hospitality,
# Nearest to with: spawning, asymptote, declares, hammers, thawed, while, bucks, pushes,
# Nearest to more: ambiguities, volap, neuroanatomy, tendency, ballplayers, apol, archimedean, edlin,
# Nearest to the: nation, of, second, see, free, looted, a, in,
# Nearest to four: one, three, zero, five, six, two, nine, manpower,
# Nearest to test: testing, transient, torsion, airborne, inx, inr, wiens, laziness,
# Nearest to discovered: astronomer, ipf, kinney, secretion, adhesives, orr, humanity, ceres,
# Nearest to units: overrode, triangle, projected, lumped, cormorants, germans, centimetre, energy,
# Nearest to shown: halacha, fornax, shandy, baraka, vdc, provably, lou, kacl,
# Nearest to applications: wheatstone, endosymbiosis, basic, inconvenient, computer, computability, developed, asterix,
# Nearest to bill: serving, aalto, warrington, magister, jimmy, benno, resignation, trotter,
# Nearest to resources: crops, qantas, collections, eukaryotes, debugged, natural, diplomatique, extremes,
# Nearest to animals: reptiles, animal, primates, mammals, bulgarians, spasms, discouraging, fellini,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2115 0.3112 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1476 0.3045 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1094 0.3074 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0921 0.3058 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0059 0.3079 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1020 0.3052 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0949 0.3052 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0946 0.3063 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1553 0.0589 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0779 0.3071 sec/batch
# Nearest to an: unlicensed, it, classicists, ontologically, igneous, piazzi, datamation, schedel,
# Nearest to on: kat, dessau, september, couldn, bromley, unholy, picabia, indomitable,
# Nearest to to: incredulity, thumbnails, defend, crucially, a, modules, interrupts, fools,
# Nearest to however: fatality, infinitesimally, relatively, forcible, eigenvector, madness, devised, savvy,
# Nearest to with: spawning, pushes, across, declares, asymptote, a, thawed, while,
# Nearest to more: ambiguities, grinding, volap, upwards, apol, ballplayers, neuroanatomy, snorting,
# Nearest to the: nation, a, of, second, free, clannad, in, see,
# Nearest to four: one, three, zero, six, five, two, wpm, manpower,
# Nearest to test: testing, transient, torsion, airborne, inr, wiens, inx, csl,
# Nearest to discovered: astronomer, secretion, kinney, ipf, adhesives, orr, ceres, ions,
# Nearest to units: overrode, triangle, germans, projected, cormorants, centimetre, lumped, catapults,
# Nearest to shown: halacha, fornax, lou, shandy, kacl, provably, vdc, baraka,
# Nearest to applications: wheatstone, developed, computer, endosymbiosis, basic, computability, inconvenient, executables,
# Nearest to bill: aalto, warrington, serving, jimmy, trotter, orville, spandau, benno,
# Nearest to resources: crops, collections, debugged, qantas, extremes, natural, bibliographic, hoyte,
# Nearest to animals: reptiles, primates, mammals, animal, peritoneum, bulgarians, spasms, birds,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0669 0.3115 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0232 0.3061 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0753 0.3060 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0056 0.3055 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0369 0.3073 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9851 0.3048 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0897 0.3072 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0746 0.3052 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0855 0.3063 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9823 0.3060 sec/batch
# Nearest to an: it, unlicensed, igneous, piazzi, ontologically, classicists, schedel, operational,
# Nearest to on: dessau, kat, september, picabia, couldn, cedes, it, bromley,
# Nearest to to: defend, a, thumbnails, crucially, incredulity, comorian, where, declares,
# Nearest to however: fatality, relatively, infinitesimally, judiciary, though, eigenvector, evenly, forcible,
# Nearest to with: spawning, across, thawed, pushes, a, declares, while, needing,
# Nearest to more: grinding, ballplayers, ambiguities, upwards, volap, mixed, extensively, snorting,
# Nearest to the: nation, a, of, in, see, second, free, catastrophic,
# Nearest to four: one, three, zero, six, five, two, wpm, manpower,
# Nearest to test: testing, transient, torsion, airborne, csl, inr, inx, wiens,
# Nearest to discovered: secretion, astronomer, adhesives, kinney, ions, ipf, spaceprobe, orr,
# Nearest to units: overrode, germans, cormorants, triangle, projected, centimetre, factoring, expeditionary,
# Nearest to shown: halacha, vdc, shandy, kacl, baraka, workings, fornax, provably,
# Nearest to applications: computer, wheatstone, basic, developed, endosymbiosis, computability, firmware, inconvenient,
# Nearest to bill: aalto, warrington, trotter, jimmy, hoover, orville, rattle, carsten,
# Nearest to resources: crops, collections, debugged, bibliographic, qantas, extremes, eukaryotes, diplomatique,
# Nearest to animals: reptiles, primates, mammals, animal, peritoneum, bulgarians, spasms, sheep,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9792 0.3099 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0186 0.3070 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9759 0.3023 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0197 0.3048 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0651 0.3066 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0244 0.3058 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0406 0.3042 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0863 0.3079 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0156 0.3033 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0183 0.3028 sec/batch
# Nearest to an: it, ontologically, unlicensed, igneous, classicists, set, arithmetical, piazzi,
# Nearest to on: kat, dessau, picabia, approach, bromley, couldn, freedesktop, cedes,
# Nearest to to: incredulity, a, crucially, defend, filtering, modules, thumbnails, interrupts,
# Nearest to however: relatively, fatality, infinitesimally, though, devised, evenly, gartner, expression,
# Nearest to with: spawning, across, while, pushes, declares, thawed, taxi, asymptote,
# Nearest to more: grinding, ambiguities, volap, ballplayers, archimedean, subpages, dominant, apol,
# Nearest to the: a, of, nation, see, is, in, second, free,
# Nearest to four: one, three, zero, five, six, two, wpm, manpower,
# Nearest to test: testing, torsion, transient, airborne, csl, wiens, rf, laziness,
# Nearest to discovered: astronomer, kinney, secretion, ipf, adhesives, ceres, orr, ions,
# Nearest to units: overrode, germans, factoring, cormorants, triangle, lumped, centimetre, energy,
# Nearest to shown: halacha, vdc, workings, kacl, provably, fornax, cohesive, shandy,
# Nearest to applications: wheatstone, endosymbiosis, developed, computer, basic, illustrates, computability, firmware,
# Nearest to bill: aalto, trotter, warrington, hoover, jimmy, galesburg, orville, serving,
# Nearest to resources: crops, debugged, collections, extremes, natural, qantas, bibliographic, diplomatique,
# Nearest to animals: reptiles, primates, mammals, animal, bulgarians, peritoneum, spasms, discouraging,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0189 0.3111 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0391 0.3042 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0378 0.3046 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0113 0.3052 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0223 0.3068 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0443 0.3047 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0528 0.3052 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0394 0.3052 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0623 0.3050 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0502 0.3084 sec/batch
# Nearest to an: classicists, it, ontologically, piazzi, unlicensed, datamation, noronha, lakshmi,
# Nearest to on: picabia, dessau, kat, september, tweaked, cedes, bromley, hanukkah,
# Nearest to to: in, a, defend, the, crucially, discontent, thumbnails, incredulity,
# Nearest to however: relatively, fatality, infinitesimally, skelter, little, evenly, though, upwelling,
# Nearest to with: spawning, across, declares, cincinnatus, confine, thawed, asymptote, while,
# Nearest to more: ambiguities, volap, grinding, ballplayers, subpages, archimedean, directx, logged,
# Nearest to the: of, nation, in, a, second, see, from, appointing,
# Nearest to four: one, three, zero, five, six, two, wpm, seven,
# Nearest to test: testing, torsion, transient, airborne, laziness, csl, inr, rf,
# Nearest to discovered: astronomer, secretion, kinney, ipf, adhesives, ceres, spaceprobe, orr,
# Nearest to units: overrode, germans, expeditionary, centimetre, lumped, cormorants, triangle, factoring,
# Nearest to shown: halacha, provably, workings, kacl, vdc, fornax, shandy, bebop,
# Nearest to applications: wheatstone, endosymbiosis, illustrates, developed, millionth, computer, basic, garnet,
# Nearest to bill: galesburg, hoover, aalto, advise, ratifying, veto, serving, secede,
# Nearest to resources: crops, debugged, collections, extremes, diplomatique, qantas, bibliographic, natural,
# Nearest to animals: reptiles, primates, mammals, animal, bulgarians, peritoneum, spasms, discouraging,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0059 0.3101 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9879 0.3060 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9876 0.3046 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0136 0.3072 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0799 0.3057 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0820 0.3056 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0968 0.3050 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0049 0.3051 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9925 0.3045 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0009 0.3042 sec/batch
# Nearest to an: it, classicists, datamation, ontologically, unlicensed, piazzi, noronha, igneous,
# Nearest to on: dessau, september, picabia, kat, cedes, fisa, indomitable, tweaked,
# Nearest to to: incredulity, a, defend, thumbnails, that, sack, crucially, filtering,
# Nearest to however: relatively, infinitesimally, fatality, expression, required, evenly, little, madness,
# Nearest to with: spawning, across, declares, pushes, while, thawed, taxi, minsky,
# Nearest to more: grinding, ambiguities, volap, disputed, subpages, discounting, archimedean, ballplayers,
# Nearest to the: of, a, nation, in, from, see, second, free,
# Nearest to four: one, three, zero, six, five, two, wpm, nine,
# Nearest to test: testing, torsion, transient, laziness, airborne, csl, experiment, inr,
# Nearest to discovered: astronomer, secretion, kinney, ipf, ceres, orr, spaceprobe, adhesives,
# Nearest to units: overrode, germans, centimetre, lumped, cormorants, expeditionary, triangle, webcast,
# Nearest to shown: provably, shandy, halacha, workings, fornax, kacl, lou, vdc,
# Nearest to applications: developed, wheatstone, endosymbiosis, millionth, illustrates, computer, monterey, basic,
# Nearest to bill: galesburg, aalto, secede, advise, hoover, ratifying, trotter, serving,
# Nearest to resources: crops, diplomatique, extremes, debugged, collections, natural, bibliographic, qantas,
# Nearest to animals: reptiles, primates, mammals, bulgarians, animal, peritoneum, sheep, discouraging,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9439 0.3111 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9816 0.3066 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0066 0.3053 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9558 0.3066 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0461 0.3057 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9911 0.2818 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9811 0.3046 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9374 0.3072 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9983 0.3052 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9403 0.3057 sec/batch
# Nearest to an: igneous, it, classicists, ontologically, datamation, piazzi, npcs, comforts,
# Nearest to on: dessau, september, picabia, indomitable, cedes, kat, bromley, fisa,
# Nearest to to: a, defend, where, incredulity, crucially, that, fools, in,
# Nearest to however: relatively, infinitesimally, required, expression, fatality, devised, gartner, little,
# Nearest to with: spawning, pushes, across, unison, made, declares, needing, minsky,
# Nearest to more: grinding, ambiguities, disputed, volap, discounting, dominant, archimedean, tendency,
# Nearest to the: of, a, nation, in, from, free, see, timbuktu,
# Nearest to four: one, three, zero, six, five, two, nine, seven,
# Nearest to test: testing, torsion, transient, laziness, airborne, flipper, csl, melanogaster,
# Nearest to discovered: secretion, astronomer, kinney, spaceprobe, ceres, orr, adhesives, hittites,
# Nearest to units: overrode, centimetre, germans, expeditionary, catapults, cormorants, lumped, factoring,
# Nearest to shown: provably, workings, fornax, shandy, halacha, kacl, bebop, cohesive,
# Nearest to applications: developed, wheatstone, endosymbiosis, computer, monterey, millionth, basic, illustrates,
# Nearest to bill: galesburg, trudeau, hoover, advise, jimmy, aalto, trotter, secede,
# Nearest to resources: diplomatique, debugged, extremes, bibliographic, crops, collections, eukaryotes, interventions,
# Nearest to animals: primates, reptiles, bulgarians, peritoneum, mammals, animal, discouraging, spasms,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9782 0.3116 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8944 0.3051 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9761 0.3047 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9742 0.3048 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9976 0.3056 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9799 0.3065 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8776 0.3074 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9366 0.3059 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8868 0.3065 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9560 0.3061 sec/batch
# Nearest to an: it, that, igneous, operational, classicists, npcs, ontologically, a,
# Nearest to on: september, kat, picabia, dessau, cedes, approach, freedesktop, indomitable,
# Nearest to to: a, in, the, where, that, at, different, comorian,
# Nearest to however: infinitesimally, relatively, required, fatality, gunto, expression, rosicrucians, little,
# Nearest to with: spawning, across, pushes, a, declares, in, the, while,
# Nearest to more: grinding, ambiguities, archimedean, rmb, ballplayers, tendency, subpages, discounting,
# Nearest to the: a, of, nation, in, from, is, see, second,
# Nearest to four: one, zero, three, six, five, two, nine, seven,
# Nearest to test: testing, torsion, transient, csl, laziness, flipper, airborne, melanogaster,
# Nearest to discovered: secretion, astronomer, ceres, spaceprobe, hittites, kinney, adhesives, gamow,
# Nearest to units: germans, overrode, expeditionary, centimetre, factoring, lumped, cormorants, projected,
# Nearest to shown: workings, kacl, provably, fornax, vdc, shandy, halacha, cohesive,
# Nearest to applications: developed, endosymbiosis, wheatstone, illustrates, computer, millionth, monterey, propagate,
# Nearest to bill: galesburg, hoover, trudeau, trotter, advise, aalto, carmina, secede,
# Nearest to resources: extremes, debugged, diplomatique, crops, bibliographic, eukaryotes, hydropower, collections,
# Nearest to animals: reptiles, primates, bulgarians, peritoneum, mammals, animal, discouraging, spasms,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9810 0.3110 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9646 0.3037 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9151 0.3045 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9655 0.3040 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0220 0.3051 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9111 0.3044 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9705 0.3057 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9238 0.3049 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9651 0.3068 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9457 0.3047 sec/batch
# Nearest to an: it, that, a, classicists, ontologically, using, piazzi, datamation,
# Nearest to on: september, dessau, picabia, kat, cedes, tweaked, approach, infrequently,
# Nearest to to: a, the, in, that, modules, also, unremarkable, different,
# Nearest to however: relatively, fatality, little, infinitesimally, though, gunto, required, evenly,
# Nearest to with: spawning, a, across, pushes, declares, the, is, in,
# Nearest to more: ambiguities, tendency, grinding, volap, directx, ballplayers, discounting, archimedean,
# Nearest to the: of, a, in, nation, see, is, from, as,
# Nearest to four: one, three, zero, six, five, two, nine, seven,
# Nearest to test: torsion, testing, laziness, transient, csl, inr, flipper, airborne,
# Nearest to discovered: secretion, kinney, astronomer, ceres, spaceprobe, adhesives, hittites, orr,
# Nearest to units: centimetre, overrode, germans, factoring, lumped, expeditionary, webcast, cormorants,
# Nearest to shown: fornax, kacl, workings, provably, bebop, vdc, cohesive, halacha,
# Nearest to applications: developed, wheatstone, illustrates, endosymbiosis, computer, millionth, monterey, propagate,
# Nearest to bill: galesburg, hoover, trudeau, advise, trotter, aalto, showered, veto,
# Nearest to resources: extremes, debugged, diplomatique, crops, interventions, bibliographic, eukaryotes, natural,
# Nearest to animals: primates, reptiles, bulgarians, animal, mammals, peritoneum, rabbits, spasms,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9871 0.3102 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9619 0.3054 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9359 0.3047 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9757 0.3054 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9741 0.3064 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9790 0.3066 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9590 0.3061 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9276 0.3042 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9249 0.3056 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9965 0.3064 sec/batch
# Nearest to an: that, it, a, to, unlicensed, operational, recognition, classicists,
# Nearest to on: cedes, september, picabia, dessau, kat, june, tweaked, approves,
# Nearest to to: a, in, that, the, also, crucially, an, from,
# Nearest to however: relatively, little, required, infinitesimally, fatality, though, expression, evenly,
# Nearest to with: spawning, a, the, across, is, declares, in, pushes,
# Nearest to more: ambiguities, tendency, discounting, ballplayers, grinding, disputed, volap, levers,
# Nearest to the: of, a, in, from, see, nation, is, s,
# Nearest to four: one, three, zero, six, five, two, nine, seven,
# Nearest to test: torsion, testing, laziness, transient, csl, melanogaster, flipper, inr,
# Nearest to discovered: secretion, astronomer, kinney, ceres, gamow, hittites, spaceprobe, orr,
# Nearest to units: centimetre, expeditionary, germans, overrode, factoring, cormorants, lumped, catapults,
# Nearest to shown: provably, fornax, kacl, halacha, workings, cohesive, bebop, vdc,
# ...
# Nearest to animals: animal, creatures, primates, sheep, rabbits, bulgarians, myocardium, reptiles,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8117 0.3102 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7324 0.3051 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.7809 0.3052 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7507 0.3078 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7801 0.3044 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7982 0.3055 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8041 0.3065 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7767 0.3062 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8151 0.3052 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8424 0.3064 sec/batch
# Nearest to an: a, that, the, to, in, as, and, it,
# Nearest to on: the, for, of, with, in, a, this, to,
# Nearest to to: a, the, of, in, and, from, as, by,
# Nearest to however: relatively, though, the, different, known, in, include, than,
# Nearest to with: the, a, in, and, for, is, to, of,
# Nearest to more: than, of, because, to, subpages, bliss, tendency, used,
# Nearest to the: a, of, in, as, is, and, to, this,
# Nearest to four: one, three, six, two, zero, five, seven, eight,
# Nearest to test: torsion, testing, laziness, flipper, ban, signed, belgique, endangered,
# Nearest to discovered: discovery, gamow, keck, astronomer, secretion, prions, booker, hittites,
# Nearest to units: centimetre, factoring, housing, unit, households, webcast, cormorants, cgs,
# Nearest to shown: kacl, sds, bebop, workings, observes, cohesive, provably, vdc,
# Nearest to applications: monterey, developed, illustrates, selenide, cryptographically, garnet, millionth, endosymbiosis,
# Nearest to bill: bills, flicker, secede, carmina, hoover, galesburg, trudeau, assertive,
# Nearest to resources: extremes, debugged, hydropower, natural, crops, diplomatique, interventions, hazards,
# Nearest to animals: animal, creatures, primates, sheep, rabbits, myocardium, peritoneum, reptiles,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7870 0.3114 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8050 0.3060 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7929 0.3067 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8163 0.3056 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7856 0.3049 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8126 0.3067 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7991 0.3068 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7924 0.3062 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8250 0.3064 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.7844 0.3040 sec/batch
# Nearest to an: a, the, that, as, in, is, to, and,
# Nearest to on: the, of, for, from, september, this, with, in,
# Nearest to to: of, the, a, in, and, from, by, as,
# Nearest to however: though, relatively, the, in, different, little, was, confirmed,
# Nearest to with: the, a, in, and, is, for, as, of,
# Nearest to more: than, of, because, to, subpages, larger, particularly, less,
# Nearest to the: of, a, in, as, is, and, from, to,
# Nearest to four: one, three, six, two, zero, five, seven, eight,
# Nearest to test: torsion, testing, laziness, flipper, ban, endangered, belgique, variation,
# Nearest to discovered: discovery, astronomer, gamow, keck, spaceprobe, hittites, niobe, employed,
# Nearest to units: centimetre, factoring, unit, households, housing, cgs, cormorants, expeditionary,
# Nearest to shown: kacl, sds, observes, bebop, cit, maris, cohesive, provably,
# Nearest to applications: monterey, illustrates, cryptographically, selenide, developed, newall, garnet, millionth,
# Nearest to bill: bills, secede, flicker, carmina, trudeau, galesburg, rarest, hints,
# Nearest to resources: extremes, hydropower, natural, debugged, crops, diplomatique, asceticism, campaigns,
# Nearest to animals: animal, creatures, primates, sheep, rabbits, bulgarians, burmese, myocardium,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7876 0.3119 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7992 0.3058 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7771 0.3067 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7651 0.3046 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8623 0.3057 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8114 0.3050 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9335 0.3062 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8662 0.3061 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8569 0.3050 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7404 0.3057 sec/batch
# Nearest to an: a, the, in, to, as, and, is, that,
# Nearest to on: the, of, from, in, for, september, a, this,
# Nearest to to: a, the, of, in, and, from, as, that,
# Nearest to however: relatively, though, be, in, than, the, little, known,
# Nearest to with: the, a, and, in, is, for, as, to,
# Nearest to more: than, of, because, to, less, discounting, levers, four,
# Nearest to the: a, of, in, as, from, and, s, to,
# Nearest to four: one, three, zero, two, six, five, seven, eight,
# Nearest to test: torsion, testing, laziness, flipper, ban, belgique, bmj, transient,
# Nearest to discovered: keck, gamow, discovery, spaceprobe, astronomer, hittites, schlegel, employed,
# Nearest to units: centimetre, factoring, unit, households, housing, expeditionary, ghq, cgs,
# Nearest to shown: kacl, sds, cit, maris, observes, bebop, workings, chanced,
# Nearest to applications: monterey, developed, cryptographically, illustrates, truetype, selenide, garnet, newall,
# Nearest to bill: bills, secede, flicker, carmina, parliament, rarest, galesburg, assertive,
# Nearest to resources: extremes, hydropower, natural, crops, asphalt, nautical, debugged, diplomatique,
# Nearest to animals: creatures, animal, primates, rabbits, sheep, cannibal, wild, burmese,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7201 0.3099 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8271 0.3043 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7168 0.3032 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8075 0.3073 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7852 0.3051 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8017 0.3066 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8475 0.1756 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7592 0.3049 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7874 0.3070 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8138 0.3056 sec/batch
# Nearest to an: a, the, in, to, as, is, that, and,
# Nearest to on: the, of, from, a, september, in, this, at,
# Nearest to to: a, the, of, in, and, as, at, an,
# Nearest to however: relatively, though, be, the, than, different, in, little,
# Nearest to with: the, a, in, and, is, for, to, of,
# Nearest to more: than, because, of, to, less, particularly, but, ducas,
# Nearest to the: a, in, of, to, and, from, as, is,
# Nearest to four: one, three, two, six, five, zero, seven, eight,
# Nearest to test: torsion, testing, laziness, flipper, cricket, ban, belgique, bmj,
# Nearest to discovered: discovery, niobe, hittites, keck, known, spaceprobe, ceres, astronomer,
# Nearest to units: centimetre, unit, factoring, households, housing, cgs, expeditionary, cormorants,
# Nearest to shown: kacl, sds, cit, chanced, workings, observes, bebop, maris,
# Nearest to applications: monterey, cryptographically, developed, illustrates, truetype, hygiene, strives, newall,
# Nearest to bill: bills, secede, flicker, assertive, parliament, rarest, galesburg, carmina,
# Nearest to resources: extremes, hydropower, debugged, natural, resource, campaigns, diplomatique, awful,
# Nearest to animals: animal, primates, creatures, rabbits, burmese, myocardium, cannibal, fecal,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7836 0.3060 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7654 0.3056 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7864 0.3048 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7570 0.3050 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7963 0.3059 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7724 0.3041 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8364 0.3038 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7172 0.3038 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7739 0.3046 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7267 0.3045 sec/batch
# Nearest to an: a, the, in, as, to, and, that, is,
# Nearest to on: the, from, of, in, a, this, for, and,
# Nearest to to: a, the, of, in, and, as, from, is,
# Nearest to however: relatively, be, though, the, in, known, time, was,
# Nearest to with: the, a, in, and, for, is, of, to,
# Nearest to more: than, of, to, because, less, and, but, some,
# Nearest to the: a, in, of, as, is, and, from, to,
# Nearest to four: one, three, six, five, zero, two, seven, eight,
# Nearest to test: torsion, testing, laziness, flipper, ban, cricket, belgique, bmj,
# Nearest to discovered: discovery, hittites, schlegel, gamow, known, ceres, prions, keck,
# Nearest to units: unit, centimetre, households, factoring, housing, expeditionary, cormorants, cgs,
# Nearest to shown: kacl, cit, workings, sds, chanced, observes, provably, maris,
# Nearest to applications: monterey, developed, cryptographically, millionth, illustrates, selenide, strives, truetype,
# Nearest to bill: bills, flicker, secede, rarest, carmina, assertive, galesburg, hints,
# Nearest to resources: extremes, hydropower, natural, resource, debugged, diplomatique, awful, crops,
# Nearest to animals: animal, primates, creatures, burmese, myocardium, cannibal, rabbits, sheep,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6708 0.3103 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7727 0.3057 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7939 0.3060 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7875 0.3087 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7384 0.3058 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8199 0.3050 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7970 0.3064 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7638 0.3053 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7365 0.3063 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7959 0.3049 sec/batch
# Nearest to an: a, the, in, and, to, as, that, is,
# Nearest to on: the, in, of, for, a, from, with, and,
# Nearest to to: of, the, a, in, and, as, from, at,
# Nearest to however: be, relatively, though, the, known, different, in, of,
# Nearest to with: a, the, in, and, for, is, of, as,
# Nearest to more: than, of, less, because, but, to, particularly, some,
# Nearest to the: of, in, a, as, is, and, to, from,
# Nearest to four: one, three, six, two, five, zero, seven, eight,
# Nearest to test: torsion, testing, laziness, flipper, ban, bmj, variation, belgique,
# Nearest to discovered: discovery, keck, hittites, gamow, astronomer, ceres, niobe, known,
# Nearest to units: unit, centimetre, households, factoring, cgs, webcast, housing, expeditionary,
# Nearest to shown: kacl, sds, cit, observes, workings, bebop, maris, provably,
# Nearest to applications: monterey, developed, cryptographically, illustrates, newall, millionth, truetype, selenide,
# Nearest to bill: bills, secede, flicker, assertive, rarest, carmina, parliament, hints,
# Nearest to resources: extremes, hydropower, natural, debugged, resource, nautical, awful, crops,
# Nearest to animals: animal, primates, creatures, burmese, rabbits, cannibal, myocardium, dinosauria,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7925 0.3113 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7987 0.3073 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7667 0.3056 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7783 0.3055 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8345 0.3060 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7940 0.3054 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7759 0.3074 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8103 0.3052 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7647 0.3113 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7554 0.3052 sec/batch
# Nearest to an: a, the, in, to, and, as, is, that,
# Nearest to on: the, of, this, in, for, a, from, with,
# Nearest to to: of, the, in, a, and, as, by, from,
# Nearest to however: be, though, the, in, relatively, known, different, of,
# Nearest to with: the, a, in, and, to, for, of, is,
# Nearest to more: than, of, less, to, but, because, particularly, larger,
# Nearest to the: of, a, in, as, is, and, to, from,
# Nearest to four: one, six, three, two, five, zero, seven, eight,
# Nearest to test: testing, torsion, laziness, ban, flipper, bmj, annotation, variation,
# Nearest to discovered: discovery, astronomer, gamow, hittites, keck, known, spaceprobe, schlegel,
# Nearest to units: unit, centimetre, households, factoring, cgs, expeditionary, webcast, housing,
# Nearest to shown: kacl, sds, cit, observes, bebop, maris, provably, chanced,
# Nearest to applications: monterey, developed, cryptographically, newall, millionth, selenide, illustrates, truetype,
# Nearest to bill: bills, secede, assertive, flicker, parliament, overridden, carmina, rarest,
# Nearest to resources: extremes, hydropower, resource, natural, debugged, nautical, awful, campaigns,
# Nearest to animals: animal, creatures, primates, burmese, cannibal, rabbits, myocardium, fecal,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7994 0.3086 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7979 0.3065 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9059 0.3037 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8454 0.3056 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8293 0.3054 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8018 0.3064 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.6995 0.3046 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7898 0.3065 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6695 0.3058 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7949 0.3072 sec/batch
# Nearest to an: a, the, in, is, to, as, and, that,
# Nearest to on: the, in, of, from, for, a, first, this,
# Nearest to to: the, a, in, of, and, from, as, an,
# Nearest to however: be, relatively, though, different, the, time, in, include,
# Nearest to with: the, a, in, and, for, to, of, are,
# Nearest to more: than, but, less, because, to, of, discounting, some,
# Nearest to the: of, in, a, from, and, is, as, s,
# Nearest to four: one, six, three, two, zero, seven, five, eight,
# Nearest to test: torsion, testing, laziness, ban, flipper, bmj, endangered, signed,
# Nearest to discovered: discovery, known, prions, hittites, gamow, keck, niobe, schlegel,
# Nearest to units: unit, centimetre, factoring, households, cgs, cormorants, webcast, expeditionary,
# Nearest to shown: kacl, sds, cit, workings, maris, bebop, addition, chanced,
# Nearest to applications: monterey, developed, cryptographically, newall, millionth, selenide, illustrates, strives,
# Nearest to bill: bills, secede, flicker, assertive, parliament, rarest, overridden, trudeau,
# Nearest to resources: extremes, hydropower, resource, natural, debugged, campaigns, crops, nautical,
# Nearest to animals: animal, primates, cannibal, creatures, burmese, rabbits, dinosauria, sheep,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7911 0.3089 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7609 0.3063 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
